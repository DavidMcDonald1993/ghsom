# %%
import os
import pickle
import shutil
import Queue

import networkx as nx
import numpy as np
import pandas as pd

# from ghsom import main_no_labels as ghsom_main
# from ghsom_parallel import main as ghsom_main
# from ghsom_parallel_signal_frequency import main as ghsom_main
from ghsom_parallel_edge_constrained import main as ghsom_main

def save_obj(obj, name):
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name):
    with open(name + '.pkl', 'rb') as f:
        return pickle.load(f)
    
    
root_dir = "/home/david/Documents/ghsom/hierarchical_exploration_constrained/"

# for data in ["yeast_reactome", "yeast_uetz", "collins", "ccsb", "ito_core", "lc_multiple"]:
for data in ["yeast_reactome"]:
    
    print "data={}".format(data)
    print
    
#     for e_sg in [0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1]:
#     for e_sg in [0.8, 0.7, 0.6, 0.5, 0.4]:
    for e_sg in [0.8, 0.6, 0.5]:
        
        print "e_sg={}".format(e_sg)
        print

#         for e_en in [0.7, 0.6, 0.5, 0.4, 0.3]:
#         for e_en in [e_sg]:
        for e_en in [0.3]:
        
            print "e_en={}".format(e_en)
            print

            os.chdir(root_dir)

            #ghsom parameters
            params = {'eta': 0.001,
                     'sigma': 1,
                      'e_sg': e_sg,
                     'e_en': e_en}

            map_file = '{}_hierarchy_communities_{}_{}'.format(data, e_sg, e_en)

            if not os.path.isfile("{}.pkl".format(map_file)):

                #run ghsom and save output
                print "running GHSOM and saving to {}.pkl".format(map_file)


#                 G, map = ghsom_main(params, '../embedded_{}.gpickle'.format(data), lam=1000)
#                 save_obj((G, map), map_file)
#                 print '\nnumber of communities found: {}, saved maps to {}'.format(len(map), map_file)

                G, networks = ghsom_main(params, '../embedded_{}.gpickle'.format(data), num_iter=1000, num_threads=5)
                save_obj((G, networks), map_file)

                print '\nnumber of maps grown: {}, saved maps to {}'.format(len(networks), map_file)

            else:

                print "{}.pkl already exists, loading maps".format(map_file)    
                #load output
#                 G, map = load_obj(map_file)
                G, networks = load_obj(map_file)

            #save results to file
            dir_name = "{}_hierarchy_communities_{}_{}".format(data, e_sg, e_en)
            if not os.path.isdir(dir_name):
#                 shutil.rmtree(dir_name)

                os.mkdir(dir_name)
                print 'made directory {}'.format(dir_name)

            os.chdir(dir_name)
            print "moved to {}".format(dir_name)

            #all genes
            all_genes_file = "all_genes.txt"
            with open(all_genes_file, 'w') as f:
                for n, d in G.nodes(data=True):
                    f.write("{}\n".format(n))
            print "wrote {}".format(all_genes_file)
            
            genes = G.nodes()
            gene_assignments = {k: v for k, v in zip(genes, 
                np.array([["" for j in range(100)] for i in range(len(genes))], dtype="S100"))}
            
            for map_id, network, e in networks[1:]:

                #shortest path matrix
                shortest_path = nx.floyd_warshall_numpy(network)
                communities_in_this_map = np.array([v for k, v in nx.get_node_attributes(network, "ID").items()])
                shortest_path_df = pd.DataFrame(shortest_path, index=communities_in_this_map)
                shortest_path_file = "{}_shortest_path.csv".format(map_id)
                
                shortest_path_df.to_csv(shortest_path_file, index=True, header=False, sep=',')
                print 'wrote shortest path matrix and saved as {}'.format(shortest_path_file)

                for n, d in network.nodes(data=True):
                    
                    community_assignment = d["ID"]
                    layer = community_assignment.count("-")
                    
                    for node in d["ls"]:
                        gene_assignments[node][layer] = community_assignment

#             #map queue
#             q = Queue.Queue()

#             c = 1
#             depth = 0
#             q.put((c, depth, map))

#             genes = G.nodes()
#             gene_assignments = {k: v for k, v in zip(genes, 
#                 np.array([["" for j in range(10)] for i in range(len(genes))], dtype="S20"))}

#             while not q.empty():

#                 map_id, depth, map = q.get()
#                 c = 1

#                 #shortest path matrix
#                 communities_in_this_map = np.array(["{}-{}".format(str(map_id).zfill(2), 
#                                                                    str(i).zfill(2)) for i in range(c, c + len(map))])

#                 shortest_path = nx.floyd_warshall_numpy(map).astype(np.int)
#     #             shortest_path = np.insert(shortest_path, 0, communities_in_this_map, axis=1)
#                 shortest_path_df = pd.DataFrame(shortest_path, index=communities_in_this_map)
#                 shortest_path_file = "{}_shortest_path.csv".format(str(map_id).zfill(2))
#     #             np.savetxt(shortest_path_file, shortest_path, fmt='%i', delimiter=",")
#                 shortest_path_df.to_csv(shortest_path_file, index=True, header=False, sep=',')
#                 print 'wrote shortest path matrix and saved as {}'.format(shortest_path_file)



#                 #gene community assignments
#                 for n, d in map.nodes(data=True):

#                     community = communities_in_this_map[c - 1]

#                     for node in d['ls']:
#                         gene_assignments[node][depth] = community

#                     #add map to queue
#                     m = d['n']

#                     if not m == []:

#                         q.put((community, depth + 1, m))   

#                     c += 1

            #back to matrix
            assignment_matrix = np.array([v for k, v in gene_assignments.items()])
            #remove unnecessary columns
            mask = assignment_matrix != ""
            idx = mask.any(axis = 0)
            assignment_matrix = assignment_matrix[:,idx]
            assignment_matrix = np.insert(assignment_matrix, 0, "01", axis=1)

            assignment_df = pd.DataFrame(assignment_matrix, index=genes)

            assignment_file = "assignment_matrix.csv"
        
            assignment_df.to_csv(assignment_file, index=True, header=False, sep=',')
                                 
            print "wrote assignment matrix and saved it as {}".format(assignment_file)
            print
            
            
print "DONE"
# Out:
# data=yeast_reactome
#
# e_sg=0.8
#
# e_en=0.3
#
# running GHSOM and saving to yeast_reactome_hierarchy_communities_0.8_0.3.pkl
# MQE_0=inf, growth_target=inf
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 1137, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 9303.8726991]
# trained network
# assigned nodes MQE=8.18596118615, target=inf
# growth terminated, MQE: 8.18596118615, target: inf, number of deleted neurons: 0
# submitted job: ID=01, e=8.18596118615, number of nodes=1137
# MQE_0=8.18596118615, growth_target=6.54876894892
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 1137, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 1137, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 1137, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 1105.25280322  1496.98479492  4599.92324023]
# trained network
# assigned nodes MQE=3.09894620704, target=6.54876894892
# growth terminated, MQE: 3.09894620704, target: 6.54876894892, number of deleted neurons: 0
# submitted job: ID=01-03, e=4.95140552543, number of nodes=1020
# MQE_0=4.95140552543, growth_target=3.96112442035
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 1020, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 1020, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 1020, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 2197.38142969  3656.12308619  2057.7699042 ]
# trained network
# assigned nodes MQE=5.93017685521, target=3.96112442035
# identified error unit: 1
# INITIALISE WEIGHT, NUMBER OF NODES: 76, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 1761.08036071  3402.93095492  1375.29223134  1792.28824488]
# trained network
# assigned nodes MQE=4.56983147501, target=3.96112442035
# identified error unit: 3
# INITIALISE WEIGHT, NUMBER OF NODES: 114, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 1752.08637928  3247.36759976  1127.23285184  1460.6068018    724.9281125 ]
# trained network
# assigned nodes MQE=4.22444726278, target=3.96112442035
# identified error unit: 4
# INITIALISE WEIGHT, NUMBER OF NODES: 156, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 1610.88469982  3277.13515499  1074.30839132  1191.06403075   485.72386256
#   1235.35158868]
# trained network
# assigned nodes MQE=4.09869249217, target=3.96112442035
# identified error unit: 1
# INITIALISE WEIGHT, NUMBER OF NODES: 26, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 1586.1826202   3251.08093259  1044.90068349  1172.32771238   417.01369616
#   1224.87221967   265.12763174]
# trained network
# assigned nodes MQE=3.81581406511, target=3.96112442035
# growth terminated, MQE: 3.81581406511, target: 3.96112442035, number of deleted neurons: 0
# MQE_0=4.3352576126, growth_target=3.46820609008MQE_0=4.08622438327, growth_target=3.26897950661submitted job: ID=01-03-02, e=4.3352576126, number of nodes=710
#
# MQE_0=4.15530507494, growth_target=3.32424405995
#
# computed shortest pathssubmitted job: ID=01-03-03, e=4.08622438327, number of nodes=59computed shortest paths
#
# INITIALISE WEIGHT, NUMBER OF NODES: 59, CONNECTED: Truesubmitted job: ID=01-03-04, e=4.15530507494, number of nodes=52
#
#
# INITIALISE WEIGHT, NUMBER OF NODES: 52, CONNECTED: TrueINITIALISE WEIGHT, NUMBER OF NODES: 59, CONNECTED: Truesubmitted job: ID=01-03-06, e=3.06442739666, number of nodes=113
#
#
#   MQE_0=3.06442739666, growth_target=2.45154191732INITIALISE WEIGHT, NUMBER OF NODES: 52, CONNECTED: TrueINITIALISE WEIGHT, NUMBER OF NODES: 59, CONNECTED: True
#
#
# computed shortest pathsINITIALISE WEIGHT, NUMBER OF NODES: 52, CONNECTED: Trueinitialised network
#
#
# INITIALISE WEIGHT, NUMBER OF NODES: 113, CONNECTED: Trueinitialised networkprecomputed sigmas
#
#
# INITIALISE WEIGHT, NUMBER OF NODES: 113, CONNECTED: Trueprecomputed sigmas
#
# INITIALISE WEIGHT, NUMBER OF NODES: 113, CONNECTED: True
# initialised network
# precomputed sigmas
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 710, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 710, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 710, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 123.85682183   81.02271329   81.02331368]
# trained network
# assigned nodes MQE=3.05181803759, target=3.32424405995
# growth terminated, MQE: 3.05181803759, target: 3.32424405995, number of deleted neurons: 0
# NET CHANGE AFTER TRAINING
# [ 160.4491318    71.31279975   71.87161694]
# trained network
# assigned nodes MQE=1.98080429045, target=3.26897950661
# growth terminated, MQE: 1.98080429045, target: 3.26897950661, number of deleted neurons: 0
# submitted job: ID=01-03-03-01, e=3.93034600745, number of nodes=57
# MQE_0=3.93034600745, growth_target=3.14427680596
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 57, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 57, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 57, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 111.3732295   189.61777407  107.32500745]
# trained network
# assigned nodes MQE=2.0932553651, target=2.45154191732
# growth terminated, MQE: 2.0932553651, target: 2.45154191732, number of deleted neurons: 0
# submitted job: ID=01-03-06-01, e=3.00049253599, number of nodes=75
# MQE_0=3.00049253599, growth_target=2.40039402879
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 75, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 75, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 75, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [  57.54003417   84.36555231  132.34354516]
# trained network
# assigned nodes MQE=2.91784847221, target=3.14427680596
# growth terminated, MQE: 2.91784847221, target: 3.14427680596, number of deleted neurons: 0
# NET CHANGE AFTER TRAINING
# [  71.76202282   84.60814203  152.96156311]
# trained network
# assigned nodes MQE=2.55491002351, target=2.40039402879
# identified error unit: 1
# INITIALISE WEIGHT, NUMBER OF NODES: 11, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [  58.23303077   70.05046916  136.67257301   62.73787292]
# trained network
# assigned nodes MQE=1.98811004444, target=2.40039402879
# growth terminated, MQE: 1.98811004444, target: 2.40039402879, number of deleted neurons: 0
# submitted job: ID=01-03-06-01-03, e=2.74655290163, number of nodes=63
# MQE_0=2.74655290163, growth_target=2.19724232131
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 63, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 63, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 63, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 55.92707379  81.06367464  83.76200738]
# trained network
# assigned nodes MQE=1.81164912167, target=2.19724232131
# growth terminated, MQE: 1.81164912167, target: 2.19724232131, number of deleted neurons: 0
# submitted job: ID=01-03-06-01-03-03, e=2.76320910115, number of nodes=59
# MQE_0=2.76320910115, growth_target=2.21056728092
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 59, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 59, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 59, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [  51.59097916   47.6042398   101.97996536]
# trained network
# assigned nodes MQE=2.17114070092, target=2.21056728092
# growth terminated, MQE: 2.17114070092, target: 2.21056728092, number of deleted neurons: 0
# NET CHANGE AFTER TRAINING
# [ 1199.81940029  1323.32455289   752.55315252]
# trained network
# assigned nodes MQE=3.33956492229, target=3.46820609008
# growth terminated, MQE: 3.33956492229, target: 3.46820609008, number of deleted neurons: 0
# submitted job: ID=01-03-02-01, e=3.6322897597, number of nodes=455
# submitted job: ID=01-03-02-02, e=2.51376037283, number of nodes=178MQE_0=3.6322897597, growth_target=2.90583180776
#
# MQE_0=3.87264463434, growth_target=3.09811570748submitted job: ID=01-03-02-03, e=3.87264463434, number of nodes=77
#
# computed shortest pathsMQE_0=2.51376037283, growth_target=2.01100829826
#
# computed shortest pathsINITIALISE WEIGHT, NUMBER OF NODES: 77, CONNECTED: True
#
# INITIALISE WEIGHT, NUMBER OF NODES: 178, CONNECTED: TrueINITIALISE WEIGHT, NUMBER OF NODES: 77, CONNECTED: True
#
# INITIALISE WEIGHT, NUMBER OF NODES: 178, CONNECTED: TrueINITIALISE WEIGHT, NUMBER OF NODES: 77, CONNECTED: True
#
# INITIALISE WEIGHT, NUMBER OF NODES: 178, CONNECTED: Trueinitialised network
#
# initialised networkprecomputed sigmas
#
# precomputed sigmas
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 455, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 455, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 455, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 119.8188439    85.81139318  114.24012278]
# trained network
# assigned nodes MQE=2.73157626837, target=3.09811570748
# growth terminated, MQE: 2.73157626837, target: 3.09811570748, number of deleted neurons: 0
# NET CHANGE AFTER TRAINING
# [ 232.98114067  191.57481433  140.37432532]
# trained network
# assigned nodes MQE=1.86360938362, target=2.01100829826
# growth terminated, MQE: 1.86360938362, target: 2.01100829826, number of deleted neurons: 0
# submitted job: ID=01-03-02-02-01, e=2.33480527071, number of nodes=165
# MQE_0=2.33480527071, growth_target=1.86784421657
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 165, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 165, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 165, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 140.22238773  234.97624198  135.80807438]
# trained network
# assigned nodes MQE=2.22091537436, target=1.86784421657
# identified error unit: 3
# INITIALISE WEIGHT, NUMBER OF NODES: 104, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [  465.29954687  1050.98060521   372.90915633]
# trained network
# assigned nodes MQE=3.05190277824, target=2.90583180776
# identified error unit: 1
# INITIALISE WEIGHT, NUMBER OF NODES: 82, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 131.54192737  224.24723115  131.3725099    61.67833812]
# trained network
# assigned nodes MQE=1.33671426503, target=1.86784421657
# growth terminated, MQE: 1.33671426503, target: 1.86784421657, number of deleted neurons: 0
# submitted job: ID=01-03-02-02-01-02, e=2.33999516637, number of nodes=162
# MQE_0=2.33999516637, growth_target=1.8719961331
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 162, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 162, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 162, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 115.86799844  300.98385061  101.65470428]
# trained network
# assigned nodes MQE=1.79541618358, target=1.8719961331
# growth terminated, MQE: 1.79541618358, target: 1.8719961331, number of deleted neurons: 0
# submitted job: ID=01-03-02-02-01-02-02, e=2.29785597563, number of nodes=149
# MQE_0=2.29785597563, growth_target=1.8382847805
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 149, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 149, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 149, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [  93.03463881  253.00211153  220.16370552]
# trained network
# assigned nodes MQE=2.4001892824, target=1.8382847805
# identified error unit: 3
# INITIALISE WEIGHT, NUMBER OF NODES: 114, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 341.66046866  914.38134548  315.61637818  457.72604663]
# trained network
# assigned nodes MQE=2.52327147049, target=2.90583180776
# growth terminated, MQE: 2.52327147049, target: 2.90583180776, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02, e=2.66525259122, number of nodes=346
# MQE_0=2.66525259122, growth_target=2.13220207298submitted job: ID=01-03-02-01-04, e=2.80871856506, number of nodes=73
# MQE_0=2.80871856506, growth_target=2.24697485205
#
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 73, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 73, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 73, CONNECTED: True
# initialised network
# precomputed sigmas
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 346, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 346, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 346, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [  78.42063501  215.42682381  187.86860702  127.48391147]
# trained network
# assigned nodes MQE=2.30191851863, target=1.8382847805
# identified error unit: 3
# INITIALISE WEIGHT, NUMBER OF NODES: 104, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 123.87087681   83.35972033   44.24628784]
# trained network
# assigned nodes MQE=2.19073766997, target=2.24697485205
# growth terminated, MQE: 2.19073766997, target: 2.24697485205, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-04-01, e=2.43685823081, number of nodes=55
# MQE_0=2.43685823081, growth_target=1.94948658465
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 55, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 55, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 55, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 55.7842932   56.65579766  55.74359499]
# trained network
# assigned nodes MQE=1.84848977425, target=1.94948658465
# growth terminated, MQE: 1.84848977425, target: 1.94948658465, number of deleted neurons: 0
# NET CHANGE AFTER TRAINING
# [  48.63385021  139.92042036  109.59431373   57.61586935  196.00394091]
# trained network
# assigned nodes MQE=2.07190020119, target=1.8382847805
# identified error unit: 5
# INITIALISE WEIGHT, NUMBER OF NODES: 100, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 192.7324259   853.09596844  219.64491294]
# trained network
# assigned nodes MQE=2.63377493174, target=2.13220207298
# identified error unit: 3
# INITIALISE WEIGHT, NUMBER OF NODES: 35, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [  40.52660226  119.68798217   85.9721998    49.57542601  175.43584886
#    89.30496999]
# trained network
# assigned nodes MQE=2.11064581196, target=1.8382847805
# identified error unit: 5
# INITIALISE WEIGHT, NUMBER OF NODES: 53, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [  39.48396855  112.88945332   78.1898313    48.35667356  144.21679757
#    89.42581597   62.03643417]
# trained network
# assigned nodes MQE=1.9841452531, target=1.8382847805
# identified error unit: 5
# INITIALISE WEIGHT, NUMBER OF NODES: 45, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 164.97225097  787.39526252  205.75826394  238.67036273]
# trained network
# assigned nodes MQE=1.83456622773, target=2.13220207298
# growth terminated, MQE: 1.83456622773, target: 2.13220207298, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02, e=2.66417300789, number of nodes=339
# MQE_0=2.66417300789, growth_target=2.13133840631
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 339, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 339, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 339, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [  37.80461008  112.88824797   68.74369209   46.1657825   122.3787151
#    82.51183823   54.40667481   61.9956773 ]
# trained network
# assigned nodes MQE=1.93622161634, target=1.8382847805
# identified error unit: 7
# INITIALISE WEIGHT, NUMBER OF NODES: 13, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [  37.70922436  112.32930819   68.19156303   45.99391865  123.72463649
#    79.57209978   43.88653132   60.34144052   40.51610167]
# trained network
# assigned nodes MQE=1.76784970737, target=1.8382847805
# growth terminated, MQE: 1.76784970737, target: 1.8382847805, number of deleted neurons: 0
# submitted job: ID=01-03-02-02-01-02-02-05, e=2.11336492679, number of nodes=62
# MQE_0=2.11336492679, growth_target=1.69069194143
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 62, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 62, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 62, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 59.33691348  61.58461119  58.12302812]
# trained network
# assigned nodes MQE=1.94640748217, target=1.69069194143
# identified error unit: 3
# INITIALISE WEIGHT, NUMBER OF NODES: 29, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 51.85379137  52.03266655  46.49387917  37.83644461]
# trained network
# assigned nodes MQE=1.53513710661, target=1.69069194143
# growth terminated, MQE: 1.53513710661, target: 1.69069194143, number of deleted neurons: 0
# NET CHANGE AFTER TRAINING
# [ 350.20773049  234.27156307  841.81873809]
# trained network
# assigned nodes MQE=3.08052402195, target=2.13133840631
# identified error unit: 1
# INITIALISE WEIGHT, NUMBER OF NODES: 74, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 324.02383941  223.96396954  808.66238242  314.56329861]
# trained network
# assigned nodes MQE=2.99704047962, target=2.13133840631
# identified error unit: 4
# INITIALISE WEIGHT, NUMBER OF NODES: 13, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 308.6692356   220.3789738   804.95270706  304.95152845   78.2110607 ]
# trained network
# assigned nodes MQE=2.73418235637, target=2.13133840631
# identified error unit: 1
# INITIALISE WEIGHT, NUMBER OF NODES: 61, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 242.10127328  163.01588509  609.74629123  222.52199819   49.82223251
#   387.86821335]
# trained network
# assigned nodes MQE=2.72328004756, target=2.13133840631
# identified error unit: 1
# INITIALISE WEIGHT, NUMBER OF NODES: 29, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 226.46612934  146.57044982  555.42645078  198.20874493   45.29248197
#   310.82635171  222.98180401]
# trained network
# assigned nodes MQE=2.82964343087, target=2.13133840631
# identified error unit: 1
# INITIALISE WEIGHT, NUMBER OF NODES: 18, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 207.90674801  132.19993766  461.60071547  179.51835591   40.40341748
#   218.68723691  204.60963538  203.79694805]
# trained network
# assigned nodes MQE=2.41696395948, target=2.13133840631
# identified error unit: 6
# INITIALISE WEIGHT, NUMBER OF NODES: 127, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 207.84584947  127.8846513   424.29679809  172.31989805   40.04511124
#   178.31098121  176.85391931  156.64826739  153.07389832]
# trained network
# assigned nodes MQE=2.4579393789, target=2.13133840631
# identified error unit: 7
# INITIALISE WEIGHT, NUMBER OF NODES: 104, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 123.44439332   94.24066875  226.90077442  113.80936239   27.86322834
#    86.77400218  141.76417084   86.69327157   81.3363256   415.97721156]
# trained network
# assigned nodes MQE=2.30939983525, target=2.13133840631
# identified error unit: 4
# INITIALISE WEIGHT, NUMBER OF NODES: 8, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 118.76057627   93.85150547  219.37455243   97.30107325   27.62230296
#    85.98203335  140.96807662   86.24957373   81.05882363  417.97896661
#    23.80488531]
# trained network
# assigned nodes MQE=2.09645598041, target=2.13133840631
# growth terminated, MQE: 2.09645598041, target: 2.13133840631, number of deleted neurons: 0
# MQE_0=2.13332248502, growth_target=1.70665798802submitted job: ID=01-03-02-01-02-02-03, e=2.13332248502, number of nodes=128
#
#  submitted job: ID=01-03-02-01-02-02-10, e=2.2974141253, number of nodes=98computed shortest paths
#
# MQE_0=2.2974141253, growth_target=1.83793130024INITIALISE WEIGHT, NUMBER OF NODES: 128, CONNECTED: True
#
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 128, CONNECTED: TrueINITIALISE WEIGHT, NUMBER OF NODES: 98, CONNECTED: True
#
# INITIALISE WEIGHT, NUMBER OF NODES: 128, CONNECTED: TrueINITIALISE WEIGHT, NUMBER OF NODES: 98, CONNECTED: True
#
# initialised network
# INITIALISE WEIGHT, NUMBER OF NODES: 98, CONNECTED: Trueprecomputed sigmas
#
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [  77.11704873  284.51257082   76.64405979]
# trained network
# assigned nodes MQE=1.97358313054, target=1.83793130024
# identified error unit: 2
# INITIALISE WEIGHT, NUMBER OF NODES: 93, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 116.70173224  119.50926476  111.82736768]
# trained network
# assigned nodes MQE=1.38082663514, target=1.70665798802
# growth terminated, MQE: 1.38082663514, target: 1.70665798802, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01, e=2.1354524758, number of nodes=126
# MQE_0=2.1354524758, growth_target=1.70836198064
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 126, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 126, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 126, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [  76.7150526   153.90111523   46.12811294  162.95841663]
# trained network
# assigned nodes MQE=1.89998093647, target=1.83793130024
# identified error unit: 4
# INITIALISE WEIGHT, NUMBER OF NODES: 89, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [  65.2476059   145.62645653  142.96681312]
# trained network
# assigned nodes MQE=1.64373767412, target=1.70836198064
# growth terminated, MQE: 1.64373767412, target: 1.70836198064, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03, e=2.09285185258, number of nodes=119
# MQE_0=2.09285185258, growth_target=1.67428148207
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 119, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 119, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 119, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [  58.56255869  121.11832455   35.85828862  130.98569591  103.78613289]
# trained network
# assigned nodes MQE=1.95464512271, target=1.83793130024
# identified error unit: 2
# INITIALISE WEIGHT, NUMBER OF NODES: 84, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 138.27649196   60.98083982  129.10370946]
# trained network
# assigned nodes MQE=1.60942200245, target=1.67428148207
# growth terminated, MQE: 1.60942200245, target: 1.67428148207, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01, e=2.0269402154, number of nodes=113
# MQE_0=2.0269402154, growth_target=1.62155217232
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 113, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 113, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 113, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [  43.35811909   90.49153303   28.58450971   80.98856515   77.52555171
#   109.93973849]
# trained network
# assigned nodes MQE=1.89459167786, target=1.83793130024
# identified error unit: 6
# INITIALISE WEIGHT, NUMBER OF NODES: 80, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 98.25872569  98.13658264  95.57276306]
# trained network
# assigned nodes MQE=1.34421033395, target=1.62155217232
# growth terminated, MQE: 1.34421033395, target: 1.62155217232, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01-02, e=2.02755370974, number of nodes=111
# MQE_0=2.02755370974, growth_target=1.62204296779
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 111, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 111, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 111, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 39.91055332  86.67097672  27.03510477  73.88529237  67.5062682
#   80.77264436  64.80689818]
# trained network
# assigned nodes MQE=1.99769026978, target=1.83793130024
# identified error unit: 1
# INITIALISE WEIGHT, NUMBER OF NODES: 10, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 98.65274996  93.82555173  94.28604248]
# trained network
# assigned nodes MQE=1.34456759277, target=1.62204296779
# growth terminated, MQE: 1.34456759277, target: 1.62204296779, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01-02-01, e=2.0278685776, number of nodes=109
# MQE_0=2.0278685776, growth_target=1.62229486208
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 109, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 109, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 109, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 36.87823207  84.12619415  21.02766779  67.43883547  62.97134241
#   75.58383291  60.2844393   31.46780052]
# MQE_0=2.88939212427, growth_target=2.31151369942trained network
#
# computed shortest pathsassigned nodes MQE=1.83284953311, target=1.83793130024
#
# INITIALISE WEIGHT, NUMBER OF NODES: 72, CONNECTED: Truegrowth terminated, MQE: 1.83284953311, target: 1.83793130024, number of deleted neurons: 0
#
# INITIALISE WEIGHT, NUMBER OF NODES: 72, CONNECTED: Truesubmitted job: ID=01-03-02-01-02-02-10-07, e=2.88939212427, number of nodes=72
#
# INITIALISE WEIGHT, NUMBER OF NODES: 72, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 119.18366012   68.2989679    70.62391691]
# trained network
# assigned nodes MQE=2.20888307655, target=2.31151369942
# growth terminated, MQE: 2.20888307655, target: 2.31151369942, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-10-07-02, e=2.94485983845, number of nodes=53
# MQE_0=2.94485983845, growth_target=2.35588787076
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 53, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 53, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 53, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [  81.75581629  117.14907356   79.69639148]
# trained network
# assigned nodes MQE=1.50120063098, target=1.62229486208
# growth terminated, MQE: 1.50120063098, target: 1.62229486208, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01-02-01-02, e=2.00097479257, number of nodes=106
# MQE_0=2.00097479257, growth_target=1.60077983406
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 106, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 106, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 106, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 31.55613853  29.61364334  97.37577023]
# trained network
# assigned nodes MQE=1.65407660942, target=2.35588787076
# growth terminated, MQE: 1.65407660942, target: 2.35588787076, number of deleted neurons: 0
# NET CHANGE AFTER TRAINING
# [ 90.03782634  92.88690469  90.9699532 ]
# trained network
# assigned nodes MQE=1.34476627972, target=1.60077983406
# growth terminated, MQE: 1.34476627972, target: 1.60077983406, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01-02-01-02-01, e=2.0302910374, number of nodes=104
# MQE_0=2.0302910374, growth_target=1.62423282992
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 104, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 104, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 104, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 91.4326438   90.80342698  86.5260102 ]
# trained network
# assigned nodes MQE=1.51144763607, target=1.62423282992
# growth terminated, MQE: 1.51144763607, target: 1.62423282992, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01-02-01-02-01-03, e=2.0312183272, number of nodes=101
# MQE_0=2.0312183272, growth_target=1.62497466176
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 101, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 101, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 101, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 87.06514246  87.52141506  86.4085003 ]
# trained network
# assigned nodes MQE=1.34559616911, target=1.62497466176
# growth terminated, MQE: 1.34559616911, target: 1.62497466176, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03, e=2.03074988175, number of nodes=99
# MQE_0=2.03074988175, growth_target=1.6245999054
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 99, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 99, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 99, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 83.80205912  85.45868602  86.54443632]
# trained network
# assigned nodes MQE=1.34581111522, target=1.6245999054
# growth terminated, MQE: 1.34581111522, target: 1.6245999054, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03, e=2.03243159119, number of nodes=97
# MQE_0=2.03243159119, growth_target=1.62594527295
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 97, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 97, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 97, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 83.91849554  83.88751843  82.87004019]
# trained network
# assigned nodes MQE=1.34575372734, target=1.62594527295
# growth terminated, MQE: 1.34575372734, target: 1.62594527295, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01, e=2.03311584665, number of nodes=95
# MQE_0=2.03311584665, growth_target=1.62649267732
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 95, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 95, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 95, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 80.97833345  81.77278573  82.81773219]
# trained network
# assigned nodes MQE=1.34626921957, target=1.62649267732
# growth terminated, MQE: 1.34626921957, target: 1.62649267732, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01-01, e=2.03374277737, number of nodes=93
# MQE_0=2.03374277737, growth_target=1.6269942219
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 93, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 93, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 93, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 80.91549432  80.21181794  79.53176131]
# trained network
# assigned nodes MQE=1.34616001724, target=1.6269942219
# growth terminated, MQE: 1.34616001724, target: 1.6269942219, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01-01-01, e=2.03339517378, number of nodes=91
# MQE_0=2.03339517378, growth_target=1.62671613902
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 91, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 91, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 91, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 78.09063991  77.5327001   79.75948155]
# trained network
# assigned nodes MQE=1.34639447104, target=1.62671613902
# growth terminated, MQE: 1.34639447104, target: 1.62671613902, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01-01-01-02, e=2.03523606592, number of nodes=89
# MQE_0=2.03523606592, growth_target=1.62818885274
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 89, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 89, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 89, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 77.32169587  76.69019307  76.24307821]
# trained network
# assigned nodes MQE=1.34637789569, target=1.62818885274
# growth terminated, MQE: 1.34637789569, target: 1.62818885274, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01-01-01-02-01, e=2.03592815489, number of nodes=87
# MQE_0=2.03592815489, growth_target=1.62874252391
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 87, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 87, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 87, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 75.57960349  74.10476972  75.54785324]
# trained network
# assigned nodes MQE=1.34726713694, target=1.62874252391
# growth terminated, MQE: 1.34726713694, target: 1.62874252391, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01-01-01-02-01-02, e=2.03684213348, number of nodes=85
# MQE_0=2.03684213348, growth_target=1.62947370678
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 85, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 85, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 85, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 71.02550493  75.72715822  73.22521585]
# trained network
# assigned nodes MQE=1.34789497631, target=1.62947370678
# growth terminated, MQE: 1.34789497631, target: 1.62947370678, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01-01-01-02-01-02-03, e=2.03769507106, number of nodes=83
# MQE_0=2.03769507106, growth_target=1.63015605685
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 83, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 83, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 83, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 69.75774759  74.13173122  70.91841253]
# trained network
# assigned nodes MQE=1.34720329796, target=1.63015605685
# growth terminated, MQE: 1.34720329796, target: 1.63015605685, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01-01-01-02-01-02-03-03, e=2.03753736587, number of nodes=81
# MQE_0=2.03753736587, growth_target=1.63002989269
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 81, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 81, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 81, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 71.9133537   68.80390211  69.07641287]
# trained network
# assigned nodes MQE=1.34751088493, target=1.63002989269
# growth terminated, MQE: 1.34751088493, target: 1.63002989269, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01-01-01-02-01-02-03-03-03, e=2.03846488506, number of nodes=79
# MQE_0=2.03846488506, growth_target=1.63077190804
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 79, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 79, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 79, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 68.08961439  68.63625808  67.92063166]
# trained network
# assigned nodes MQE=1.34850033291, target=1.63077190804
# growth terminated, MQE: 1.34850033291, target: 1.63077190804, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01-01-01-02-01-02-03-03-03-03, e=2.03954279755, number of nodes=77
# MQE_0=2.03954279755, growth_target=1.63163423804
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 77, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 77, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 77, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 67.3813817   67.20679539  65.02752838]
# trained network
# assigned nodes MQE=1.34856690853, target=1.63163423804
# growth terminated, MQE: 1.34856690853, target: 1.63163423804, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01-01-01-02-01-02-03-03-03-03-01, e=2.04052792923, number of nodes=75
# MQE_0=2.04052792923, growth_target=1.63242234338
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 75, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 75, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 75, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 65.63145435  64.94866072  63.82453636]
# trained network
# assigned nodes MQE=1.34917589545, target=1.63242234338
# growth terminated, MQE: 1.34917589545, target: 1.63242234338, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01-01-01-02-01-02-03-03-03-03-01-03, e=2.04264315645, number of nodes=73
# MQE_0=2.04264315645, growth_target=1.63411452516
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 73, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 73, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 73, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 65.4902304   62.4819851   61.27919485]
# trained network
# assigned nodes MQE=1.34958628415, target=1.63411452516
# growth terminated, MQE: 1.34958628415, target: 1.63411452516, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01-01-01-02-01-02-03-03-03-03-01-03-01, e=2.04279010448, number of nodes=71
# MQE_0=2.04279010448, growth_target=1.63423208358
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 71, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 71, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 71, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 61.03110105  61.98490092  61.06315947]
# trained network
# assigned nodes MQE=1.34967697811, target=1.63423208358
# growth terminated, MQE: 1.34967697811, target: 1.63423208358, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01-01-01-02-01-02-03-03-03-03-01-03-01-03, e=2.04494813856, number of nodes=69
# MQE_0=2.04494813856, growth_target=1.63595851085
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 69, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 69, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 69, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 58.69018119  59.77977648  60.50402257]
# trained network
# assigned nodes MQE=1.35043929606, target=1.63595851085
# growth terminated, MQE: 1.35043929606, target: 1.63595851085, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01-01-01-02-01-02-03-03-03-03-01-03-01-03-03, e=2.04636481025, number of nodes=67
# MQE_0=2.04636481025, growth_target=1.6370918482
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 67, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 67, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 67, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 49.35376224  72.60018242  48.94241293]
# trained network
# assigned nodes MQE=1.33475135465, target=1.6370918482
# growth terminated, MQE: 1.33475135465, target: 1.6370918482, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01-01-01-02-01-02-03-03-03-03-01-03-01-03-03-02, e=2.000939251, number of nodes=65
# MQE_0=2.000939251, growth_target=1.6007514008
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 65, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 65, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 65, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 55.85711957  56.3004378   56.53331275]
# trained network
# assigned nodes MQE=1.35104508589, target=1.6007514008
# growth terminated, MQE: 1.35104508589, target: 1.6007514008, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01-01-01-02-01-02-03-03-03-03-01-03-01-03-03-02-02, e=2.04911192694, number of nodes=63
# MQE_0=2.04911192694, growth_target=1.63928954155
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 63, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 63, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 63, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 54.72819862  53.74179517  55.07400161]
# trained network
# assigned nodes MQE=1.35123682127, target=1.63928954155
# growth terminated, MQE: 1.35123682127, target: 1.63928954155, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01-01-01-02-01-02-03-03-03-03-01-03-01-03-03-02-02-02, e=2.04963960536, number of nodes=61
# MQE_0=2.04963960536, growth_target=1.63971168429
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 61, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 61, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 61, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 53.54187063  52.55237052  52.39513147]
# trained network
# assigned nodes MQE=1.35277639737, target=1.63971168429
# growth terminated, MQE: 1.35277639737, target: 1.63971168429, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01-01-01-02-01-02-03-03-03-03-01-03-01-03-03-02-02-02-01, e=2.05231718489, number of nodes=59
# MQE_0=2.05231718489, growth_target=1.64185374791
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 59, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 59, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 59, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 65.62051917  42.16930365  42.76640178]
# trained network
# assigned nodes MQE=1.3345835049, target=1.64185374791
# growth terminated, MQE: 1.3345835049, target: 1.64185374791, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01-01-01-02-01-02-03-03-03-03-01-03-01-03-03-02-02-02-01-01, e=2.00104425455, number of nodes=57
# MQE_0=2.00104425455, growth_target=1.60083540364
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 57, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 57, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 57, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 40.94447108  62.11306943  42.18455008]
# trained network
# assigned nodes MQE=1.33477760201, target=1.60083540364
# growth terminated, MQE: 1.33477760201, target: 1.60083540364, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01-01-01-02-01-02-03-03-03-03-01-03-01-03-03-02-02-02-01-01-02, e=2.0010727071, number of nodes=55
# MQE_0=2.0010727071, growth_target=1.60085816568
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 55, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 55, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 55, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 47.5323982   47.09921969  48.48041042]
# trained network
# assigned nodes MQE=1.3537750555, target=1.60085816568
# growth terminated, MQE: 1.3537750555, target: 1.60085816568, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01-01-01-02-01-02-03-03-03-03-01-03-01-03-03-02-02-02-01-01-02-02, e=2.05812707478, number of nodes=53
# MQE_0=2.05812707478, growth_target=1.64650165982
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 53, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 53, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 53, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 46.72182811  46.39826937  44.92830375]
# trained network
# assigned nodes MQE=1.35476368066, target=1.64650165982
# growth terminated, MQE: 1.35476368066, target: 1.64650165982, number of deleted neurons: 0
# submitted job: ID=01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01-01-01-02-01-02-03-03-03-03-01-03-01-03-03-02-02-02-01-01-02-02-01, e=2.05932903444, number of nodes=51
# MQE_0=2.05932903444, growth_target=1.64746322755
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 51, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 51, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 51, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 44.15056955  44.65115131  44.17079124]
# trained network
# assigned nodes MQE=1.35556103619, target=1.64746322755
# growth terminated, MQE: 1.35556103619, target: 1.64746322755, number of deleted neurons: 0
# DONE
#
# number of maps grown: 59, saved maps to yeast_reactome_hierarchy_communities_0.8_0.3
# made directory yeast_reactome_hierarchy_communities_0.8_0.3
# moved to yeast_reactome_hierarchy_communities_0.8_0.3
# wrote all_genes.txt
# wrote shortest path matrix and saved as 01_shortest_path.csv
# wrote shortest path matrix and saved as 01-03_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-04_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-03_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-06_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-03-01_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-06-01_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-06-01-03_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-06-01-03-03_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-03_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-02_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-02-01_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-02-01-02_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-01_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-01-04_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-01-04-01_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-01-02_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-02-01-02-02_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-02-01-02-02-05_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-01-02-02_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-01-02-02-03_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-01-02-02-03-01_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-01-02-02-03-01-03_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-01-02-02-03-01-03-01_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-01-02-02-03-01-03-01-02_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-01-02-02-10_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-01-02-02-10-07_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-01-02-02-03-01-03-01-02-01_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-01-02-02-10-07-02_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-01-02-02-03-01-03-01-02-01-02_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-01-02-02-03-01-03-01-02-01-02-01_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-01-02-02-03-01-03-01-02-01-02-01-03_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01-01_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01-01-01_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01-01-01-02_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01-01-01-02-01_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01-01-01-02-01-02_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01-01-01-02-01-02-03_shortest_path.csv
# wrote shortest path matrix and saved as 01-03-02-01-02-02-03-01-03-01-02-01-02-01-03-03-03-01-01-01-02-01-02-03-03_shortest_path.csv
# ...
# identified error unit: 6
# INITIALISE WEIGHT, NUMBER OF NODES: 19, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [  38.60780604   80.99768357   82.03667065   56.33939633   34.60843
#   186.35407414   42.53157361   52.75311083   34.43227519   21.29648293
#     9.32723477   23.85685496   26.41312252]
# trained network
# assigned nodes MQE=2.07430036851, target=1.91105278841
# identified error unit: 5
# INITIALISE WEIGHT, NUMBER OF NODES: 10, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [  90.80654841   92.64879881   48.11686009  141.66988582   99.84299223
#   101.09845119   58.08976956   21.53484455   68.95385435   55.02012301
#    46.61307674   23.34896251]
# trained network
# assigned nodes MQE=2.0022366484, target=1.93018712226
# identified error unit: 6
# INITIALISE WEIGHT, NUMBER OF NODES: 17, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [  37.58499605   79.848069     79.23889055   55.85470156   33.01836884
#   185.73615951   42.4390658    52.88626619   34.48022304   20.64226232
#     8.99425339   23.14819094   24.76328975   10.97892371]
# trained network
# assigned nodes MQE=1.97384381138, target=1.91105278841
# identified error unit: 5
# INITIALISE WEIGHT, NUMBER OF NODES: 9, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 774.19242293  384.21801939  268.85189995  657.77691741  211.87913401
#    84.56653059]
# trained network
# assigned nodes MQE=2.44988676697, target=1.79586855245
# identified error unit: 3
# INITIALISE WEIGHT, NUMBER OF NODES: 17, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [  90.26023496   91.98631791   47.43713913  133.40217047   97.50724871
#    72.62744443   57.47093115   21.37958176   62.75313203   54.62771249
#    45.56783577   17.24374462   44.45984403]
# trained network
# assigned nodes MQE=1.97724604085, target=1.93018712226
# identified error unit: 5
# INITIALISE WEIGHT, NUMBER OF NODES: 16, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [  36.53702666   78.9311914    75.70643251   55.08670798   29.98533294
#   184.37315531   42.34140289   52.66211012   34.34935706   19.65768205
#     8.49978861   22.21726076   20.55854557    8.14374869   12.51852476]
# trained network
# assigned nodes MQE=1.88612339444, target=1.91105278841
# growth terminated, MQE: 1.88612339444, target: 1.91105278841, number of deleted neurons: 0
# submitted job: ID=01-04-06, e=2.34573880777, number of nodes=84
# MQE_0=2.34573880777, growth_target=1.17286940388
# computed shortest paths
# INITIALISE WEIGHT, NUMBER OF NODES: 84, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 84, CONNECTED: True
# INITIALISE WEIGHT, NUMBER OF NODES: 84, CONNECTED: True
# initialised network
# precomputed sigmas
# NET CHANGE AFTER TRAINING
# [ 112.97954386   58.35440218   98.58296754]
# trained network
# assigned nodes MQE=1.64428002851, target=1.17286940388
# identified error unit: 1
# INITIALISE WEIGHT, NUMBER OF NODES: 80, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 90.25426216  42.70199752  74.52379982  72.02618694]
# trained network
# assigned nodes MQE=1.65402711509, target=1.17286940388
# identified error unit: 4
# INITIALISE WEIGHT, NUMBER OF NODES: 77, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [  84.86402574   90.63128226   45.92258282  130.1953998    94.14866796
#    71.88334826   55.29283508   21.21846867   62.15462907   54.16371296
#    42.63457762   17.2846519    44.32232403   35.61620596]
# trained network
# assigned nodes MQE=1.93156811633, target=1.93018712226
# identified error unit: 1
# INITIALISE WEIGHT, NUMBER OF NODES: 24, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 74.43751165  40.31604986  69.03449621  71.65580683  41.83785279]
# trained network
# assigned nodes MQE=1.38944682983, target=1.17286940388
# identified error unit: 1
# INITIALISE WEIGHT, NUMBER OF NODES: 78, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 68.10957114  34.5482867   63.02659008  60.65198791  37.48442637
#   39.47973311]
# trained network
# assigned nodes MQE=1.43771098051, target=1.17286940388
# identified error unit: 4
# INITIALISE WEIGHT, NUMBER OF NODES: 75, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 61.26698604  31.35128562  56.59925972  58.82531579  35.60654367
#   32.95468026  30.97216153]
# trained network
# assigned nodes MQE=1.34957524187, target=1.17286940388
# identified error unit: 1
# INITIALISE WEIGHT, NUMBER OF NODES: 75, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 735.85168949  362.4030889   250.1727595   618.51101412  198.13670069
#   100.43150285  110.72387015]
# trained network
# assigned nodes MQE=2.26467727294, target=1.79586855245
# identified error unit: 7
# INITIALISE WEIGHT, NUMBER OF NODES: 105, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [  77.51986836   87.86376003   43.61529424  124.3230273    82.82198525
#    70.46629446   47.72864424   20.93226864   60.66103803   53.02529092
#    37.64186051   17.06376084   43.78363731   29.38913988   32.93515482]
# trained network
# assigned nodes MQE=1.9211233742, target=1.93018712226
# growth terminated, MQE: 1.9211233742, target: 1.93018712226, number of deleted neurons: 0
# NET CHANGE AFTER TRAINING
# [ 56.67608728  29.00038252  53.2013147   50.52400146  32.18213724
#   31.33532701  27.67075451  32.63792   ]
# trained network
# assigned nodes MQE=1.30661023455, target=1.17286940388
# identified error unit: 1
# INITIALISE WEIGHT, NUMBER OF NODES: 74, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 53.58331256  26.27092483  45.6539563   48.60267979  29.22150764
#   26.82817097  25.74664901  29.95762258  30.80185049]
# trained network
# assigned nodes MQE=1.3481732927, target=1.17286940388
# identified error unit: 4
# INITIALISE WEIGHT, NUMBER OF NODES: 71, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 50.11751892  24.51829419  41.91805367  45.99948697  26.93439834
#   25.0576111   24.37461127  28.11083384  28.53125276  25.79126755]
# trained network
# assigned nodes MQE=1.45856567446, target=1.17286940388
# identified error unit: 6
# INITIALISE WEIGHT, NUMBER OF NODES: 47, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 48.11074106  22.61771367  36.77668828  41.32635525  24.20221822
#   24.22465903  21.66765026  24.97958472  25.02564147  22.64663105
#   25.28545045]
# trained network
# assigned nodes MQE=1.30770212246, target=1.17286940388
# identified error unit: 1
# INITIALISE WEIGHT, NUMBER OF NODES: 66, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 45.94807803  20.94137909  31.74241598  35.29951462  22.31495838
#   22.5226601   20.43264008  25.12233729  22.03425365  20.87774803
#   24.49618075  23.68823449]
# trained network
# assigned nodes MQE=1.43802206441, target=1.17286940388
# identified error unit: 10
# INITIALISE WEIGHT, NUMBER OF NODES: 38, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 38.18538184  18.54427509  26.9840472   32.74454238  19.63577408
#   19.43046813  17.56352017  20.7030038   19.16245004  21.39498701
#   22.76397333  18.02709616  31.42661126]
# trained network
# assigned nodes MQE=1.31555395993, target=1.17286940388
# identified error unit: 1
# INITIALISE WEIGHT, NUMBER OF NODES: 61, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 698.4328391   349.33762075  255.29855951  580.90961989  191.27143997
#    99.05104485  112.09001533   85.29895089]
# trained network
# assigned nodes MQE=2.38383166874, target=1.79586855245
# identified error unit: 7
# INITIALISE WEIGHT, NUMBER OF NODES: 75, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 37.33804101  17.80305169  24.1789302   30.24176029  17.98307619
#   21.14928623  16.39173448  18.80965018  17.7224877   19.90769939
#   22.31079247  16.70037971  26.47857138  19.61506956]
# trained network
# assigned nodes MQE=1.34160715415, target=1.17286940388
# identified error unit: 4
# INITIALISE WEIGHT, NUMBER OF NODES: 58, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 36.79035008  17.15716516  22.98385267  29.48050406  16.8633678
#   19.35717879  14.97291922  18.23064535  16.37716778  18.90980232
#   21.86566917  15.63029867  25.46451964  20.47120644  15.38561613]
# trained network
# assigned nodes MQE=1.29760675171, target=1.17286940388
# identified error unit: 6
# INITIALISE WEIGHT, NUMBER OF NODES: 34, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 35.46261076  16.82210174  23.38628662  29.38210449  16.43756946
#   19.41376924  13.96144872  17.39690847  15.91797574  18.08184083
#   21.38575658  15.78779699  24.56086111  17.44127736  14.42206987
#   10.7371343 ]
# trained network
# assigned nodes MQE=1.34043744948, target=1.17286940388
# identified error unit: 10
# INITIALISE WEIGHT, NUMBER OF NODES: 33, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 32.12775156  16.32487357  25.79047074  28.97459015  13.85275861
#   18.29672009  12.92977707  15.23457308  14.74928329  18.45476482
#   20.94686021  13.92290522  22.87545884  14.46236129  12.33006831
#    8.91798257  13.73258198]
# trained network
# assigned nodes MQE=1.45884382416, target=1.17286940388
# identified error unit: 10
# INITIALISE WEIGHT, NUMBER OF NODES: 12, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 33.91753746  15.27027566  23.80197733  24.68090682  13.31671618
#   16.6102844   11.96880755  14.22163851  12.18812595  18.87500907
#   20.34894761  11.3563939   23.01643891  13.68422326  12.40375211
#    8.59982807  13.60656736  11.99475435]
# trained network
# assigned nodes MQE=1.35091897886, target=1.17286940388
# identified error unit: 11
# INITIALISE WEIGHT, NUMBER OF NODES: 8, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 655.08163856  330.96254937  245.80435082  536.80717785  181.56962146
#    95.8117025   114.39759202   99.46460415  101.29517128]
# trained network
# assigned nodes MQE=2.25684060273, target=1.79586855245
# identified error unit: 6
# INITIALISE WEIGHT, NUMBER OF NODES: 28, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 29.38800762  15.06746557  20.21790684  23.66965836  12.69622227
#   15.05218949  11.68576796  14.79891406  11.76357307  19.12838829
#   15.0631417   14.34331759  23.14826812  17.07268866  11.38510034
#    9.34072187  13.50411308  12.06901159  13.34723759]
# trained network
# assigned nodes MQE=1.41487417145, target=1.17286940388
# identified error unit: 10
# INITIALISE WEIGHT, NUMBER OF NODES: 27, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 31.68997433  14.47628742  23.98496295  22.06980731  12.22595753
#   14.51473038  11.53413503  12.61786923  11.65973415  18.52874313
#   14.67227381  10.40984862  23.10624312  12.77906727  11.22181385
#    8.87362188  13.34749995  12.46088137  13.16419241   7.23776989]
# trained network
# assigned nodes MQE=1.42749846266, target=1.17286940388
# identified error unit: 10
# INITIALISE WEIGHT, NUMBER OF NODES: 3, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 31.94948807  14.18680057  18.23514157  21.36227599  12.03126029
#   14.23239116  11.11261867  12.65196411  11.06409877  19.71456224
#   14.5471911   15.35420172  22.00958175  11.77462604  10.82939982
#    8.55000839  13.20030169  13.18830837  12.9649057    6.86630468
#    5.44073809]
# trained network
# DELETING NODES: [21]
# assigned nodes MQE=1.285883592, target=1.17286940388
# identified error unit: 1
# INITIALISE WEIGHT, NUMBER OF NODES: 49, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 29.54998508  14.01793574  16.97024701  21.71434361  11.52418218
#   13.65645749  10.8519944   13.72564305  11.50261611  17.83506163
#   14.30887285  16.01438784  21.0160131   13.00309523  11.06925159
#    7.45193318  13.04432678  11.9446764   13.06654733   7.14275796
#    9.95282598]
# trained network
# assigned nodes MQE=1.30656597768, target=1.17286940388
# identified error unit: 12
# INITIALISE WEIGHT, NUMBER OF NODES: 46, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 26.7442685   13.6085545   16.16220761  19.62650306  11.20339743
#   13.32096332  11.06742822  14.03018872  10.59055603  17.03521314
#   14.12960329  11.7903818   20.33983668  14.85607171  10.02714581
#    8.3225353   12.77388009  11.51762365  12.84091484   7.58824543
#   12.46210878   7.85941241]
# trained network
# assigned nodes MQE=1.26368602685, target=1.17286940388
# identified error unit: 4
# INITIALISE WEIGHT, NUMBER OF NODES: 46, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 654.23535169  330.24334903  244.4565805   537.09736236  179.27103827
#    94.23138901  113.26332667   98.70619685  100.40798035   33.00241272]
# trained network
# assigned nodes MQE=2.12553289175, target=1.79586855245
# identified error unit: 2
# INITIALISE WEIGHT, NUMBER OF NODES: 25, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 27.54606198  13.18089341  15.33997483  24.26445615  11.26706902
#   12.94836102  10.50692323  13.40291344   9.99013251  16.805807
#   13.94491351  13.26109209  21.63503421   9.10128495   9.73294971
#    7.50463441  12.72495834  11.4227163   12.45483572   6.20782704
#    9.02702413   8.72059354   8.68404891]
# trained network
# assigned nodes MQE=1.31310183762, target=1.17286940388
# identified error unit: 11
# INITIALISE WEIGHT, NUMBER OF NODES: 5, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 24.74172641  13.02362612  17.85115934  20.38348018  10.73622846
#   12.55194791  10.99827126  14.55642828  11.64863713  16.66213808
#   10.8422462    9.79324323  20.72501841  14.15881271  10.09340104
#    7.10908523  12.80497867  11.97969174   9.47138969   6.2968594
#    8.94106517   6.58295085   8.66684522   7.07131702]
# trained network
# assigned nodes MQE=1.34012038451, target=1.17286940388
# identified error unit: 20
# INITIALISE WEIGHT, NUMBER OF NODES: 22, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 23.08529603  12.53834711  15.92221297  18.56944687  10.25146138
#   12.34490923  10.25714636  13.02916919   9.53327407  16.29069095
#   10.56597484  14.91147783  20.50246978  11.31534551   9.08628218
#    7.13650058  12.66355021  12.18596521   9.34193247   7.19457769
#    8.47227035   6.96900265   8.54135388   7.03587361   7.06125405]
# trained network
# assigned nodes MQE=1.25791625954, target=1.17286940388
# identified error unit: 3
# INITIALISE WEIGHT, NUMBER OF NODES: 23, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 22.15552905  12.44628889  17.85957353  18.15780513  10.06742685
#   11.43083773  10.03038793  13.62203477   9.03407989  15.58403247
#   10.28197746   9.44214381  19.96974064   7.88206491   9.73866529
#    7.1004463   12.4670805   11.78236234   9.04137005   6.80363415
#    8.05263064   8.34762807   8.48990849   7.08651419  10.18810258
#    7.34212779]
# trained network
# assigned nodes MQE=1.26126385414, target=1.17286940388
# identified error unit: 13
# INITIALISE WEIGHT, NUMBER OF NODES: 12, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 656.33860283  293.21242027  234.10101957  530.49696962  178.66501988
#    93.11071567  111.95349607   97.53174194   99.91257407   32.96126113
#   194.48848836]
# trained network
# assigned nodes MQE=2.07402067388, target=1.79586855245
# identified error unit: 4
# INITIALISE WEIGHT, NUMBER OF NODES: 223, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 23.07470255  11.95891615  18.00850548  17.56615482   9.64684864
#   10.95741499   9.83012605  12.74776521   9.25567554  15.88633091
#   10.16184184   9.32202041  21.55949577   7.80691887   8.52797167
#    6.5367409   12.48197687  11.56958931   8.91953637   6.60399912
#   10.7364081    6.14355651   8.33684718   6.96373979   5.51439754
#    6.80488534   7.22675863]
# trained network
# assigned nodes MQE=1.24522145045, target=1.17286940388
# identified error unit: 14
# INITIALISE WEIGHT, NUMBER OF NODES: 21, CONNECTED: True
# expanded network
# NET CHANGE AFTER TRAINING
# [ 23.05981504  11.83875568  13.47980099  16.92005752   9.49926403
#   10.85681021   9.72170973  12.36913967   8.66962182  15.44117771
#   10.03984964  10.93578926  19.94685923   8.53314627   8.88591645
#    6.0992645   12.28488417  11.20156485   8.89680856   6.4622163
#    8.2458128    9.56829964   8.00904574   7.03429369   5.23933588
#    6.34636344   7.05167758   7.67652476]
# trained network
# assigned nodes MQE=1.22245163273, target=1.17286940388
# identified error unit: 12
# INITIALISE WEIGHT, NUMBER OF NODES: 41, CONNECTED: True
# expanded network

# %%
import numpy as np
import networkx as nx

from Queue import Queue
from threading import Thread
from threading import current_thread

from sklearn.manifold import MDS
from sklearn.metrics.pairwise import euclidean_distances

def distances(X, d):
    return euclidean_distances(X[:,:d])

def stress(distances, Ds, tri):
    return np.sqrt(np.sum((distances[tri] - np.sqrt(Ds[tri])) ** 2) / np.sum(Ds[tri]))
    
def classic_mds(Ds):
        
    #centering matrix
    n = len(Ds)
    C = np.identity(n) - np.ones((n, n)) / n
    
    #double centered similarity matrix
    K = - 0.5 * np.dot(np.dot(C, Ds), C)
    
    #eigen decompose K
    l, U = np.linalg.eigh(K)
    
    mask = l > 0
    l = l[mask]
    U = U[:, mask]
    
    ##sort eigenvalues (and eigenvectors) into ascending order
    idx = l.argsort()[::-1]
    l = l[idx]
    U = U[:,idx]
    
#     if k < 1:
        
#         print "attempting to preserve 95% of variance"
        
#         total = sum(l)
#         k = 0
#         var = sum(l[:k]) / total
#         while var < variance_preserved:
#             k += 1
#             var = sum(l[:k]) / total

#     print "embedding to {} dimensions".format(k)
    
    #position matrix
    X = np.dot(U, np.diag(l ** 0.5))
    
    #upper triangle
    tri = np.triu_indices(n=len(Ds), k = 1, m=len(Ds))

    #determine the k that minimised stress
    stresses = np.array([stress(distances(X, d), Ds, tri) for d in range(1, min(50, U.shape[1]))])
    k = stresses.argmin() + 1
    
    print "embedding to {} dimensions with stress {}".format(k, stresses[k-1])
    
    return X[:,:k], stresses

##function to generate benchmark graph
def benchmark_hierarchical_graph(edge_path, c1_path, c2_path):

    #construct graph from edge list
    G = nx.read_edgelist(edge_path)

    #create dictionarys of attributes
    c1 = read_attributes(c1_path)
    c2 = read_attributes(c2_path)

    #set attributes of G
    nx.set_node_attributes(G, 'firstlevelcommunity', c1)
    nx.set_node_attributes(G, 'secondlevelcommunity', c2)
    
    #return graph
    return G

##function to generate benchmark graph
def benchmark_graph(edge_path, c_path):
    
    #construct graph from edge list
    G = nx.read_edgelist(edge_path)

    #create dictionarys of attributes
    c = read_attributes(c_path)

    #set attributes of G
    nx.set_node_attributes(G, 'firstlevelcommunity', c)
    
    #return graph
    return G

##function to read in attributes from file and return a dictionary
def read_attributes(filepath):
    
    #initialise dictionary
    d = {}
    
    #open file
    with open(filepath) as f:
        
        #iterate over lines in f
        for l in f:
            
            #separate into key and value
            k, v = l.split()
            
            #add to dictionary
            d[k] = v
    
    #return
    return d

def filter_nodes_with_no_embedding(G, D):
    
    for n in G.nodes():
    
        if n not in D.keys():
            print "{} not in D, removing it from the network".format(n)
            G.remove_node(n)

##save embedding to graph
def set_embedding(G, X):
    
    embedding = {k: v for k, v in zip(G.nodes(), X)}
    
    nx.set_node_attributes(G, "embedding", embedding)
    
    
## get embedding
def get_embedding(G):

    return np.array([v for k, v in nx.get_node_attributes(G, "embedding").items()])
    
def main_hierarchical(network, first_level, second_level, filename):
    
    #import graph from file
    G = benchmark_hierarchical_graph(network, first_level, second_level)
    
    #only embed largest subgraph
    H = max(nx.connected_component_subgraphs(G), key=len)
    
    #embed into X
    D = nx.floyd_warshall(H)
    
    #remove nodes from H with no embedding
    filter_nodes_with_no_embedding(H, D)    

    ##to array
    Ds = np.array([[D[i][j] ** 2 for j in D.keys()] for i in D.keys()])

    #mds
    X, stresses = classic_mds(Ds)
    
    #save embedding to nodes of G
    set_embedding(H, X)
    
    #write gml file
    nx.write_gpickle(H, filename)

    return X, Ds, stresses
    
def main_binary(network, first_level, filename):
    
    #import graph from file
    G = benchmark_graph(network, first_level)
    
    #only embed largest subgraph
    H = max(nx.connected_component_subgraphs(G), key=len)
    
    #embed into X
    D = nx.floyd_warshall(H)
    
    #remove nodes from H with no embedding
    filter_nodes_with_no_embedding(H, D)   
    
    ##to array
    Ds = np.array([[D[i][j] ** 2 for j in D.keys()] for i in D.keys()])
    
    #mds
    X, stresses = custom_mds(Ds) 

    
#     print "embedding to {} dimensions".format(k)

#     mds = MDS(n_components = k, dissimilarity = "precomputed", n_jobs=-1, max_iter=10000)
#     X = mds.fit_transform(D)
    
    #save embedding to nodes of G
    set_embedding(H, X)
    
    #write gml file
    nx.write_gpickle(H, filename)
    
    return X, Ds, stresses

def main(txt, filename, D=None, delimiter="\t"):
    
    #import graph from file
    G = nx.read_edgelist(txt, delimiter=delimiter)
    
    #only embed largest subgraph
    H = max(nx.connected_component_subgraphs(G), key=len)
    
    #embed into X
    if D == None:
        #if no precomuped distance matrix then use floyd
        D = nx.floyd_warshall(H)
    
    #remove nodes from H with no embedding
    filter_nodes_with_no_embedding(H, D) 
    
    ##array of squared shortest path distances
    Ds = np.array([[D[i][j] ** 2 for j in D.keys()] for i in D.keys()])
    
    print "computed distance matrix"
    
#     #validation testing for best dimension
#     stresses = np.array([])
    
#     for k in range(min_k, max_k + 1):
        
#         mds = MDS(n_components = k, dissimilarity = "precomputed", n_jobs=-1, max_iter=10000)
#         mds.fit(D)

#         stress = mds.stress_
#         X = mds.embedding_
        
#         print stress

#         stresses = np.append(stresses, stress)
        
#         if len(stresses) > 1:
#             gradient = np.gradient(stresses, 5)[-1]

#             print "k={}, stress={}, gradient={}".format(k, stress, gradient)

#             if np.abs(gradient) < eps:
#                 print "BREAK"
#                 break
    
#     mds = MDS(n_components = k, dissimilarity = "precomputed", n_jobs=-1, max_iter=10000)
#     mds.fit(D)

#     stress = mds.stress_
#     X = mds.embedding_
    X, stresses = classic_mds(Ds)
    
    #save embedding to nodes of G
    set_embedding(H, X)

    #write gml file
    nx.write_gpickle(H, filename)

    return X, Ds, stresses

# %%
X, D, stresses = main("Uetz_screen.txt", "embedded_yeast_uetz.gpickle", delimiter="\t")
# Out:
# computed distance matrix
# embedding to 10 dimensions with stress 0.0827381995922

# %%
X, D, stresses = main_hierarchical("benchmarks/network.dat", "benchmarks/community_first_level.dat", 
                  "benchmarks/community_second_level.dat", "benchmarks/hierarchical_benchmark.gpickle")
# Out:
# embedding to 32 dimensions with stress 0.164205746756

# %%
stresses

# %%
G = nx.read_gpickle("benchmarks/hierarchical_benchmark.gpickle")

# %%
X = get_embedding(G)

# %%
X.shape
# Out:
# (512, 39)

# %%
G.nodes(data=True)
# Out:
# [(u'344',
#   {'embedding': array([  3.49051661e-01,  -3.19418447e-01,   1.09063765e-01,
#            -1.16078364e-01,   2.09129704e-01,  -1.71228473e-02,
#             4.34386387e-02,  -7.15931860e-02,   2.00001430e-01,
#            -3.23126125e-01,   8.64329535e-02,  -2.42280602e-01,
#             1.37117559e-01,  -1.93248824e-02,   7.07096772e-02,
#            -1.50439014e-01,  -7.93745584e-03,   5.94446806e-02,
#            -1.27927115e-01,   1.47864264e-01,  -1.66557114e-01,
#             2.62281413e-01,  -2.53536794e-02,   2.07000031e-04,
#            -4.86950644e-02,   2.32102072e-01,  -1.95973752e-01,
#             1.02894272e-01,  -9.60744416e-02,   8.14593478e-02,
#            -8.62704274e-02,   3.50756428e-03,  -3.28906988e-02,
#            -1.89287610e-01,   2.37095125e-01,  -2.35965601e-01,
#             1.02799014e-01,  -2.29461923e-01,  -2.39295936e-02]),
#    'firstlevelcommunity': '11',
#    'secondlevelcommunity': '3'}),
#  (u'345',
#   {'embedding': array([ 0.29818963, -0.36094679,  0.13751338, -0.10214628,  0.09621445,
#            0.05197943,  0.1053855 , -0.19393805,  0.09629912, -0.04079251,
#           -0.00387543, -0.21007438,  0.10970806, -0.06775092,  0.16233489,
#            0.33160612,  0.134439  ,  0.03609869, -0.32007996, -0.07635691,
#           -0.08414982,  0.25167537,  0.26508365, -0.02585255,  0.08048947,
#            0.13200637, -0.09316784, -0.10115442,  0.24345383, -0.30985711,
#           -0.06292389, -0.18642189, -0.04322954, -0.02078861, -0.06089916,
#            0.22003393,  0.12788929, -0.1738507 , -0.18979306]),
#    'firstlevelcommunity': '11',
#    'secondlevelcommunity': '3'}),
#  (u'346',
#   {'embedding': array([  3.16830769e-01,  -7.06414915e-02,   3.57237174e-01,
#             2.29470023e-01,  -3.35646088e-01,  -9.66574242e-02,
#             6.50195615e-02,   8.20798244e-02,   2.05868868e-01,
#             3.40714835e-02,   3.17506578e-01,   1.55588097e-01,
#             2.29242160e-01,   1.18689445e-01,   5.03697953e-02,
#            -5.28456381e-02,  -2.19015192e-02,   4.21066660e-02,
#             1.16771963e-01,  -1.49685696e-01,   2.70364907e-04,
#             2.33853326e-01,  -1.10324261e-01,   8.64870646e-02,
#            -3.60350483e-02,   2.13356689e-02,  -1.51185189e-01,
#            -1.78488602e-01,  -2.08292440e-01,  -5.81183551e-02,
#            -5.90766054e-02,  -4.45561773e-02,   1.31151729e-01,
#             2.18727429e-01,  -4.22458900e-02,   1.25812629e-01,
#            -2.29035850e-02,  -2.03254839e-03,  -9.82439119e-02]),
#    'firstlevelcommunity': '9',
#    'secondlevelcommunity': '3'}),
#  (u'347',
#   {'embedding': array([ 0.28532025, -0.19794634,  0.13958798,  0.21861442,  0.1064123 ,
#           -0.1086652 ,  0.25717137, -0.05848093,  0.11283661, -0.03299402,
#           -0.37535256,  0.00579036,  0.04193845, -0.18126621,  0.00696302,
#            0.01413577,  0.35549308, -0.0533577 ,  0.16455627,  0.26335966,
#            0.13622005, -0.03040382,  0.05071156, -0.26113707,  0.09178651,
#           -0.2056359 ,  0.01220097,  0.00938219, -0.0376328 , -0.00472201,
#           -0.08833982, -0.15058817,  0.09174372,  0.01484142,  0.13178322,
#           -0.18080605,  0.05637908,  0.00289633,  0.00977426]),
#    'firstlevelcommunity': '10',
#    'secondlevelcommunity': '3'}),
#  (u'340',
#   {'embedding': array([ 0.34196391, -0.03721214,  0.26308185, -0.03331104, -0.38387975,
#           -0.24767901,  0.05953375, -0.07070351, -0.10696257, -0.09093811,
#            0.22270751,  0.04227748,  0.03840132,  0.063881  , -0.24275479,
#            0.04624779, -0.33623728, -0.16784856, -0.07704269,  0.24151277,
#            0.18111338, -0.18235302,  0.14571299,  0.03043082, -0.0559344 ,
#            0.05598172,  0.11084874,  0.15171644, -0.01069494,  0.33635894,
#           -0.10354625,  0.00394981,  0.02353827, -0.12798257, -0.11812958,
#           -0.06487234,  0.10625552, -0.27085729,  0.1649545 ]),
#    'firstlevelcommunity': '9',
#    'secondlevelcommunity': '3'}),
#  (u'341',
#   {'embedding': array([ 0.26080591, -0.16613206,  0.27166635,  0.1546751 ,  0.25015774,
#           -0.01893892,  0.13307864, -0.12056191,  0.13506881,  0.22808254,
#           -0.14555977, -0.09695786, -0.07068516, -0.17908314, -0.25499403,
#            0.10148342,  0.01739161,  0.15345183,  0.05669683, -0.16197466,
#           -0.09263437,  0.07800941,  0.03442027, -0.13304297, -0.16471147,
#            0.1003682 , -0.00961841, -0.01488739, -0.19085726, -0.03257603,
#           -0.10415172,  0.19926672,  0.32061629, -0.21346372,  0.07870165,
#            0.31599896, -0.12901217,  0.01989376, -0.0067197 ]),
#    'firstlevelcommunity': '10',
#    'secondlevelcommunity': '3'}),
#  (u'342',
#   {'embedding': array([ 0.19592246, -0.07692668,  0.42425171, -0.14499186, -0.14907685,
#           -0.4072018 ,  0.14842199,  0.02961773,  0.02107018,  0.20059848,
#            0.01977353,  0.11913435,  0.26778097,  0.08083776, -0.17809967,
#            0.04121814, -0.11692168, -0.16978904,  0.02914408, -0.04235114,
#            0.17788486, -0.15682884,  0.20048263,  0.21828695, -0.05067866,
#           -0.126847  ,  0.12925337,  0.08792752,  0.1286842 ,  0.11673329,
#            0.1329202 ,  0.08288348,  0.30542851,  0.17161865, -0.09302483,
#            0.10646655,  0.0745298 , -0.0533275 , -0.08122306]),
#    'firstlevelcommunity': '9',
#    'secondlevelcommunity': '3'}),
#  (u'343',
#   {'embedding': array([ 0.36494726, -0.07936712,  0.29408004, -0.23981575, -0.3792642 ,
#           -0.15014912,  0.29166992,  0.11398422, -0.11265487, -0.08307458,
#            0.02483888,  0.08598883, -0.04892522, -0.16734597, -0.21667047,
#            0.02036138, -0.09101604, -0.12535777,  0.31823373, -0.00764098,
#           -0.10239306,  0.08483746,  0.07326039, -0.10174343,  0.18717421,
#            0.06403682, -0.18749968,  0.10343105, -0.17775568, -0.11479738,
#            0.05251677, -0.04347868, -0.25043165,  0.03051657,  0.06828778,
#           -0.10183483, -0.11405592, -0.17197704, -0.1037967 ]),
#    'firstlevelcommunity': '9',
#    'secondlevelcommunity': '3'}),
#  (u'348',
#   {'embedding': array([ 0.27891268, -0.12761302,  0.24071537,  0.13966997,  0.25414745,
#            0.22423458,  0.12022204, -0.12277819,  0.18639413,  0.39981819,
#           -0.13945545, -0.28537458, -0.09025745, -0.13499628,  0.01521542,
#           -0.21093158, -0.29007089, -0.13593111,  0.07155978, -0.01773126,
#            0.15040156,  0.09049192,  0.02290281,  0.0705628 ,  0.06354535,
#           -0.04906335,  0.17386882, -0.12961896, -0.22090305,  0.06193459,
#            0.15063519, -0.06678692,  0.01947141, -0.19782859,  0.05435377,
#            0.1609649 ,  0.01097388,  0.10968014,  0.02815747]),
#    'firstlevelcommunity': '10',
#    'secondlevelcommunity': '3'}),
#  (u'349',
#   {'embedding': array([ 0.22257937, -0.1754796 ,  0.31140969, -0.32541311, -0.08101421,
#            0.19700912, -0.13936496,  0.22032871,  0.05705019, -0.08219882,
#           -0.05658281,  0.16951991, -0.06563739,  0.21928421, -0.10283364,
#            0.05625585, -0.10037746,  0.36853454,  0.10857624, -0.01904001,
#            0.21615293,  0.10515444,  0.13006591, -0.08400911, -0.15141221,
#            0.20437626,  0.1190438 , -0.18048683, -0.16025982, -0.00400912,
#           -0.08657994,  0.09125469, -0.05785377,  0.16370207,  0.12212425,
#            0.24120849,  0.02720362,  0.05899525,  0.04579412]),
#    'firstlevelcommunity': '12',
#    'secondlevelcommunity': '3'}),
#  (u'298',
#   {'embedding': array([-0.2039211 ,  0.34638822,  0.21381569,  0.11974408, -0.11749444,
#            0.01623875,  0.21800685,  0.1209619 , -0.01924405, -0.07206845,
#           -0.53111705, -0.07555325,  0.1026602 , -0.08683242, -0.30343273,
#           -0.32367983, -0.07550718,  0.15291627, -0.01396879, -0.0482572 ,
#           -0.12463609,  0.16715863,  0.18866266,  0.15309051, -0.03437989,
#           -0.15771456, -0.03655288, -0.08894549, -0.20151219,  0.19828155,
#           -0.13110964,  0.11864031,  0.10033721, -0.10188687, -0.00618412,
#           -0.00878205, -0.05782167, -0.02228704,  0.06185079]),
#    'firstlevelcommunity': '11',
#    'secondlevelcommunity': '3'}),
#  (u'299',
#   {'embedding': array([ 0.3818633 , -0.08867935,  0.20112112, -0.23733174,  0.1861926 ,
#           -0.17326332,  0.11879116, -0.2945351 ,  0.03680789, -0.0741051 ,
#            0.16539571, -0.03124884, -0.02603025, -0.08851397,  0.3364013 ,
#            0.4019559 , -0.1396333 , -0.29385621,  0.05953245,  0.06592903,
#           -0.01821353,  0.04621572,  0.23590654,  0.09352492, -0.03077433,
#            0.05715226, -0.22429279,  0.03430363, -0.13003783, -0.07678714,
#           -0.19249773,  0.09864759,  0.03742902, -0.14923917, -0.04945421,
#            0.08973502, -0.10884111, -0.08705774, -0.07332696]),
#    'firstlevelcommunity': '11',
#    'secondlevelcommunity': '3'}),
#  (u'296',
#   {'embedding': array([ 0.31667806, -0.15876498,  0.25629883, -0.00980376,  0.1706098 ,
#           -0.10047575,  0.13555955, -0.2568816 ,  0.0317436 , -0.27554342,
#            0.10206442,  0.28760203, -0.02094384,  0.19587072,  0.26291827,
#            0.11950827, -0.06045654,  0.2900732 , -0.11578424, -0.00711719,
#           -0.20290921,  0.16066085, -0.02427946,  0.15914148,  0.04884466,
#           -0.09125777, -0.12904442,  0.17507911, -0.00521135,  0.07928987,
#           -0.05051648,  0.08252682, -0.22289656, -0.19552203, -0.13340619,
#            0.17353619,  0.20479748,  0.01341715, -0.02013855]),
#    'firstlevelcommunity': '10',
#    'secondlevelcommunity': '3'}),
#  (u'297',
#   {'embedding': array([ 0.25539845, -0.1668382 ,  0.38013756,  0.15536991, -0.02549769,
#           -0.18233194, -0.24293535, -0.0818743 ,  0.07612977,  0.25726897,
#           -0.09493295,  0.00752488, -0.25656903, -0.05125913, -0.05729154,
#            0.13565727, -0.19318582,  0.35648243,  0.03615464, -0.16949298,
#           -0.0300282 , -0.16395874,  0.08482002, -0.23285546,  0.27386953,
#            0.0442651 ,  0.30001475, -0.26061885,  0.17005755, -0.16044275,
#            0.17270832,  0.09853888,  0.16043944, -0.31199521, -0.03683272,
#            0.13257937, -0.12417719,  0.03609197, -0.02342987]),
#    'firstlevelcommunity': '12',
#    'secondlevelcommunity': '3'}),
#  (u'294',
#   {'embedding': array([ 0.38654877, -0.13021307,  0.16020634, -0.03145993,  0.05433921,
#            0.04809084, -0.23176954,  0.23812056,  0.14218778, -0.11840643,
#            0.04125137,  0.21537264, -0.12451443,  0.22974825,  0.04979999,
#           -0.22792962, -0.0333217 , -0.20224092,  0.05527579,  0.09183279,
#            0.04996795, -0.18144198,  0.19915747,  0.08082846,  0.250003  ,
#           -0.13680595, -0.07840376,  0.21586123, -0.01976052,  0.10910235,
#           -0.3406877 ,  0.04214262, -0.06137334, -0.10859126,  0.10959018,
#            0.07506558, -0.05057474, -0.09920623,  0.02409841]),
#    'firstlevelcommunity': '9',
#    'secondlevelcommunity': '3'}),
#  (u'295',
#   {'embedding': array([ 0.43406336, -0.20948072,  0.02347318,  0.08721503, -0.22513493,
#           -0.07776719, -0.03923205,  0.16639108,  0.12199975, -0.0275946 ,
#            0.09546761,  0.31476581,  0.20282619, -0.17948351, -0.2274246 ,
#            0.07153101, -0.0060686 ,  0.00486315, -0.10865047,  0.09505772,
#           -0.32338238,  0.10312605, -0.13903388,  0.32084928, -0.256953  ,
#           -0.11863534, -0.17441212, -0.1572743 , -0.08205196,  0.02560718,
#            0.02504713, -0.18089311, -0.09053479, -0.12612643, -0.11037528,
#            0.11469911, -0.07804661,  0.32384255,  0.03585952]),
#    'firstlevelcommunity': '9',
#    'secondlevelcommunity': '3'}),
#  (u'292',
#   {'embedding': array([ 0.21581511, -0.29592151,  0.27446039,  0.13951611, -0.16901983,
#           -0.13727182, -0.07021935,  0.05746342, -0.06359538,  0.16258959,
#            0.30688061,  0.12509773,  0.30670117,  0.04848099, -0.12708315,
#            0.11935013, -0.10436718, -0.03165357, -0.00818711, -0.05545515,
#            0.18103414, -0.03141902,  0.08279363,  0.08263288, -0.15743738,
#           -0.45466906,  0.20946162,  0.10938484,  0.10969157, -0.3188407 ,
#            0.00259286,  0.08727834,  0.18552316, -0.27343152,  0.08090788,
#           -0.17967889,  0.04881993,  0.03412301,  0.14523525]),
#    'firstlevelcommunity': '12',
#    'secondlevelcommunity': '3'}),
#  (u'293',
#   {'embedding': array([ 0.29238756, -0.20870371,  0.23352474, -0.13293596, -0.061373  ,
#            0.32827156, -0.24886726,  0.25573849,  0.15485077,  0.07518866,
#           -0.21897923,  0.00066518, -0.19135029, -0.05029718,  0.18290613,
#            0.01548876, -0.13617347, -0.12843616, -0.06854239, -0.1129066 ,
#           -0.07809752,  0.01257312,  0.02746154, -0.19297881, -0.07294876,
#           -0.24389328, -0.13464395, -0.00803903, -0.08663224,  0.25012604,
#            0.09762925,  0.1611982 , -0.1338452 , -0.08902108,  0.13957639,
#            0.24502528,  0.12729828, -0.030269  ,  0.23628042]),
#    'firstlevelcommunity': '12',
#    'secondlevelcommunity': '3'}),
#  (u'290',
#   {'embedding': array([ 0.42243826, -0.32999579,  0.01253197, -0.09057324, -0.01553768,
#            0.06133271, -0.31338159,  0.28867877,  0.10443706,  0.00844886,
#           -0.14936611,  0.14166184,  0.0897132 ,  0.12511098,  0.08639537,
#            0.11262007,  0.15786499,  0.24931834,  0.03967313, -0.19338516,
#           -0.26986749, -0.19098073, -0.0322045 , -0.15607688, -0.0488863 ,
#           -0.02696235,  0.02267894,  0.08999798, -0.12294944,  0.10637404,
#            0.2813757 , -0.1116229 ,  0.15678293, -0.01875998,  0.09118111,
#            0.15072108,  0.0413414 , -0.02706257, -0.01205522]),
#    'firstlevelcommunity': '9',
#    'secondlevelcommunity': '3'}),
#  (u'291',
#   {'embedding': array([ 0.29560266, -0.24411579,  0.08565991,  0.05412284, -0.37720157,
#           -0.16523849,  0.20611098,  0.15486454,  0.32381776,  0.01694643,
#           -0.07692832, -0.01669126,  0.0324927 , -0.05304976, -0.21744794,
#           -0.2978298 ,  0.03482073,  0.12311025, -0.01479684, -0.00141375,
#            0.13897052,  0.03927127, -0.18785878,  0.14627866,  0.25123509,
#           -0.00912642, -0.18381663,  0.0529954 , -0.02428214,  0.14231472,
#           -0.34133133, -0.08774426, -0.03609659,  0.28452168,  0.10258405,
#           -0.07284903, -0.00912119,  0.08608569, -0.18417291]),
#    'firstlevelcommunity': '10',
#    'secondlevelcommunity': '3'}),
#  (u'199',
#   {'embedding': array([ 0.37358558, -0.19647623,  0.17079538,  0.32646911,  0.08031515,
#           -0.27928917,  0.01527823,  0.08510116, -0.0410175 ,  0.39695495,
#           -0.13254703, -0.06704431, -0.15734468, -0.1472318 ,  0.05237804,
#            0.22179286, -0.07107439, -0.05105714,  0.02105394,  0.00991871,
#           -0.18516336,  0.0766455 , -0.04415941, -0.07508515,  0.01117435,
#            0.08283493,  0.05817374, -0.12154894,  0.03488544, -0.04457096,
#            0.07886424, -0.04898147, -0.08504645,  0.04392375, -0.23818728,
#            0.07612227,  0.08602046, -0.0541781 , -0.22113612]),
#    'firstlevelcommunity': '8',
#    'secondlevelcommunity': '2'}),
#  (u'198',
#   {'embedding': array([-0.17310846,  0.32849494,  0.17360334, -0.08425232,  0.04755104,
#            0.1570747 ,  0.23424165,  0.08542405, -0.06288008, -0.12175094,
#           -0.36861614,  0.01642007,  0.04303782,  0.1686335 , -0.11833899,
#           -0.10075144,  0.08305224,  0.23293082,  0.0335421 ,  0.18445618,
#            0.09692457, -0.01532022, -0.25716186,  0.21143484, -0.15448892,
#           -0.03908416,  0.06917144, -0.09925564, -0.00067081, -0.0978424 ,
#            0.06056721,  0.16995395, -0.15631903,  0.15924999, -0.07693802,
#           -0.01086475, -0.01804003,  0.04252221, -0.19290461]),
#    'firstlevelcommunity': '7',
#    'secondlevelcommunity': '2'}),
#  (u'195',
#   {'embedding': array([-0.31538251,  0.09420033,  0.38772515,  0.0023852 ,  0.09664012,
#           -0.04425283, -0.0732151 ,  0.05421337, -0.06168992,  0.19159938,
#            0.187772  ,  0.11105517, -0.02392111, -0.13914909,  0.13078295,
#           -0.18253012, -0.02602744, -0.10188943,  0.08635279,  0.14579348,
#            0.06984886, -0.25387092,  0.05523002, -0.17221531, -0.22297547,
#           -0.1237885 ,  0.11494003,  0.03311188,  0.04063807,  0.15050172,
#           -0.14177405,  0.124959  , -0.00445892,  0.10027198,  0.2288769 ,
#            0.1512867 , -0.07788958,  0.13455025,  0.01428561]),
#    'firstlevelcommunity': '6',
#    'secondlevelcommunity': '2'}),
#  (u'194',
#   {'embedding': array([ -2.98961490e-01,   1.88326752e-01,   2.17482209e-01,
#             1.77513545e-01,   2.29962041e-01,   5.36722974e-03,
#            -2.88609727e-01,  -2.21479182e-01,   2.33953468e-02,
#            -3.30651900e-01,   1.60577870e-01,  -7.97303161e-02,
#            -1.83822584e-01,   7.11340054e-02,  -8.35513957e-02,
#             1.41976868e-01,  -2.49483423e-01,  -1.41866589e-01,
#             8.78723655e-02,   1.08218297e-01,   2.13931870e-04,
#             9.28334585e-02,  -1.07539095e-02,   1.07895971e-01,
#            -1.34680676e-01,  -2.34501788e-01,  -3.44566112e-02,
#            -1.15426281e-01,  -9.23055280e-02,   1.38387841e-01,
#             1.16842339e-01,   7.33791676e-02,  -1.75162973e-04,
#             3.50662571e-02,  -2.14254678e-01,   1.05396989e-02,
#            -3.21340921e-01,   3.94725106e-02,  -1.11657389e-01]),
#    'firstlevelcommunity': '8',
#    'secondlevelcommunity': '2'}),
#  (u'197',
#   {'embedding': array([ -4.07452173e-01,   3.82160233e-01,   4.93054667e-02,
#            -1.46414140e-01,  -1.16036708e-01,  -2.67777421e-02,
#            -1.20112952e-02,   9.89495386e-02,  -1.90702449e-01,
#            -2.43301865e-01,  -2.77985876e-01,  -1.06099955e-01,
#            -1.76992581e-01,  -2.63034028e-01,   4.51194154e-02,
#            -1.62149620e-01,   7.23964823e-02,  -1.04091202e-01,
#            -1.20654657e-02,  -2.49560860e-01,  -4.98722987e-02,
#             1.48060917e-01,  -1.32807853e-01,   1.51818837e-01,
#            -3.92371002e-02,  -2.29531296e-04,   8.22456964e-02,
#            -1.43688590e-02,  -1.21379032e-02,  -7.67886276e-02,
#            -1.74073103e-01,  -1.89339949e-01,  -3.21162278e-02,
#             2.32095541e-01,  -1.61422159e-01,   9.38984924e-02,
#             2.81789767e-01,   1.21269619e-01,  -5.46861600e-02]),
#    'firstlevelcommunity': '8',
#    'secondlevelcommunity': '2'}),
#  (u'196',
#   {'embedding': array([-0.30658944,  0.13222979,  0.24781231, -0.010983  , -0.17600733,
#           -0.04675645, -0.06708162,  0.0547956 , -0.1114702 , -0.31421426,
#           -0.27056446, -0.00598284,  0.07789467, -0.20797409, -0.12153997,
#           -0.02827885, -0.14350483, -0.10833944,  0.0456535 , -0.10615478,
#           -0.21758749,  0.11962215,  0.13624403,  0.06183662,  0.33483006,
#            0.05372073,  0.07824501,  0.1937564 , -0.1519776 , -0.06762982,
#           -0.04952042, -0.00972772,  0.14362106, -0.13831568,  0.01238676,
#           -0.19327803,  0.00235366,  0.31138899, -0.31694018]),
#    'firstlevelcommunity': '8',
#    'secondlevelcommunity': '2'}),
#  (u'191',
#   {'embedding': array([-0.21287134,  0.19656951,  0.27623876, -0.31123712, -0.08261587,
#           -0.00709958, -0.08975672, -0.10730507, -0.25308855, -0.11108537,
#           -0.37818273,  0.14916048,  0.24284872, -0.13986741,  0.04745582,
#            0.27524079, -0.01307282,  0.05065784, -0.08131953,  0.03383291,
#           -0.00559059,  0.2019265 , -0.05686537, -0.02942003, -0.1059694 ,
#            0.14548004,  0.13927382,  0.35142755, -0.03424026, -0.14361125,
#            0.11060623,  0.26144223, -0.07674792,  0.06040649, -0.05159489,
#            0.09724057, -0.13552215,  0.15626482, -0.07178558]),
#    'firstlevelcommunity': '6',
#    'secondlevelcommunity': '2'}),
#  (u'190',
#   {'embedding': array([-0.07567983,  0.19446383,  0.39977037,  0.3512246 ,  0.0626451 ,
#           -0.06635716, -0.24698683,  0.19087444,  0.09083002, -0.23555056,
#           -0.13136865, -0.09275327,  0.02513654,  0.00388294, -0.11068142,
#            0.1264191 ,  0.05327969, -0.15481652, -0.24655764, -0.28187655,
#           -0.04373764,  0.28763558,  0.06449535,  0.04444947, -0.22953022,
#           -0.01371963,  0.03803998,  0.00934651,  0.04361614,  0.21066304,
#           -0.05252464, -0.10473755, -0.05738698, -0.02349816, -0.08662328,
#            0.16218105,  0.31429532,  0.01895399,  0.28970899]),
#    'firstlevelcommunity': '7',
#    'secondlevelcommunity': '2'}),
#  (u'193',
#   {'embedding': array([-0.31258306,  0.21011196,  0.17719101, -0.09790511,  0.25809845,
#           -0.25482594,  0.02317026, -0.05733748, -0.13638985, -0.13154372,
#            0.35584824,  0.01932368,  0.11503281, -0.12650468,  0.03001729,
#           -0.18281215,  0.19150705,  0.03401189,  0.01301485, -0.3014078 ,
#            0.1930569 , -0.03662498, -0.10363837, -0.06510757, -0.01561819,
#           -0.24321741, -0.10974196, -0.10617616, -0.08286006,  0.22482593,
#           -0.00248785, -0.01561279, -0.13077943,  0.0795056 ,  0.11710128,
#            0.08558897, -0.17231733, -0.04360288, -0.08816614]),
#    'firstlevelcommunity': '8',
#    'secondlevelcommunity': '2'}),
#  (u'192',
#   {'embedding': array([-0.28081446,  0.09895119,  0.33249962, -0.06328026, -0.08662258,
#            0.2581761 , -0.03297537,  0.15620769, -0.07790773, -0.02996926,
#           -0.27226801, -0.09665254,  0.16036052, -0.19874542, -0.13618217,
#           -0.0170738 ,  0.11946185,  0.10470273, -0.03475969,  0.30636818,
#           -0.22775501, -0.08825539,  0.01415672, -0.01934007,  0.08570681,
#           -0.01845595,  0.21894214, -0.04789135, -0.30104721,  0.30738467,
#            0.03271279, -0.06754179, -0.22389819, -0.07010686, -0.05916245,
#           -0.19522478,  0.08809788, -0.24075199, -0.06652335]),
#    'firstlevelcommunity': '5',
#    'secondlevelcommunity': '2'}),
#  (u'270',
#   {'embedding': array([-0.30740834,  0.29253917,  0.15157022, -0.20765249, -0.18280208,
#            0.02092   ,  0.27813215,  0.08665986,  0.28758831,  0.05301503,
#            0.26060846, -0.07237705, -0.02135005,  0.14167025, -0.0566887 ,
#            0.23586066, -0.03820523, -0.09738578,  0.05637931,  0.32617269,
#            0.03125827,  0.05899428, -0.09494901, -0.12230043, -0.09564739,
#           -0.09464798,  0.23156377,  0.34109573, -0.07528231,  0.23647729,
#            0.04936079, -0.03723672, -0.19976054, -0.1676095 ,  0.14150386,
#            0.05010637,  0.13346882, -0.36417941,  0.05066879]),
#    'firstlevelcommunity': '11',
#    'secondlevelcommunity': '3'}),
#  (u'271',
#   {'embedding': array([ 0.2830124 , -0.33473172,  0.10514809, -0.22674944,  0.36056436,
#           -0.12951129,  0.14950225,  0.06655406, -0.0123317 , -0.16287012,
#            0.14827528, -0.16841302,  0.1485105 , -0.0006438 , -0.08850585,
#           -0.07342529,  0.05291003,  0.03965377, -0.4674358 ,  0.17377483,
#           -0.31307583, -0.0135714 ,  0.06406157,  0.15142786, -0.11111911,
#            0.02833754,  0.14386741,  0.08069196, -0.29821019, -0.12462688,
#           -0.07469588, -0.26143454, -0.2122279 ,  0.13951821,  0.04508274,
#           -0.08591213,  0.05204774,  0.09209255, -0.05841952]),
#    'firstlevelcommunity': '9',
#    'secondlevelcommunity': '3'}),
#  (u'272',
#   {'embedding': array([ 0.30532135, -0.19125281,  0.21264059, -0.11859659, -0.40697012,
#           -0.08201336,  0.11614015,  0.06338031,  0.00402454,  0.15093994,
#           -0.00669796, -0.06381259,  0.4076992 , -0.14985132,  0.03106766,
#            0.05348746, -0.00162827, -0.02365114, -0.0816547 ,  0.05560671,
#            0.07997039, -0.0535875 , -0.31526536,  0.05624204,  0.21100133,
#            0.15446024, -0.00583498,  0.19156156, -0.03434203,  0.22451465,
#           -0.12588769,  0.00742291,  0.12811867, -0.05055824, -0.24229572,
#            0.08963143, -0.23528665, -0.09687135,  0.37458082]),
#    'firstlevelcommunity': '12',
#    'secondlevelcommunity': '3'}),
#  (u'273',
#   {'embedding': array([ 0.29076101, -0.19938399,  0.31253147, -0.1416285 ,  0.22037264,
#            0.09753869, -0.15376861,  0.13031137, -0.06024277,  0.02017775,
#            0.22388589,  0.09666648, -0.33748453,  0.09528881, -0.03297522,
#           -0.04271625,  0.15692214,  0.11773164, -0.01485017,  0.27509616,
#            0.07794822, -0.18729314,  0.23872993, -0.08155771, -0.20782796,
#            0.33353795,  0.02884721,  0.13393894,  0.12873448,  0.08482861,
#           -0.13611056, -0.13714958,  0.14598498,  0.22916583,  0.06346266,
#           -0.01619081, -0.01825131,  0.26733348,  0.00459076]),
#    'firstlevelcommunity': '10',
#    'secondlevelcommunity': '3'}),
#  (u'274',
#   {'embedding': array([ 0.49919195, -0.04377287,  0.07973335,  0.19177234,  0.15418285,
#           -0.21254603,  0.21529468, -0.05933709, -0.07514084,  0.24064175,
#           -0.10409922, -0.07346154, -0.22662866, -0.04226506,  0.17477952,
#           -0.10966659,  0.00842398, -0.17862096, -0.12297934,  0.11117754,
#           -0.10336544, -0.14487799,  0.01846962, -0.04432627,  0.05569101,
#           -0.09229944,  0.35698874, -0.01060963,  0.26095004, -0.05162921,
#            0.02242511, -0.02513924, -0.10084569, -0.09350361, -0.04194823,
#           -0.12148263,  0.0288299 , -0.01388795, -0.20847085]),
#    'firstlevelcommunity': '10',
#    'secondlevelcommunity': '3'}),
#  (u'275',
#   {'embedding': array([ 0.32250769, -0.19779107,  0.20698838,  0.22877944,  0.07222608,
#           -0.00509945,  0.05251653, -0.04322857,  0.27656721,  0.1194554 ,
#           -0.01969038, -0.27380134, -0.36197199, -0.11330777,  0.02959256,
#           -0.05138016, -0.20419037, -0.09028396,  0.07991637,  0.09271108,
#            0.28474521, -0.1462499 , -0.0152383 , -0.06989797,  0.01752509,
#           -0.27361072, -0.10441388,  0.2403297 , -0.01541449,  0.22346065,
#            0.07992923, -0.12054047, -0.05395774,  0.33894933, -0.08465811,
#            0.02379464,  0.10574949,  0.05259189, -0.03095207]),
#    'firstlevelcommunity': '12',
#    'secondlevelcommunity': '3'}),
#  (u'276',
#   {'embedding': array([ 0.21953794, -0.22186893,  0.47786444, -0.31162287,  0.04310204,
#           -0.05082094, -0.19923781,  0.22294268,  0.05081764,  0.09381725,
#           -0.05962156, -0.16451671, -0.18591161,  0.20583882,  0.10539631,
#            0.01209805,  0.29109668, -0.00261565,  0.09265133, -0.36054168,
#           -0.0103755 , -0.20293845,  0.03906967, -0.25804307, -0.08755037,
#           -0.03826789, -0.16124645, -0.11750211, -0.11314504, -0.04383716,
#            0.3405978 ,  0.01006652, -0.10790125,  0.00598266,  0.00102941,
#           -0.22118598,  0.12182431,  0.03526477, -0.03900912]),
#    'firstlevelcommunity': '9',
#    'secondlevelcommunity': '3'}),
#  (u'277',
#   {'embedding': array([ 0.45550644,  0.01540925,  0.26573679,  0.03706972, -0.3642796 ,
#           -0.06066617, -0.10052886,  0.08409214, -0.07516194,  0.03668107,
#            0.19124651,  0.12530224,  0.09135361,  0.04049392, -0.02225223,
#            0.11093688, -0.01565027, -0.27748256, -0.36972193,  0.03912372,
#            0.12813813, -0.06741061,  0.20019519, -0.03620241, -0.1566464 ,
#           -0.05818066,  0.00537723, -0.20925843,  0.10903645,  0.03455386,
#            0.1400636 ,  0.19281684, -0.1372665 , -0.10332869,  0.29084153,
#           -0.10272734,  0.1044515 ,  0.00857238, -0.09904963]),
#    'firstlevelcommunity': '9',
#    'secondlevelcommunity': '3'}),
#  (u'278',
#   {'embedding': array([ 0.30834206, -0.19526238,  0.27645469,  0.23095299, -0.33397892,
#           -0.06466335,  0.03786294,  0.09675526,  0.16891024, -0.08921255,
#            0.15231022,  0.13225883,  0.26589189,  0.01145022, -0.07118494,
#            0.1690011 , -0.0436799 , -0.14114877,  0.09684149,  0.07436623,
#            0.02262744,  0.07126419,  0.38664938,  0.00137801,  0.04382145,
#           -0.10788002,  0.02788363,  0.00400863,  0.033316  , -0.2688666 ,
#           -0.16004326, -0.01446869, -0.17111084,  0.15917303, -0.18322623,
#            0.13740588, -0.14151949, -0.02440212, -0.23737797]),
#    'firstlevelcommunity': '11',
#    'secondlevelcommunity': '3'}),
#  (u'279',
#   {'embedding': array([ 0.21026422, -0.39965157,  0.15760182, -0.03232236,  0.11794952,
#           -0.19211758,  0.29466159, -0.38481038, -0.26364187, -0.12241411,
#            0.03875037, -0.21614654,  0.08709395,  0.09796309,  0.1418595 ,
#           -0.29309098, -0.04411416,  0.0050084 , -0.08769958,  0.06283878,
#           -0.07748378, -0.11006526,  0.03336253,  0.02692973, -0.00704558,
#            0.13856963,  0.03711336, -0.23273258,  0.29439182,  0.08514927,
#            0.08276843,  0.10959913, -0.22524698, -0.04313308, -0.10986378,
#            0.31425047,  0.18732018, -0.2327477 , -0.33340941]),
#    'firstlevelcommunity': '10',
#    'secondlevelcommunity': '3'}),
#  (u'449',
#   {'embedding': array([ 0.42797543, -0.09734781,  0.125767  ,  0.43200063,  0.11020349,
#            0.09409276,  0.28010886, -0.14795127, -0.0578633 ,  0.20846408,
#           -0.00177969, -0.02965474, -0.05384115, -0.06645292,  0.04289719,
#            0.00092097,  0.14287839, -0.05371906,  0.06430705, -0.0644903 ,
#            0.02836398, -0.02460585, -0.14629452,  0.00869367, -0.27748946,
#           -0.01727974,  0.14100679, -0.00520783,  0.11996993,  0.15274761,
#           -0.21060935,  0.09905658,  0.05713751,  0.00694604,  0.03850986,
#           -0.34826317, -0.11080991, -0.11720012, -0.03085114]),
#    'firstlevelcommunity': '16',
#    'secondlevelcommunity': '4'}),
#  (u'448',
#   {'embedding': array([ 0.33674998,  0.20520442, -0.25649508,  0.06576394, -0.01302901,
#            0.3637194 ,  0.21771153,  0.06319341, -0.13592253, -0.04397606,
#            0.06572679, -0.27616481,  0.0472783 , -0.11254424, -0.15469587,
#           -0.00085611,  0.16403984, -0.1195777 , -0.02712988,  0.01983769,
#           -0.23748045, -0.23268102,  0.05120838,  0.11338112,  0.11060392,
#            0.0444619 , -0.25672221,  0.04506801,  0.05303186,  0.00931772,
#            0.04820035, -0.0568672 ,  0.11083353,  0.00977396,  0.06056981,
#            0.11131927, -0.09800295, -0.02650734, -0.02311631]),
#    'firstlevelcommunity': '14',
#    'secondlevelcommunity': '4'}),
#  (u'443',
#   {'embedding': array([ 0.24935218,  0.20983014, -0.33061439,  0.22401084,  0.1966675 ,
#           -0.17331369, -0.34453429, -0.30762363, -0.08839327,  0.12574019,
#           -0.15513847,  0.06469395, -0.13650327,  0.03889045, -0.1605192 ,
#            0.03123484, -0.039652  , -0.20315495, -0.17690233, -0.10668261,
#            0.10342072, -0.01941711,  0.12210757,  0.07463592, -0.22331439,
#           -0.07018092,  0.16276569, -0.04187294,  0.30129886,  0.09295345,
#           -0.23698535, -0.08935165, -0.25304988,  0.16301075, -0.16800103,
#           -0.12577748, -0.0076073 ,  0.01899187, -0.07146029]),
#    'firstlevelcommunity': '16',
#    'secondlevelcommunity': '4'}),
#  (u'442',
#   {'embedding': array([ 0.21269932,  0.14062555, -0.33704339, -0.01508474,  0.30209378,
#            0.0164727 ,  0.22376219,  0.36517546,  0.00794292,  0.0247837 ,
#           -0.01053505, -0.19091686, -0.03956052, -0.24026818, -0.07716277,
#            0.1142616 , -0.033264  , -0.19023839,  0.00406477, -0.0552577 ,
#            0.03725767, -0.10483093, -0.13303607, -0.28753807, -0.1487784 ,
#           -0.12781477, -0.02322208, -0.09085981,  0.03641006,  0.22063192,
#            0.08982166,  0.34048617,  0.08396734, -0.0263763 , -0.26958742,
#           -0.23576918, -0.03899605, -0.22096377, -0.08895096]),
#    'firstlevelcommunity': '13',
#    'secondlevelcommunity': '4'}),
#  (u'441',
#   {'embedding': array([ 0.13141095,  0.17412806, -0.38528208, -0.0577358 , -0.30547102,
#            0.16417542,  0.06112544,  0.02153155,  0.18667818, -0.06410577,
#            0.18454591,  0.14552135, -0.10882721, -0.25067905,  0.02714208,
#           -0.15377682,  0.15189255, -0.17896796, -0.25736204,  0.13220935,
#           -0.06388596,  0.23729032, -0.20538291, -0.18073398, -0.20678094,
#           -0.11836859,  0.11172123,  0.03026774, -0.00433131, -0.02836207,
#           -0.23487375,  0.02207105, -0.04171718, -0.17791558,  0.0082753 ,
#            0.18001102, -0.00428901, -0.2375006 , -0.03485493]),
#    'firstlevelcommunity': '15',
#    'secondlevelcommunity': '4'}),
#  (u'440',
#   {'embedding': array([ 0.0762372 ,  0.36083175, -0.27506752,  0.11729113, -0.14438245,
#           -0.31941886, -0.0456394 ,  0.01764221,  0.08542586,  0.02928347,
#           -0.1992947 , -0.11871303,  0.24111612,  0.20799011,  0.18418395,
#           -0.00943397,  0.05790128, -0.3175165 ,  0.00744847, -0.04113912,
#            0.14865234, -0.04502835,  0.09305931,  0.17780355,  0.31725226,
#           -0.07329165,  0.16690584,  0.06827151,  0.06446473,  0.01932138,
#           -0.00618085,  0.05154374,  0.25259769, -0.0878251 , -0.15686438,
#            0.11243625,  0.15922402,  0.3119751 , -0.23610026]),
#    'firstlevelcommunity': '13',
#    'secondlevelcommunity': '4'}),
#  (u'447',
#   {'embedding': array([ 0.26222649,  0.19909241, -0.34679479, -0.18914328, -0.26810623,
#            0.34927017,  0.1352536 , -0.06719962,  0.02795727, -0.07960341,
#           -0.17887322,  0.15822369, -0.12615648, -0.03784847,  0.25638832,
#            0.00874037,  0.20754412, -0.13410616,  0.02869202,  0.15933243,
#           -0.05555285, -0.12304084,  0.09204947, -0.04472411, -0.04425328,
#           -0.10853234, -0.01436171,  0.2129154 , -0.08843409,  0.02113569,
#            0.2845017 , -0.13387538, -0.05433579, -0.14726739, -0.16626857,
#            0.06701485,  0.24994829, -0.09003037, -0.08729756]),
#    'firstlevelcommunity': '15',
#    'secondlevelcommunity': '4'}),
#  (u'446',
#   {'embedding': array([ 0.0393472 ,  0.21050285, -0.34760301,  0.33477178, -0.23363704,
#           -0.17253813, -0.08353872,  0.18960949,  0.09941724,  0.17027377,
#            0.12620822, -0.1007901 ,  0.1644314 , -0.01394598, -0.00342103,
#           -0.07900232, -0.02285772, -0.04612786,  0.08687959,  0.15864816,
#            0.08310489,  0.28991977,  0.26827964,  0.06291673, -0.25314657,
#            0.02398211, -0.04379613,  0.02321705, -0.08899446,  0.02648333,
#            0.17999491, -0.29853851, -0.05961676,  0.0396096 , -0.14447289,
#           -0.06437025, -0.03885845,  0.08724348,  0.26736261]),
#    'firstlevelcommunity': '14',
#    'secondlevelcommunity': '4'}),
#  (u'445',
#   {'embedding': array([ 0.09050828,  0.17201441, -0.46567113, -0.1040611 ,  0.17525447,
#           -0.1951959 , -0.18093016, -0.22550225,  0.17642886,  0.18617504,
#           -0.02969895,  0.14708261,  0.27254735, -0.00355462, -0.29167558,
#            0.25475549,  0.28279482, -0.276046  , -0.05257654, -0.05416481,
#            0.12556594, -0.23668398, -0.01838797, -0.04948731,  0.13440743,
#            0.26221749,  0.23578737, -0.10426192, -0.1196224 ,  0.00712752,
#           -0.01208292,  0.11783771,  0.13491783, -0.07685905,  0.12474687,
#           -0.06400598,  0.14432985, -0.17322097,  0.0509397 ]),
#    'firstlevelcommunity': '14',
#    'secondlevelcommunity': '4'}),
#  (u'444',
#   {'embedding': array([ 0.13534547,  0.16587684, -0.43933024, -0.08110149,  0.35726348,
#           -0.08598926, -0.08262498, -0.31061937, -0.15510027,  0.19865212,
#            0.0670334 ,  0.13493131, -0.15927599,  0.0306494 ,  0.01027036,
#            0.08542023, -0.0951997 , -0.16495048, -0.20001325,  0.10025404,
#           -0.03863017, -0.16077624,  0.09336181,  0.09175136,  0.19576387,
#           -0.04648778,  0.17996519, -0.22219978, -0.26720322, -0.15370944,
#           -0.13447699, -0.07600364, -0.23162774,  0.10721709,  0.00056148,
#            0.24006827, -0.25747972,  0.09135452,  0.16184036]),
#    'firstlevelcommunity': '16',
#    'secondlevelcommunity': '4'}),
#  (u'108',
#   {'embedding': array([ 0.31293629,  0.13664198, -0.27274906,  0.02295021,  0.22490766,
#            0.13615385,  0.13197745,  0.17002505, -0.09353305,  0.11225088,
#            0.10210686, -0.29964887, -0.09604312,  0.0168655 , -0.15015906,
#            0.05986032,  0.19280004,  0.05112364,  0.2830981 ,  0.17029835,
#           -0.13070272, -0.16969282, -0.17312763, -0.08795206, -0.1580917 ,
#            0.00722811, -0.06437167,  0.15677919,  0.09057484,  0.05385823,
#            0.17703511,  0.04335389,  0.11242955, -0.20565529,  0.06171651,
#            0.10955357,  0.165011  , -0.28092257, -0.05283842]),
#    'firstlevelcommunity': '2',
#    'secondlevelcommunity': '1'}),
#  (u'109',
#   {'embedding': array([-0.30090893, -0.31601143, -0.02530601, -0.07155212,  0.05728739,
#           -0.21309275, -0.19422377,  0.07138024, -0.20976365, -0.20940772,
#           -0.09521155, -0.24394246, -0.41088226,  0.02742463, -0.04139072,
#           -0.08736087, -0.06155926, -0.05774529, -0.06656615,  0.01790317,
#           -0.01311234,  0.01570153, -0.16862492,  0.09873638, -0.0189023 ,
#            0.2787901 ,  0.2078799 , -0.06838675, -0.06781768,  0.02240465,
#            0.00231154, -0.00082358,  0.21418078,  0.06725605,  0.1609478 ,
#            0.14120246, -0.05457038, -0.07888907, -0.22745579]),
#    'firstlevelcommunity': '4',
#    'secondlevelcommunity': '1'}),
#  (u'102',
#   {'embedding': array([-0.17979042, -0.40111832, -0.09886387, -0.1782031 , -0.24978367,
#            0.32931191,  0.13872945, -0.2550222 , -0.023829  , -0.01072592,
#            0.17702282, -0.0902511 , -0.1809791 , -0.03609538, -0.11110709,
#            0.04982381, -0.17627696, -0.06834659,  0.35706128,  0.10387582,
#            0.14375992,  0.24969246, -0.02384102,  0.17924461,  0.00894404,
#            0.32574826,  0.06629475,  0.12357558, -0.08849257,  0.07628308,
#            0.03070285,  0.0071988 ,  0.05776496,  0.005519  , -0.05859147,
#            0.0028014 , -0.02807869,  0.16288461, -0.05020156]),
#    'firstlevelcommunity': '1',
#    'secondlevelcommunity': '1'}),
#  (u'103',
#   {'embedding': array([-0.15841067, -0.31776651, -0.33266181,  0.26434269,  0.13502841,
#           -0.03510529, -0.31206992, -0.21228634,  0.01873144,  0.14924336,
#            0.10770709, -0.07431081,  0.30376612, -0.17339753,  0.12704342,
#            0.16760306,  0.05093517, -0.00945163, -0.03658878, -0.19226838,
#           -0.22311135, -0.14272144, -0.05213517,  0.15191141,  0.01132991,
#            0.13106081,  0.22688956, -0.27773928,  0.06238097,  0.22328959,
#           -0.05670205,  0.15373774,  0.05833939, -0.07361526,  0.07155829,
#           -0.22954691,  0.00441588, -0.04123927,  0.01914011]),
#    'firstlevelcommunity': '4',
#    'secondlevelcommunity': '1'}),
#  (u'100',
#   {'embedding': array([-0.11766618, -0.42623253, -0.21594995, -0.12767763, -0.29742316,
#            0.17094336, -0.03945527, -0.11590942, -0.13028151,  0.14383512,
#           -0.11494346, -0.08363927,  0.07852879,  0.0705543 ,  0.08078397,
#            0.09513934,  0.09390591,  0.05983467, -0.11865877,  0.36920363,
#            0.07950447, -0.06073094,  0.20044683,  0.00885275, -0.05588942,
#            0.07580009,  0.2421199 ,  0.17850411,  0.06782699, -0.16280755,
#            0.148029  ,  0.14634206,  0.10789465, -0.23923392, -0.04094621,
#            0.09511803, -0.1021958 ,  0.17415126, -0.05368179]),
#    'firstlevelcommunity': '4',
#    'secondlevelcommunity': '1'}),
#  (u'101',
#   {'embedding': array([-0.2336281 , -0.25187894, -0.34092745,  0.22243091, -0.23186607,
#            0.13065827,  0.25089806, -0.20804823, -0.08969823,  0.05888245,
#            0.0364865 , -0.05401149,  0.09910387,  0.13473734, -0.32675148,
#           -0.13723066, -0.08361491, -0.04292739, -0.28022773, -0.38943854,
#            0.0905371 , -0.13601845, -0.11443186,  0.05872276,  0.04439736,
#            0.1770137 , -0.2148835 ,  0.09774987,  0.00348165, -0.34117856,
#           -0.0938008 ,  0.06182889,  0.0573465 , -0.02496553, -0.14969542,
#           -0.13893933,  0.11187374, -0.01721616,  0.02672303]),
#    'firstlevelcommunity': '2',
#    'secondlevelcommunity': '1'}),
#  (u'106',
#   {'embedding': array([-0.22000273, -0.3292555 , -0.14039269, -0.30730685,  0.18001769,
#           -0.03419854, -0.01627842,  0.07481853, -0.02590394,  0.0041737 ,
#           -0.15104493,  0.02394955, -0.54041799,  0.08712007, -0.10083165,
#            0.13221841,  0.06321837, -0.21182506, -0.03565543,  0.08698375,
#            0.09456896, -0.04239061,  0.08590617,  0.29684386,  0.1404736 ,
#           -0.20124342,  0.08043685, -0.20147997,  0.07635098, -0.12113062,
#            0.06495074,  0.06121856, -0.44228012, -0.09135477,  0.01336203,
#            0.1553979 , -0.10865952, -0.00230866,  0.03864442]),
#    'firstlevelcommunity': '1',
#    'secondlevelcommunity': '1'}),
#  (u'107',
#   {'embedding': array([ -2.23284729e-01,  -3.91233321e-01,  -1.21607868e-01,
#            -7.12755748e-02,   1.60709813e-01,  -1.53480794e-01,
#            -3.31970356e-01,   8.71970628e-02,   3.27673722e-01,
#            -1.50854163e-01,   2.45881870e-01,  -1.72423749e-01,
#             4.10637799e-01,   5.12301613e-02,   6.54875221e-02,
#             5.19879062e-02,  -2.95430355e-01,  -1.19048519e-01,
#            -5.38480574e-02,  -3.91079033e-02,  -3.64428834e-03,
#             1.62602724e-01,   3.24996665e-02,  -5.80523738e-02,
#             3.81886302e-05,  -3.11277737e-02,   1.08565350e-01,
#             2.41505062e-01,   8.52193201e-02,  -7.20884627e-03,
#             1.05111815e-01,  -1.29279427e-01,   5.24874269e-02,
#             1.16968359e-01,   3.40263002e-02,  -1.45415562e-01,
#             2.65040596e-01,  -1.40689081e-02,   2.49250074e-02]),
#    'firstlevelcommunity': '4',
#    'secondlevelcommunity': '1'}),
#  (u'104',
#   {'embedding': array([-0.45139745, -0.13710503, -0.16782879,  0.21668034, -0.17379262,
#            0.29302329,  0.05299001, -0.29544533, -0.07678435,  0.05171837,
#           -0.09632912, -0.293015  , -0.01369234,  0.02998226, -0.10711865,
#            0.11498311, -0.02446304, -0.15031632, -0.0882107 , -0.08094973,
#           -0.01072822, -0.00401155, -0.10865885, -0.03400705, -0.05296108,
#            0.10620625,  0.31719492, -0.01117164,  0.19408028, -0.00621874,
#           -0.31216717,  0.0254221 ,  0.10142195, -0.0357101 ,  0.2305066 ,
#           -0.19233437,  0.06699758, -0.05255778, -0.11143357]),
#    'firstlevelcommunity': '2',
#    'secondlevelcommunity': '1'}),
#  (u'105',
#   {'embedding': array([-0.23936513, -0.17069684, -0.24244779, -0.03423472,  0.12005651,
#           -0.08217506,  0.11515268,  0.13698221, -0.19363452,  0.03422863,
#           -0.12221823, -0.1620424 , -0.3392322 , -0.14616495, -0.29738598,
#            0.12050137,  0.00403122,  0.03272193, -0.08970982, -0.23626017,
#            0.05442034,  0.17848135, -0.08825628,  0.13300463,  0.20548634,
#           -0.03159108, -0.02358424, -0.03558504,  0.0219961 , -0.07053329,
#            0.06293583,  0.00194945, -0.15478971, -0.40514527,  0.06067373,
#           -0.13742769, -0.09889504,  0.03298242,  0.01509526]),
#    'firstlevelcommunity': '4',
#    'secondlevelcommunity': '1'}),
#  (u'39',
#   {'embedding': array([-0.17375767, -0.33179422, -0.2094861 , -0.04398077, -0.31261524,
#            0.4206864 ,  0.09060753, -0.13227373, -0.09727652,  0.00650091,
#            0.1154995 , -0.01965529, -0.13692425, -0.05875659,  0.09790329,
#            0.08772233,  0.00149465, -0.34737217,  0.0529806 , -0.04870356,
#           -0.05653502, -0.0018102 , -0.07432149, -0.24980423, -0.05587531,
#           -0.0959638 ,  0.13313178,  0.01116306,  0.02012234,  0.20209772,
#            0.16929603, -0.37365593, -0.01759076, -0.06043755,  0.11888995,
#            0.18070246, -0.09781889, -0.03328158,  0.12048067]),
#    'firstlevelcommunity': '1',
#    'secondlevelcommunity': '1'}),
#  (u'38',
#   {'embedding': array([-0.1666699 , -0.4015324 , -0.07921206,  0.13181055, -0.08252441,
#           -0.08063561, -0.3301074 ,  0.20680554,  0.08000479,  0.19731746,
#           -0.10926498, -0.0708288 ,  0.10387317,  0.00586758,  0.18257488,
#           -0.0204617 ,  0.11056542, -0.0776619 ,  0.0351511 , -0.00290528,
#           -0.2282265 , -0.23787131, -0.09618752,  0.04002129, -0.01555732,
#           -0.27645344,  0.03280679,  0.15178556, -0.16351472, -0.11413714,
#            0.04557158,  0.15496647,  0.13092302, -0.03280843,  0.0780421 ,
#            0.02673873,  0.00281232, -0.10533604, -0.08296679]),
#    'firstlevelcommunity': '4',
#    'secondlevelcommunity': '1'}),
#  (u'33',
#   {'embedding': array([-0.25242733, -0.19771639, -0.28367003,  0.01577953, -0.55667364,
#            0.22351876,  0.12627115, -0.13501475, -0.2056153 ,  0.12548606,
#            0.09197135, -0.04911573, -0.15884843,  0.15060664, -0.06221846,
#            0.16707322, -0.07562397,  0.12015796, -0.03635269, -0.08365258,
#            0.01865731, -0.02589954, -0.0241732 ,  0.08779447, -0.19107511,
#           -0.100681  ,  0.00377291, -0.22810259,  0.04865981, -0.16320051,
#           -0.40104888,  0.00436651,  0.05002047, -0.06502442,  0.04631636,
#           -0.09374538, -0.01194894, -0.02125197,  0.03354022]),
#    'firstlevelcommunity': '1',
#    'secondlevelcommunity': '1'}),
#  (u'32',
#   {'embedding': array([-0.15071508, -0.4404154 , -0.06846752,  0.17716652,  0.02195571,
#           -0.00885415, -0.3799395 , -0.11353024,  0.02355232,  0.38343735,
#            0.04224625,  0.09485695,  0.00563671, -0.30911565, -0.11819931,
#            0.00939089, -0.01477315, -0.23912642, -0.06765761,  0.10270656,
#           -0.27022243,  0.06625981, -0.06605019,  0.31211751,  0.00226194,
#            0.11517422, -0.17313124, -0.09224527, -0.13653735,  0.04773719,
#            0.01155404,  0.10108448, -0.14550746,  0.02713168,  0.06506511,
#            0.12620192, -0.05932076,  0.25501994, -0.06483664]),
#    'firstlevelcommunity': '4',
#    'secondlevelcommunity': '1'}),
#  (u'31',
#   {'embedding': array([-0.12740986, -0.25962459, -0.28492076, -0.1176328 , -0.25689096,
#            0.27243664, -0.09137054, -0.04272653, -0.15222389,  0.10730017,
#           -0.15977746, -0.08406077,  0.00976914, -0.11587248,  0.08622398,
#            0.13094909,  0.0760062 ,  0.10955349,  0.02190955,  0.19200118,
#            0.19875785, -0.00352603,  0.02047533, -0.5336006 ,  0.05734385,
#            0.12173743,  0.06585519, -0.1589146 ,  0.12839302, -0.00081031,
#            0.07579502, -0.21025193,  0.00685288, -0.07905726, -0.1746565 ,
#            0.06352503,  0.1656823 ,  0.20830521, -0.16278532]),
#    'firstlevelcommunity': '3',
#    'secondlevelcommunity': '1'}),
#  (u'30',
#   {'embedding': array([-0.32445531, -0.14196794, -0.25066222,  0.32508114,  0.1283241 ,
#            0.19534205,  0.08599929,  0.16497431,  0.15515387,  0.01333189,
#           -0.02813877, -0.05759196, -0.00529365,  0.16346742, -0.00913577,
#           -0.11682124, -0.10516079, -0.1203829 ,  0.05970301, -0.23020323,
#            0.2895107 ,  0.11136967,  0.05894944, -0.04831403,  0.16476953,
#            0.03360337, -0.03299544, -0.39433114, -0.25731934, -0.0398295 ,
#            0.0143248 ,  0.12654681,  0.0106421 , -0.01732842,  0.20712342,
#            0.20141165, -0.01144678,  0.0496678 ,  0.24424308]),
#    'firstlevelcommunity': '4',
#    'secondlevelcommunity': '1'}),
#  (u'37',
#   {'embedding': array([-0.23034035, -0.35720561, -0.1545613 , -0.26880529, -0.06009511,
#            0.31997579,  0.10228542, -0.23156349, -0.14100336,  0.24648968,
#            0.11759039,  0.11051553,  0.03265695,  0.29387161,  0.04356521,
#           -0.05556643, -0.14456081,  0.17270641, -0.06038305,  0.16321023,
#            0.04796429,  0.05918717,  0.13884755,  0.05193271, -0.00422099,
#           -0.0228816 ,  0.17434945, -0.15596748, -0.03552192, -0.04034734,
#           -0.12471535,  0.0795498 ,  0.23596679, -0.10988161, -0.07718883,
#           -0.26097288, -0.01463712, -0.18427481,  0.15196978]),
#    'firstlevelcommunity': '1',
#    'secondlevelcommunity': '1'}),
#  (u'36',
#   {'embedding': array([-0.32137545, -0.29233272, -0.038712  ,  0.16420296,  0.11572207,
#            0.03971974, -0.42087836, -0.29003226,  0.0461914 , -0.03542537,
#            0.15346837, -0.1163595 ,  0.27983452, -0.42712335,  0.00427366,
#           -0.00272427,  0.14859208, -0.02136734,  0.28997432, -0.3071948 ,
#           -0.00364309,  0.07891197, -0.08645628,  0.04304628, -0.14450751,
#           -0.07089858, -0.14385584, -0.13717341, -0.05287861, -0.12566531,
#           -0.07345855,  0.218352  , -0.16153899, -0.16719057, -0.04965847,
#            0.09499921,  0.08081133,  0.09815296,  0.05760704]),
#    'firstlevelcommunity': '3',
#    'secondlevelcommunity': '1'}),
#  (u'35',
#   {'embedding': array([-0.22708555, -0.20691048, -0.12964155, -0.08636787,  0.08409763,
#            0.16849839,  0.29466026,  0.42255566,  0.16773701,  0.13003829,
#            0.08357508,  0.227235  , -0.14906933,  0.11890181, -0.11524486,
#            0.03561142, -0.02418989,  0.48872451, -0.04451027, -0.03340106,
#            0.10581157,  0.20134516, -0.03270591,  0.16025463, -0.18753765,
#            0.09200637, -0.12989799, -0.25691405,  0.17263963, -0.14241902,
#           -0.1037309 ,  0.08235552,  0.07022289,  0.08107779,  0.1295921 ,
#            0.03411568,  0.120698  ,  0.20075937, -0.05119157]),
#    'firstlevelcommunity': '4',
#    'secondlevelcommunity': '1'}),
#  (u'34',
# ...
#            -9.84161681e-02,   4.41375038e-01,   3.12707779e-02,
#             2.25472807e-01,  -2.62912682e-01,  -1.10845355e-01,
#             1.51806683e-01,   2.20551610e-02,   8.86525737e-02,
#            -4.56974398e-02,  -1.58330569e-02,  -1.13816348e-01,
#            -1.46351979e-01,   1.43707121e-01,   7.68291760e-02]),
#    'firstlevelcommunity': '3',
#    'secondlevelcommunity': '1'}),
#  (u'40',
#   {'embedding': array([-0.34342624, -0.18001378, -0.2861843 ,  0.07170963, -0.1758851 ,
#            0.31151291,  0.06818671, -0.16710531, -0.24073978,  0.11024229,
#            0.04862625, -0.00072646,  0.08924621, -0.08737795, -0.2453013 ,
#            0.10935525,  0.16345178,  0.39669824,  0.16602327,  0.36205695,
#           -0.07754711,  0.04743089,  0.245586  ,  0.02558789,  0.14279108,
#           -0.03475153,  0.1695323 ,  0.10653912, -0.17370639,  0.03307964,
#            0.08469876, -0.05418274, -0.1880543 , -0.06377123, -0.19552061,
#           -0.02249876, -0.04523089,  0.21315553, -0.0018409 ]),
#    'firstlevelcommunity': '4',
#    'secondlevelcommunity': '1'}),
#  (u'41',
#   {'embedding': array([-0.30018793, -0.37486679, -0.04766167,  0.06754218,  0.34965732,
#            0.05025731,  0.30031284,  0.10498837, -0.021996  , -0.03644254,
#            0.10087031,  0.07454296,  0.04822124,  0.16764263,  0.06352803,
#            0.15037354,  0.16386671, -0.00901674, -0.10397949,  0.16372571,
#            0.11061569,  0.0086669 , -0.09804729, -0.21177012, -0.28155759,
#            0.11549926, -0.00601669, -0.12429491,  0.11099035,  0.17856277,
#           -0.15874074, -0.08665922,  0.224401  ,  0.26606858,  0.23547991,
#           -0.32472906,  0.01243195,  0.1408449 ,  0.07097439]),
#    'firstlevelcommunity': '3',
#    'secondlevelcommunity': '1'}),
#  (u'5',
#   {'embedding': array([-0.3657052 , -0.20314888, -0.19123518, -0.00176973, -0.22249271,
#            0.15494594,  0.11868653, -0.15469362, -0.33073626,  0.10524713,
#           -0.01558533, -0.08909869, -0.17709416,  0.27976649, -0.04786295,
#            0.06054117, -0.15016203, -0.15034179, -0.20548754,  0.32697198,
#           -0.12669874, -0.21922802,  0.10388796,  0.18650731,  0.03938694,
#           -0.09949767,  0.26526477,  0.11755585, -0.07433489, -0.23828195,
#           -0.13730149,  0.04798067,  0.01262981,  0.12253092, -0.01198125,
#            0.11456224, -0.03084671, -0.14673535,  0.35537413]),
#    'firstlevelcommunity': '4',
#    'secondlevelcommunity': '1'}),
#  (u'489',
#   {'embedding': array([ 0.17394284,  0.21716896, -0.3092728 ,  0.24524688, -0.24638681,
#           -0.31702301,  0.03740455,  0.21385951,  0.09206874,  0.23104896,
#           -0.129371  , -0.11558292,  0.06359255,  0.22236909, -0.12351135,
#            0.0063883 , -0.3138914 ,  0.01833601,  0.06566829, -0.05675082,
#            0.09332103, -0.16161178, -0.12452933,  0.2252526 , -0.32529172,
#            0.06672212,  0.00278444, -0.10462069,  0.01171538,  0.03078768,
#           -0.15175989, -0.0029838 ,  0.02234744, -0.09597626, -0.29950812,
#           -0.12785874,  0.17761377,  0.08743991,  0.11922171]),
#    'firstlevelcommunity': '15',
#    'secondlevelcommunity': '4'}),
#  (u'488',
#   {'embedding': array([ 0.35565427,  0.10682286, -0.40603644, -0.01780591,  0.25321604,
#            0.15324966, -0.05868612, -0.29136357,  0.01483011, -0.04321565,
#           -0.12212276, -0.09474959,  0.03932704,  0.27751136, -0.16310575,
#           -0.08111367,  0.00836838, -0.3673267 , -0.20610662, -0.02871507,
#            0.1800148 , -0.04920589,  0.21465438, -0.33238349,  0.15543317,
#            0.14884671, -0.14996397,  0.07396877,  0.07824993, -0.10440558,
#           -0.06720159, -0.12765343,  0.04502236, -0.02838819,  0.1135873 ,
#           -0.07042921, -0.16112008,  0.10555084,  0.18309758]),
#    'firstlevelcommunity': '14',
#    'secondlevelcommunity': '4'}),
#  (u'487',
#   {'embedding': array([ 0.20153079,  0.18624244, -0.40984917,  0.06169379,  0.30980395,
#           -0.02911853,  0.00616056, -0.21424899,  0.00269466, -0.14653232,
#           -0.21032205,  0.0592219 ,  0.28155521,  0.17446148,  0.04851319,
#            0.09375568,  0.06183114,  0.27274711,  0.0995404 ,  0.10889238,
#           -0.06980321, -0.0858716 ,  0.07617814, -0.22996657,  0.06799052,
#           -0.01072681, -0.14056551, -0.03715895,  0.23680434,  0.20034843,
#            0.09543358, -0.24209245, -0.01097866, -0.0035295 , -0.27502238,
#            0.07094303, -0.03923016,  0.16052162,  0.02095309]),
#    'firstlevelcommunity': '14',
#    'secondlevelcommunity': '4'}),
#  (u'486',
#   {'embedding': array([ 0.21136299,  0.15314004, -0.31894256,  0.03370268, -0.16919512,
#           -0.45078309,  0.24918484,  0.11990639, -0.02204232, -0.13506767,
#           -0.19307214,  0.01616579,  0.01083952,  0.09254142, -0.02715229,
#            0.20839986, -0.05857532,  0.09628013, -0.06859971,  0.21275637,
#            0.25620557, -0.0191411 , -0.05792507,  0.03693152,  0.15921438,
#            0.01339255, -0.11615462, -0.37260084, -0.06215841, -0.10101696,
#            0.09267866, -0.16247177,  0.21592685,  0.19178262,  0.03392488,
#           -0.02866034,  0.01947427, -0.07648374,  0.11728766]),
#    'firstlevelcommunity': '15',
#    'secondlevelcommunity': '4'}),
#  (u'485',
#   {'embedding': array([-0.01098168,  0.29570197, -0.37364059, -0.17585712, -0.13315888,
#           -0.08489636, -0.02353763,  0.02707737,  0.18095764, -0.1512563 ,
#            0.12710674, -0.0132573 , -0.24234831, -0.37293169,  0.00670754,
#           -0.24114584, -0.00721145,  0.21786233, -0.02463474,  0.03193403,
#            0.16731764, -0.08918631, -0.23809197,  0.06546539,  0.06475399,
#            0.04846936,  0.00301602, -0.0720328 , -0.0092061 ,  0.02343584,
#           -0.20246892,  0.19300784,  0.09731004,  0.21904379, -0.06838379,
#           -0.18818868,  0.07627666,  0.29996014, -0.049446  ]),
#    'firstlevelcommunity': '13',
#    'secondlevelcommunity': '4'}),
#  (u'484',
#   {'embedding': array([ 0.19673916,  0.20132089, -0.2790175 , -0.01136627, -0.16293117,
#            0.17872131,  0.12064756, -0.29260063,  0.16233654, -0.04626373,
#            0.04495223,  0.14035074, -0.14779819, -0.23401067,  0.18050617,
#            0.05891709,  0.29286161, -0.2300162 ,  0.25879869,  0.16251705,
#            0.0330052 ,  0.30762674,  0.18349409,  0.04010245, -0.07691627,
#            0.09178612, -0.19777854,  0.15742238, -0.06843704, -0.10307777,
#           -0.08924245, -0.06959302,  0.04988655,  0.16796713,  0.14246597,
#           -0.07153169,  0.01194532,  0.18353921,  0.13962557]),
#    'firstlevelcommunity': '13',
#    'secondlevelcommunity': '4'}),
#  (u'483',
#   {'embedding': array([ 0.06026301,  0.42270357, -0.29856321, -0.04718019,  0.19225613,
#           -0.03416532, -0.03845241, -0.4418622 , -0.24217114, -0.01303229,
#           -0.09835169,  0.2186091 ,  0.1309359 ,  0.04214796, -0.07372928,
#            0.30422962,  0.0045837 ,  0.2549114 ,  0.03912077,  0.22950622,
#           -0.14054431,  0.29827696,  0.0135107 , -0.01052866,  0.09389616,
#           -0.00924467, -0.02565896,  0.11975946,  0.02063113,  0.18087195,
#           -0.08039992,  0.19793965, -0.29715574,  0.07719194, -0.1622878 ,
#            0.06691454,  0.10947978,  0.12976468,  0.04326218]),
#    'firstlevelcommunity': '14',
#    'secondlevelcommunity': '4'}),
#  (u'482',
#   {'embedding': array([ 0.17788709,  0.27944232, -0.2351405 , -0.12862868,  0.02754402,
#            0.06549513, -0.05593364,  0.36738101, -0.12493029,  0.04974021,
#            0.162259  , -0.19205821, -0.06104884, -0.20577319, -0.16964568,
#            0.27490624, -0.09535249, -0.15086707,  0.02921296,  0.20964807,
#            0.02569907,  0.00185965, -0.16665863,  0.07242031, -0.24645837,
#           -0.24242646,  0.04604266,  0.05369518,  0.05377345, -0.21742812,
#            0.00885538,  0.28230023, -0.00280587, -0.1231    ,  0.12509046,
#           -0.03052518,  0.15779515, -0.11597535,  0.04013352]),
#    'firstlevelcommunity': '16',
#    'secondlevelcommunity': '4'}),
#  (u'481',
#   {'embedding': array([ 0.11016966, -0.00631818, -0.5716416 ,  0.04208059,  0.32963118,
#           -0.28042591, -0.00244008, -0.12321446, -0.09475999,  0.06680365,
#           -0.06248127,  0.26270511,  0.03346611,  0.00841879, -0.0041752 ,
#           -0.03625567, -0.27347813,  0.274426  ,  0.02251306,  0.15739526,
#            0.05271695,  0.19511345, -0.04054237,  0.07109245, -0.07808552,
#           -0.06607992, -0.04845496, -0.07076924, -0.1482868 , -0.09802554,
#            0.04403312, -0.31433316, -0.02748331,  0.17321546,  0.09692451,
#            0.1857128 ,  0.2187593 ,  0.23601987, -0.09345951]),
#    'firstlevelcommunity': '14',
#    'secondlevelcommunity': '4'}),
#  (u'480',
#   {'embedding': array([-0.00158235,  0.21831367, -0.35038192,  0.02300302,  0.26982703,
#           -0.02323128,  0.10658839, -0.18598636, -0.22331693,  0.01088337,
#           -0.15233082,  0.1343143 , -0.07744491, -0.20137549, -0.25874535,
#           -0.07162318,  0.3010202 , -0.35100558,  0.04553591, -0.01761447,
#            0.03732388, -0.2127164 ,  0.07831575, -0.28072   ,  0.0554897 ,
#            0.16189649,  0.03120604,  0.18516394,  0.1187208 , -0.00609548,
#           -0.06071167, -0.13332567,  0.19091808,  0.2408949 ,  0.06068463,
#            0.09550889, -0.22368264,  0.03947905,  0.17859799]),
#    'firstlevelcommunity': '14',
#    'secondlevelcommunity': '4'}),
#  (u'472',
#   {'embedding': array([ 0.05242937,  0.18607257, -0.38860739, -0.11099715,  0.18526852,
#            0.07124364, -0.20572171,  0.02215791, -0.1890358 , -0.02395895,
#           -0.27935862,  0.18844864,  0.2368365 ,  0.09529045,  0.0809491 ,
#           -0.02302728, -0.07440083,  0.12227519,  0.04282551,  0.2544295 ,
#            0.02127413, -0.00162805, -0.05016558, -0.28693004, -0.16341268,
#           -0.00987042,  0.30410567, -0.12898744, -0.1800532 ,  0.12908433,
#           -0.18289199, -0.14999008,  0.12378348,  0.07984994,  0.08815015,
#           -0.27221008, -0.14380013, -0.06836178, -0.01417494]),
#    'firstlevelcommunity': '14',
#    'secondlevelcommunity': '4'}),
#  (u'473',
#   {'embedding': array([ 0.30649965,  0.41175923, -0.14412074, -0.11765559,  0.14846756,
#            0.158256  ,  0.02099282,  0.1927256 , -0.08542824,  0.22075584,
#            0.1075375 , -0.22166624,  0.26129372,  0.0980147 ,  0.18300764,
#            0.23516128, -0.16246893,  0.29421333, -0.11911006, -0.16631801,
#           -0.24383487,  0.03597014,  0.01578901,  0.07411511,  0.03627268,
#            0.04723263, -0.02259825,  0.05299336,  0.0627865 , -0.19665741,
#           -0.06838235, -0.05196485, -0.04810947,  0.16158086, -0.03141975,
#            0.14968736,  0.12495428, -0.03625309,  0.26913072]),
#    'firstlevelcommunity': '16',
#    'secondlevelcommunity': '4'}),
#  (u'470',
#   {'embedding': array([ 0.21527458,  0.22486627, -0.22066466, -0.17434524,  0.04677046,
#           -0.04394303,  0.08175617,  0.0091668 ,  0.2029528 , -0.0006072 ,
#            0.14236889,  0.28112339, -0.07670007, -0.21034789,  0.38834531,
#           -0.15390321, -0.13050134, -0.01272854,  0.02534105, -0.11299237,
#           -0.04200537, -0.03272264, -0.22960917, -0.10442601, -0.24983115,
#           -0.00095573,  0.14922629, -0.06944015,  0.02683339,  0.04335878,
#           -0.00226587,  0.31957658, -0.14120031,  0.10577877, -0.04927989,
#            0.32645033, -0.03177084,  0.05031753,  0.02614042]),
#    'firstlevelcommunity': '13',
#    'secondlevelcommunity': '4'}),
#  (u'471',
#   {'embedding': array([ 0.08700788,  0.22278875, -0.31681623, -0.07246481, -0.07580532,
#            0.09572138,  0.07741775,  0.1243238 ,  0.08602519, -0.16773757,
#            0.02440008,  0.11780304, -0.37857859, -0.10243137, -0.089645  ,
#           -0.37611249,  0.10072263,  0.00320069,  0.06114191, -0.10909655,
#           -0.23958275,  0.06582721,  0.05169246, -0.29537125,  0.12724665,
#            0.12275641,  0.2101004 , -0.05040177,  0.26230662, -0.19894866,
#           -0.00771835, -0.00790777,  0.04233508, -0.11048388, -0.15116471,
#           -0.02791004,  0.10953857,  0.04340007, -0.04044676]),
#    'firstlevelcommunity': '13',
#    'secondlevelcommunity': '4'}),
#  (u'476',
#   {'embedding': array([ 0.40101494,  0.25497583, -0.18410951,  0.11395267, -0.27223818,
#           -0.22528398, -0.1540173 ,  0.01362712, -0.2536064 , -0.08175466,
#            0.10535397, -0.03304221, -0.13296614,  0.28386763,  0.00625307,
#           -0.00445451, -0.03028135,  0.01276254, -0.09874246, -0.01010857,
#            0.0513285 , -0.28086485,  0.03984276, -0.13059553,  0.1262531 ,
#            0.29274869, -0.3640843 , -0.14709737,  0.01974596,  0.00803133,
#           -0.08512794,  0.29917425, -0.19077707, -0.13030291, -0.15080732,
#           -0.12195298, -0.03000922, -0.1595459 ,  0.01624348]),
#    'firstlevelcommunity': '15',
#    'secondlevelcommunity': '4'}),
#  (u'477',
#   {'embedding': array([-0.03602809,  0.26566221, -0.33389342,  0.12886831, -0.16792019,
#           -0.31642487, -0.0558004 ,  0.07258455, -0.11097965, -0.04706791,
#            0.05406134, -0.35726491, -0.01431708, -0.00864147,  0.20475457,
#            0.00624263,  0.22028208,  0.1188494 ,  0.03239168, -0.0057709 ,
#            0.13741302, -0.09620628,  0.03648977, -0.00352563, -0.17193353,
#           -0.07856401,  0.06514506, -0.10442997, -0.00783744, -0.05285793,
#           -0.33691194, -0.11747844, -0.04893661, -0.12468455,  0.01164371,
#           -0.06884353, -0.14332617, -0.15828611, -0.08093445]),
#    'firstlevelcommunity': '15',
#    'secondlevelcommunity': '4'}),
#  (u'474',
#   {'embedding': array([ 0.2000659 ,  0.20834983, -0.30251995, -0.11324189,  0.31541586,
#            0.26353951,  0.12376294,  0.26905266, -0.07124622,  0.01889069,
#           -0.00564917, -0.18054468,  0.07764734, -0.16896023, -0.04980854,
#            0.20017414,  0.09140781, -0.15416008, -0.03528469,  0.01579338,
#            0.32712639,  0.09511809, -0.03439882, -0.07753778,  0.12772323,
#           -0.30241796, -0.15750058, -0.05150077,  0.03078801, -0.01739831,
#            0.05026657,  0.2787301 , -0.03003198, -0.20715804, -0.16836814,
#           -0.13069685, -0.30197225,  0.01200459, -0.22845994]),
#    'firstlevelcommunity': '16',
#    'secondlevelcommunity': '4'}),
#  (u'475',
#   {'embedding': array([ 0.18027216,  0.20985233, -0.27739216, -0.03764121,  0.04528447,
#           -0.13815098,  0.17890668, -0.09432225,  0.22809272, -0.25927412,
#            0.21364992,  0.21868991, -0.11989873, -0.10939969,  0.02116023,
#           -0.0530879 , -0.09301202,  0.01357765,  0.11326678,  0.0031491 ,
#           -0.13248644, -0.30823122, -0.26780072,  0.56202433, -0.03954126,
#           -0.1616246 ,  0.02616342, -0.13316016,  0.12008339,  0.14286526,
#            0.15941181, -0.25593258,  0.08573634,  0.00892333, -0.0826305 ,
#           -0.03803898, -0.23758786,  0.07024573,  0.20761571]),
#    'firstlevelcommunity': '13',
#    'secondlevelcommunity': '4'}),
#  (u'478',
#   {'embedding': array([ 0.16002132,  0.20999769, -0.35654257,  0.03677727,  0.08736349,
#            0.02165174, -0.03972218, -0.34135116, -0.00139629,  0.05604408,
#           -0.15858641, -0.02391113,  0.15166286, -0.30794394, -0.19548152,
#            0.06852344, -0.3580569 ,  0.02086118,  0.20421945, -0.18302943,
#            0.23619546, -0.00475831,  0.12528935, -0.00617971, -0.21640736,
#           -0.06057927,  0.04476291, -0.11319543,  0.08442203,  0.10441486,
#            0.18452038, -0.02610935, -0.01683657, -0.24154737,  0.0303886 ,
#            0.14714782,  0.43007684,  0.26116586, -0.07098612]),
#    'firstlevelcommunity': '14',
#    'secondlevelcommunity': '4'}),
#  (u'479',
#   {'embedding': array([ 0.21104838,  0.27059833, -0.21820388,  0.21457953, -0.32998621,
#           -0.08871388, -0.30838382,  0.16479955, -0.1448469 , -0.03845713,
#           -0.06937838,  0.03867592,  0.09532546,  0.10546256,  0.2170939 ,
#           -0.09943592,  0.29004724,  0.02498774, -0.15051053,  0.11989912,
#            0.1479883 ,  0.03918171, -0.11820069, -0.39803008, -0.10549368,
#            0.10457162, -0.08274506,  0.11508706,  0.05510368, -0.04650115,
#            0.17485881, -0.17859594,  0.06336721, -0.15118172,  0.10273171,
#           -0.10700014, -0.03565671, -0.01419725, -0.1017658 ]),
#    'firstlevelcommunity': '15',
#    'secondlevelcommunity': '4'})]

# %%
## try http:// if https:// URLs are not supported
source("https://bioconductor.org/biocLite.R")
biocLite()
biocLite("ALL")
biocLite("topGO")
biocLite("hgu95av2.db")
biocLite("Rgraphviz")
biocLite("colMap")
# Out:
# Bioconductor version 3.4 (BiocInstaller 1.24.0), ?biocLite for help
# BioC_mirror: https://bioconductor.org
# Using Bioconductor 3.4 (BiocInstaller 1.24.0), R 3.3.2 (2016-10-31).
# Old packages: 'backports', 'broom', 'colorspace', 'data.table', 'digest',
#   'forcats', 'ggplot2', 'jsonlite', 'Matrix', 'mgcv', 'nlme', 'openssl',
#   'pbdZMQ', 'psych', 'Rcpp', 'rprojroot', 'selectr', 'shiny', 'stringr',
#   'tidyr', 'tidyverse', 'xml2', 'zoo'
# BioC_mirror: https://bioconductor.org
# Using Bioconductor 3.4 (BiocInstaller 1.24.0), R 3.3.2 (2016-10-31).
# Installing package(s) ‘ALL’
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Old packages: 'backports', 'broom', 'colorspace', 'data.table', 'digest',
#   'forcats', 'ggplot2', 'jsonlite', 'Matrix', 'mgcv', 'nlme', 'openssl',
#   'pbdZMQ', 'psych', 'Rcpp', 'rprojroot', 'selectr', 'shiny', 'stringr',
#   'tidyr', 'tidyverse', 'xml2', 'zoo'
# BioC_mirror: https://bioconductor.org
# Using Bioconductor 3.4 (BiocInstaller 1.24.0), R 3.3.2 (2016-10-31).
# Installing package(s) ‘topGO’
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Old packages: 'backports', 'broom', 'colorspace', 'data.table', 'digest',
#   'forcats', 'ggplot2', 'jsonlite', 'Matrix', 'mgcv', 'nlme', 'openssl',
#   'pbdZMQ', 'psych', 'Rcpp', 'rprojroot', 'selectr', 'shiny', 'stringr',
#   'tidyr', 'tidyverse', 'xml2', 'zoo'
# BioC_mirror: https://bioconductor.org
# Using Bioconductor 3.4 (BiocInstaller 1.24.0), R 3.3.2 (2016-10-31).
# Installing package(s) ‘hgu95av2.db’
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Old packages: 'backports', 'broom', 'colorspace', 'data.table', 'digest',
#   'forcats', 'ggplot2', 'jsonlite', 'Matrix', 'mgcv', 'nlme', 'openssl',
#   'pbdZMQ', 'psych', 'Rcpp', 'rprojroot', 'selectr', 'shiny', 'stringr',
#   'tidyr', 'tidyverse', 'xml2', 'zoo'
# BioC_mirror: https://bioconductor.org
# Using Bioconductor 3.4 (BiocInstaller 1.24.0), R 3.3.2 (2016-10-31).
# Installing package(s) ‘Rgraphviz’
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Old packages: 'backports', 'broom', 'colorspace', 'data.table', 'digest',
#   'forcats', 'ggplot2', 'jsonlite', 'Matrix', 'mgcv', 'nlme', 'openssl',
#   'pbdZMQ', 'psych', 'Rcpp', 'rprojroot', 'selectr', 'shiny', 'stringr',
#   'tidyr', 'tidyverse', 'xml2', 'zoo'
# BioC_mirror: https://bioconductor.org
# Using Bioconductor 3.4 (BiocInstaller 1.24.0), R 3.3.2 (2016-10-31).
# Installing package(s) ‘colMap’
# Warning message:
# “package ‘colMap’ is not available (for R version 3.3.2)”Old packages: 'backports', 'broom', 'colorspace', 'data.table', 'digest',
#   'forcats', 'ggplot2', 'jsonlite', 'Matrix', 'mgcv', 'nlme', 'openssl',
#   'pbdZMQ', 'psych', 'Rcpp', 'rprojroot', 'selectr', 'shiny', 'stringr',
#   'tidyr', 'tidyverse', 'xml2', 'zoo'

# %%
library(topGO)
library(ALL)
data(ALL)
data(geneList)
# Out:
# Loading required package: BiocGenerics
# Loading required package: parallel
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, cbind, colnames, do.call,
#     duplicated, eval, evalq, Filter, Find, get, grep, grepl, intersect,
#     is.unsorted, lapply, lengths, Map, mapply, match, mget, order,
#     paste, pmax, pmax.int, pmin, pmin.int, Position, rank, rbind,
#     Reduce, rownames, sapply, setdiff, sort, table, tapply, union,
#     unique, unsplit, which, which.max, which.min
#
# Loading required package: graph
# Loading required package: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
# Loading required package: GO.db
# Loading required package: AnnotationDbi
# Loading required package: stats4
# Loading required package: IRanges
# Loading required package: S4Vectors
#
# Attaching package: ‘S4Vectors’
#
# The following objects are masked from ‘package:base’:
#
#     colMeans, colSums, expand.grid, rowMeans, rowSums
#
#
# Loading required package: SparseM
#
# Attaching package: ‘SparseM’
#
# The following object is masked from ‘package:base’:
#
#     backsolve
#
#
# groupGOTerms: 	GOBPTerm, GOMFTerm, GOCCTerm environments built.
#
# Attaching package: ‘topGO’
#
# The following object is masked from ‘package:IRanges’:
#
#     members

# %%
affyLib <- paste(annotation(ALL), "db", sep = ".")
library(package = affyLib, character.only = TRUE)
# Out:
# Loading required package: org.Hs.eg.db

# %%
sampleGOdata <- new("topGOdata",
                    description = "Simple session", ontology = "BP",
                    allGenes = geneList, geneSel = topDiffGenes,
                    nodeSize = 10,
                    annot = annFUN.db, affyLib = affyLib)
# Out:
# Building most specific GOs .....
# 	( 1499 GO terms found. )
#
# Build GO DAG topology ..........
# 	( 4222 GO terms and 9836 relations. )
#
# Annotating nodes ...............
# 	( 310 genes annotated to the GO terms. )

# %%
sampleGOdata
# Out:
# ------------------------- topGOdata object -------------------------
#
#  Description:
#    -  Simple session
#
#  Ontology:
#    -  BP
#
#  323 available genes (all genes from the array):
#    - symbol:  1095_s_at 1130_at 1196_at 1329_s_at 1340_s_at  ...
#    - score :  1 1 0.62238 0.541224 1  ...
#    - 50  significant genes.
#
#  310 feasible genes (genes that can be used in the analysis):
#    - symbol:  1095_s_at 1130_at 1196_at 1329_s_at 1340_s_at  ...
#    - score :  1 1 0.62238 0.541224 1  ...
#    - 46  significant genes.
#
#  GO graph (nodes with at least  10  genes):
#    - a graph with directed edges
#    - number of nodes = 1017
#    - number of edges = 2275
#
# ------------------------- topGOdata object -------------------------

# %%
resultFisher <- runTest(sampleGOdata, algorithm = "classic", statistic = "fisher")
resultFisher
# Out:
# 			 -- Classic Algorithm --
#
# 		 the algorithm is scoring 915 nontrivial nodes
# 		 parameters:
# 			 test statistic: fisher
# Description: Simple session
# Ontology: BP
# 'classic' algorithm with the 'fisher' test
# 1017 GO terms scored: 17 terms with p < 0.01
# Annotation data:
#     Annotated genes: 310
#     Significant genes: 46
#     Min. no. of genes annotated to a GO: 10
#     Nontrivial nodes: 915

# %%
resultKS <- runTest(sampleGOdata, algorithm = "classic", statistic = "ks")
resultKS
# Out:
# 			 -- Classic Algorithm --
#
# 		 the algorithm is scoring 1017 nontrivial nodes
# 		 parameters:
# 			 test statistic: ks
# 			 score order: increasing
# Description: Simple session
# Ontology: BP
# 'classic' algorithm with the 'ks' test
# 1017 GO terms scored: 49 terms with p < 0.01
# Annotation data:
#     Annotated genes: 310
#     Significant genes: 46
#     Min. no. of genes annotated to a GO: 10
#     Nontrivial nodes: 1017

# %%
resultKS.elim <- runTest(sampleGOdata, algorithm = "elim", statistic = "ks")
resultKS.elim
# Out:
# 			 -- Elim Algorithm --
#
# 		 the algorithm is scoring 1017 nontrivial nodes
# 		 parameters:
# 			 test statistic: ks
# 			 cutOff: 0.01
# 			 score order: increasing
#
# 	 Level 15:	3 nodes to be scored	(0 eliminated genes)
#
# 	 Level 14:	7 nodes to be scored	(0 eliminated genes)
#
# 	 Level 13:	14 nodes to be scored	(0 eliminated genes)
#
# 	 Level 12:	32 nodes to be scored	(0 eliminated genes)
#
# 	 Level 11:	38 nodes to be scored	(0 eliminated genes)
#
# 	 Level 10:	48 nodes to be scored	(10 eliminated genes)
#
# 	 Level 9:	91 nodes to be scored	(10 eliminated genes)
#
# 	 Level 8:	123 nodes to be scored	(22 eliminated genes)
#
# 	 Level 7:	159 nodes to be scored	(113 eliminated genes)
#
# 	 Level 6:	168 nodes to be scored	(199 eliminated genes)
#
# 	 Level 5:	159 nodes to be scored	(199 eliminated genes)
#
# 	 Level 4:	115 nodes to be scored	(215 eliminated genes)
#
# 	 Level 3:	41 nodes to be scored	(219 eliminated genes)
#
# 	 Level 2:	18 nodes to be scored	(219 eliminated genes)
#
# 	 Level 1:	1 nodes to be scored	(219 eliminated genes)
# Description: Simple session
# Ontology: BP
# 'elim' algorithm with the 'ks : 0.01' test
# 1017 GO terms scored: 18 terms with p < 0.01
# Annotation data:
#     Annotated genes: 310
#     Significant genes: 46
#     Min. no. of genes annotated to a GO: 10
#     Nontrivial nodes: 1017

# %%
allRes <- GenTable(sampleGOdata, classicFisher = resultFisher,
                   classicKS = resultKS, elimKS = resultKS.elim,
                   orderBy = "elimKS", ranksOf = "classicFisher", topNodes = 10)
allRes
# Out:
#    GO.ID      Term                                        Annotated Significant
# 1  GO:0007067 mitotic nuclear division                    171       17
# 2  GO:0051301 cell division                               146       16
# 3  GO:0000086 G2/M transition of mitotic cell cycle        35        6
# 4  GO:0045931 positive regulation of mitotic cell cycl...  32        3
# 5  GO:0051726 regulation of cell cycle                    122       15
# 6  GO:0090068 positive regulation of cell cycle proces...  33        3
# 7  GO:0032465 regulation of cytokinesis                    12        2
# 8  GO:0002768 immune response-regulating cell surface ...  12        7
# 9  GO:0070925 organelle assembly                           32        4
# 10 GO:0007062 sister chromatid cohesion                    45        4
#    Expected Rank in classicFisher classicFisher classicKS elimKS
# 1  25.37    907                   0.99781       5.3e-09   1.1e-07
# 2  21.66    858                   0.97657       7.8e-08   2.2e-07
# 3   5.19    344                   0.42080       0.00098   0.00098
# 4   4.75    704                   0.88666       0.00120   0.00120
# 5  18.10    684                   0.88146       0.00031   0.00167
# 6   4.90    707                   0.89957       0.00265   0.00265
# 7   1.78    424                   0.55432       0.00282   0.00282
# 8   1.78      1                   0.00046       0.00297   0.00297
# 9   4.75    534                   0.73382       0.00353   0.00353
# 10  6.68    792                   0.93286       0.00581   0.00581

# %%
pValue.classic <- score(resultKS)
pValue.elim <- score(resultKS.elim)[names(pValue.classic)]
gstat <- termStat(sampleGOdata, names(pValue.classic))
gSize <- gstat$Annotated / max(gstat$Annotated) * 4
gCol <- colMap(gstat$Significant)
plot(pValue.classic, pValue.elim, xlab = "p-value classic", ylab = "p-value elim",
     pch = 19, cex = gSize, col = gCol)
# Out:
# Error in eval(expr, envir, enclos): could not find function "colMap"
# Traceback:

# %%
sel.go <- names(pValue.classic)[pValue.elim < pValue.classic]
cbind(termStat(sampleGOdata, sel.go),
      elim = pValue.elim[sel.go],
      classic = pValue.classic[sel.go])
# Out:
#            Annotated Significant Expected elim       classic
# GO:0050793 69        16          10.24    0.03158704 0.05295464

# %%
showSigOfNodes(sampleGOdata, score(resultKS.elim), firstSigNodes = 5, useInfo ='all')
# Out:
# Loading required package: Rgraphviz
# Loading required package: grid
#
# Attaching package: ‘grid’
#
# The following object is masked from ‘package:topGO’:
#
#     depth
#
#
# Attaching package: ‘Rgraphviz’
#
# The following objects are masked from ‘package:IRanges’:
#
#     from, to
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     from, to
# $dag
# A graphNEL graph with directed edges
# Number of Nodes = 28
# Number of Edges = 48
#
# $complete.dag
# [1] "A graph with 28 nodes."
# plot without title

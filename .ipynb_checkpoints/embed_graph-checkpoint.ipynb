# %%
import numpy as np
import networkx as nx

from Queue import Queue
from threading import Thread
from threading import current_thread

from sklearn.manifold import MDS
    
# def custom_mds(D, k=5, variance_preserved=0.95):
        
#     #centering matrix
#     n = len(D)
#     C = np.identity(n) - np.ones((n, n)) / n
    
#     #similarity matrix
#     K = - 0.5 * np.dot(np.dot(C, D ** 2), C)
    
#     #eigen decompose K
#     l, U = np.linalg.eigh(K)
    
#     ##sort eigenvalues (and eigenvectors) into ascending order
#     idx = l.argsort()[::-1]
#     l = l[idx]
#     U = U[:,idx]
    
#     if k < 1:
    
#         s = (l - l[-1]) / (l[0] - l[-1])
#         print l
#         print s

#         total = sum(s)
#         k = 0
#         var = sum(s[:k]) / total
#         while var < variance_preserved:
#             k += 1
#             var = sum(s[:k]) / total
        
#         print "attempting to preserve 95% of variance".format(k)
    
#     print "embedding to {} dimensions".format(k)
    
    
#     #position matrix
#     X = np.dot(U[:,:k], np.diag(l[:k] ** 0.5))
    
#     return X

##function to generate benchmark graph
def benchmark_hierarchical_graph(edge_path, c1_path, c2_path):

    #construct graph from edge list
    G = nx.read_edgelist(edge_path)

    #create dictionarys of attributes
    c1 = read_attributes(c1_path)
    c2 = read_attributes(c2_path)

    #set attributes of G
    nx.set_node_attributes(G, 'firstlevelcommunity', c1)
    nx.set_node_attributes(G, 'secondlevelcommunity', c2)
    
    #return graph
    return G

##function to generate benchmark graph
def benchmark_graph(edge_path, c_path):
    
    #construct graph from edge list
    G = nx.read_edgelist(edge_path)

    #create dictionarys of attributes
    c = read_attributes(c_path)

    #set attributes of G
    nx.set_node_attributes(G, 'firstlevelcommunity', c)
    
    #return graph
    return G

##function to read in attributes from file and return a dictionary
def read_attributes(filepath):
    
    #initialise dictionary
    d = {}
    
    #open file
    with open(filepath) as f:
        
        #iterate over lines in f
        for l in f:
            
            #separate into key and value
            k, v = l.split()
            
            #add to dictionary
            d[k] = v
    
    #return
    return d

def filter_nodes_with_no_embedding(G, D):
    
    for n in G.nodes():
    
        if n not in D.keys():
            print "{} not in D, removing it from the network".format(n)
            G.remove_node(n)

##save embedding to graph
def set_embedding(G, X):
    
    embedding = {k: v for k, v in zip(G.nodes(), X)}
    
    nx.set_node_attributes(G, "embedding", embedding)
    
def main_hierarchical(network, first_level, second_level, filename):
    
    #import graph from file
    G = benchmark_hierarchical_graph(network, first_level, second_level)
    
    #only embed largest subgraph
    H = max(nx.connected_component_subgraphs(G), key=len)
    
    #embed into X
    D = nx.floyd_warshall(H)
    
    #remove nodes from H with no embedding
    filter_nodes_with_no_embedding(H, D)    

    ##to array
    D = np.array([[D[i][j] for j in D.keys()] for i in D.keys()])

    k = 10
    
    print "embedding to {} dimensions".format(k)

    mds = MDS(n_components = k, dissimilarity = "precomputed", n_jobs=-1, max_iter=1000)
    X = mds.fit_transform(D)
    
    #save embedding to nodes of G
    set_embedding(H, X)
    
    #write gml file
    nx.write_gpickle(H, filename)

def main_binary(network, first_level, filename, k = 5):
    
    #import graph from file
    G = benchmark_graph(network, first_level)
    
    #only embed largest subgraph
    H = max(nx.connected_component_subgraphs(G), key=len)
    
    #embed into X
    D = nx.floyd_warshall(H)
    
    #remove nodes from H with no embedding
    filter_nodes_with_no_embedding(H, D)   
    
    ##to array
    D = np.array([[D[i][j] for j in D.keys()] for i in D.keys()])
    
    #mds
    X = custom_mds(D, k = k) 

    
#     print "embedding to {} dimensions".format(k)

#     mds = MDS(n_components = k, dissimilarity = "precomputed", n_jobs=-1, max_iter=10000)
#     X = mds.fit_transform(D)
    
    #save embedding to nodes of G
    set_embedding(H, X)
    
    #write gml file
    nx.write_gpickle(H, filename)

def main(txt, filename, D=None, delimiter="\t", min_k = 1, max_k = 50, eps = 1):
    
    #import graph from file
    G = nx.read_edgelist(txt, delimiter=delimiter)
    
    #only embed largest subgraph
    H = max(nx.connected_component_subgraphs(G), key=len)
    
    #embed into X
    if D == None:
        #if no precomuped distance matrix then use floyd
        D = nx.floyd_warshall(H)
    
    #remove nodes from H with no embedding
    filter_nodes_with_no_embedding(H, D) 
    
    ##to array
    D = np.array([[D[i][j] for j in D.keys()] for i in D.keys()])
    
    print "computed distance matrix"
    
    #validation testing for best dimension
    stresses = np.array([])
    
    
    for k in range(min_k, max_k + 1):
        
        mds = MDS(n_components = k, dissimilarity = "precomputed", n_jobs=-1, max_iter=1000)
        mds.fit(D)

        stress = mds.stress_
        X = mds.embedding_
        


        stresses = np.append(stresses, stress)
        gradient = np.gradient(stresses, 5)[-1]
        
        
        print "k={}, stress={}, gradient={}".format(k, stress, gradient)
            
        if np.abs(gradient) < eps:
            print "BREAK"
            break
    
    #save embedding to nodes of G
#     set_embedding(H, X)

    #write gml file
#     nx.write_gpickle(H, filename)
    
    return k, stress, X

# %%
stresses = main("reactome_edgelist.txt", "embedded_yeast_reactome.gpickle", min_k = 10)
# Out:
# computed distance matrix
# k=13, epsilon=2358.77567848, gradient=-589.693919619
# k=14, epsilon=1435.90063507, gradient=-358.975158768
# k=15, epsilon=1204.23731365, gradient=-301.059328413
# k=16, epsilon=1006.01894082, gradient=-251.504735205
# k=17, epsilon=447.264115187, gradient=-111.816028797
# k=18, epsilon=727.708924441, gradient=-181.92723111
# k=19, epsilon=410.144079159, gradient=-102.53601979
# k=20, epsilon=304.492096919, gradient=-76.1230242297
# k=21, epsilon=209.135786968, gradient=-52.283946742
# k=22, epsilon=224.126604716, gradient=-56.031651179
# k=23, epsilon=209.394237951, gradient=-52.3485594877
# k=24, epsilon=150.970629549, gradient=-37.7426573872
# k=25, epsilon=171.055463037, gradient=-42.7638657593
# k=26, epsilon=122.342085455, gradient=-30.5855213637
# k=27, epsilon=97.5524894139, gradient=-24.3881223535

# %%
stresses
# Out:
# (27,
#  6495.642254203447,
#  array([[ 0.38401351,  0.31031239,  0.9148125 , ...,  0.75009025,
#           0.67016012, -0.51782998],
#         [ 0.33927871, -0.4803749 ,  1.24347522, ...,  2.4149187 ,
#           0.14358231, -1.11292806],
#         [ 0.57036365,  0.21023049, -0.12652271, ..., -0.35407745,
#           0.27584259,  1.09989805],
#         ...,
#         [ 1.15066486, -0.41047932,  2.50217295, ...,  2.56398161,
#           1.58332918, -1.20861159],
#         [-0.81178507,  1.50425892,  1.41168018, ...,  1.93864531,
#          -1.43381879,  1.32322018],
#         [ 0.8925345 , -0.18315787,  0.35101934, ...,  0.40536165,
#           0.36829668, -0.76612723]]))

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(stresses)
plt.show()

# %%
main_binary("benchmarks/network.dat", "benchmarks/community.dat", "embedded_benchmark.gpickle", k = 10)
# Out:
# embedding to 10 dimensions

# %%
G = nx.read_gpickle("embedded_yeast_reactome.gpickle")

# %%
G.nodes(data=True)
# Out:
# [(u'Q03761', {'embedding': array([ 1.93280185])}),
#  (u'P39077', {'embedding': array([-3.07451251])}),
#  (u'Q12311', {'embedding': array([ 1.66353196])}),
#  (u'Q03764', {'embedding': array([-2.08365321])}),
#  (u'Q06102', {'embedding': array([ 2.54693411])}),
#  (u'Q06103', {'embedding': array([ 1.93595652])}),
#  (u'P30619', {'embedding': array([ 0.35350198])}),
#  (u'P0C0T4', {'embedding': array([ 1.66353196])}),
#  (u'P40555', {'embedding': array([ 1.93595652])}),
#  (u'P0CX85', {'embedding': array([-6.36295523])}),
#  (u'P0CX84', {'embedding': array([ 1.64213992])}),
#  (u'P0CX83', {'embedding': array([ 2.32982633])}),
#  (u'P0CX82', {'embedding': array([ 1.86617232])}),
#  (u'P38991', {'embedding': array([-0.48775116])}),
#  (u'P48566', {'embedding': array([ 3.47481559])}),
#  (u'P35688', {'embedding': array([ 1.60757891])}),
#  (u'P0C2H7', {'embedding': array([ 0.99624355])}),
#  (u'Q6Q595', {'embedding': array([ 1.92799259])}),
#  (u'Q12289', {'embedding': array([-4.65519125])}),
#  (u'P40559', {'embedding': array([-4.66147706])}),
#  (u'P39875', {'embedding': array([-2.65231005])}),
#  (u'P41810', {'embedding': array([-5.03832997])}),
#  (u'P41811', {'embedding': array([-3.50006648])}),
#  (u'P0CD98', {'embedding': array([ 1.48670072])}),
#  (u'Q3E731', {'embedding': array([ 0.97772896])}),
#  (u'Q07560', {'embedding': array([-7.30712285])}),
#  (u'P25374', {'embedding': array([ 3.61211232])}),
#  (u'Q04305', {'embedding': array([ 1.66353196])}),
#  (u'P0CD90', {'embedding': array([ 1.64213992])}),
#  (u'P07143', {'embedding': array([ 1.61783187])}),
#  (u'Q07442', {'embedding': array([ 1.94213454])}),
#  (u'P20081', {'embedding': array([-5.18364656])}),
#  (u'Q06407', {'embedding': array([ 1.94141058])}),
#  (u'P32796', {'embedding': array([-4.66147706])}),
#  (u'P38697', {'embedding': array([ 0.6867676])}),
#  (u'P38759', {'embedding': array([ 1.37970622])}),
#  (u'P38811', {'embedding': array([-2.87171062])}),
#  (u'P38755', {'embedding': array([-3.09138726])}),
#  (u'P38754', {'embedding': array([ 2.09517577])}),
#  (u'P32829', {'embedding': array([ 1.05405059])}),
#  (u'P38753', {'embedding': array([ 2.09517577])}),
#  (u'Q12271', {'embedding': array([ 2.09517577])}),
#  (u'P38170', {'embedding': array([ 1.00960735])}),
#  (u'Q12277', {'embedding': array([ 2.40214999])}),
#  (u'Q07963', {'embedding': array([ 2.08761286])}),
#  (u'P41318', {'embedding': array([ 1.66353196])}),
#  (u'P25386', {'embedding': array([ 1.66110181])}),
#  (u'P38274', {'embedding': array([ 1.66110181])}),
#  (u'P05743', {'embedding': array([-4.97255316])}),
#  (u'P05740', {'embedding': array([ 0.8222648])}),
#  (u'P15731', {'embedding': array([ 2.0538498])}),
#  (u'Q12446', {'embedding': array([-4.56572078])}),
#  (u'P05747', {'embedding': array([ 1.93511742])}),
#  (u'P02829', {'embedding': array([ 1.74146627])}),
#  (u'P05749', {'embedding': array([ 2.40359988])}),
#  (u'P54999', {'embedding': array([-5.21059556])}),
#  (u'Q12375', {'embedding': array([ 1.68882803])}),
#  (u'Q12377', {'embedding': array([ 2.04564274])}),
#  (u'P20435', {'embedding': array([ 1.70161017])}),
#  (u'P20434', {'embedding': array([ 2.03555314])}),
#  (u'P40422', {'embedding': array([-5.03447539])}),
#  (u'P20436', {'embedding': array([ 0.53866512])}),
#  (u'P06787', {'embedding': array([-6.90712963])}),
#  (u'P06786', {'embedding': array([-5.85653567])}),
#  (u'P20433', {'embedding': array([-4.65519125])}),
#  (u'P32361', {'embedding': array([-5.31081664])}),
#  (u'P26783', {'embedding': array([ 1.66353196])}),
#  (u'P22141', {'embedding': array([ 2.46158537])}),
#  (u'Q3E7X9', {'embedding': array([ 2.46158537])}),
#  (u'Q03290', {'embedding': array([ 2.50637058])}),
#  (u'P26309', {'embedding': array([ 1.97802274])}),
#  (u'Q02931', {'embedding': array([ 0.66982651])}),
#  (u'P32944', {'embedding': array([ 0.3528773])}),
#  (u'P0C2H9', {'embedding': array([ 1.36734197])}),
#  (u'P39081', {'embedding': array([ 2.54693411])}),
#  (u'Q02939', {'embedding': array([ 2.92459086])}),
#  (u'P40498', {'embedding': array([-0.65949414])}),
#  (u'P24814', {'embedding': array([-3.83927477])}),
#  (u'Q12086', {'embedding': array([ 1.74146627])}),
#  (u'P38798', {'embedding': array([ 2.92077027])}),
#  (u'P33412', {'embedding': array([ 1.55467089])}),
#  (u'P26786', {'embedding': array([ 1.64213992])}),
#  (u'Q04322', {'embedding': array([-4.56057437])}),
#  (u'P40034', {'embedding': array([-7.48767409])}),
#  (u'P18494', {'embedding': array([ 1.64213992])}),
#  (u'P35182', {'embedding': array([ 2.84705566])}),
#  (u'Q00582', {'embedding': array([ 0.54334517])}),
#  (u'P35180', {'embedding': array([-4.67498846])}),
#  (u'P35187', {'embedding': array([-4.0715906])}),
#  (u'P25441', {'embedding': array([ 2.33311128])}),
#  (u'P00942', {'embedding': array([-5.36664955])}),
#  (u'P34160', {'embedding': array([ 2.08548736])}),
#  (u'P19735', {'embedding': array([ 1.63256726])}),
#  (u'P15873', {'embedding': array([ 0.35350198])}),
#  (u'O13516', {'embedding': array([ 2.07845004])}),
#  (u'P07560', {'embedding': array([ 1.69139614])}),
#  (u'P47142', {'embedding': array([ 2.62981133])}),
#  (u'P07213', {'embedding': array([-0.59384428])}),
#  (u'P43637', {'embedding': array([-4.92373418])}),
#  (u'P47147', {'embedding': array([ 2.06329172])}),
#  (u'P12612', {'embedding': array([ 1.64213992])}),
#  (u'P03965', {'embedding': array([ 1.64213992])}),
#  (u'P03962', {'embedding': array([-5.75392915])}),
#  (u'Q08749', {'embedding': array([ 0.89959754])}),
#  (u'P10659', {'embedding': array([ 2.32982633])}),
#  (u'Q08745', {'embedding': array([-0.99890602])}),
#  (u'P53091', {'embedding': array([ 1.70394976])}),
#  (u'P29311', {'embedding': array([ 1.70367812])}),
#  (u'P14736', {'embedding': array([-6.25345554])}),
#  (u'P32502', {'embedding': array([ 2.01407971])}),
#  (u'P32501', {'embedding': array([ 3.29128707])}),
#  (u'Q08162', {'embedding': array([-2.92438891])}),
#  (u'P32914', {'embedding': array([-5.99620887])}),
#  (u'P01120', {'embedding': array([ 1.92914092])}),
#  (u'P28743', {'embedding': array([ 0.83847791])}),
#  (u'P32910', {'embedding': array([ 3.13786177])}),
#  (u'P34110', {'embedding': array([ 0.93400893])}),
#  (u'P21954', {'embedding': array([ 0.79489619])}),
#  (u'P21951', {'embedding': array([ 1.64213992])}),
#  (u'P00830', {'embedding': array([-0.65963072])}),
#  (u'P40047', {'embedding': array([-4.08527306])}),
#  (u'P53152', {'embedding': array([ 3.94295582])}),
#  (u'P32461', {'embedding': array([ 1.94245854])}),
#  (u'P32463', {'embedding': array([ 2.32920291])}),
#  (u'P32462', {'embedding': array([ 3.30617464])}),
#  (u'Q02159', {'embedding': array([-0.78466749])}),
#  (u'Q03834', {'embedding': array([ 1.46645899])}),
#  (u'P07276', {'embedding': array([ 2.87446306])}),
#  (u'Q03833', {'embedding': array([ 2.0538498])}),
#  (u'P00424', {'embedding': array([ 2.63250765])}),
#  (u'P15019', {'embedding': array([ 1.37970622])}),
#  (u'P23594', {'embedding': array([ 2.92459086])}),
#  (u'P04385', {'embedding': array([ 1.64213992])}),
#  (u'P00549', {'embedding': array([ 2.32982633])}),
#  (u'P36014', {'embedding': array([ 0.70649549])}),
#  (u'Q08444', {'embedding': array([ 2.69908282])}),
#  (u'P36017', {'embedding': array([-5.05877792])}),
#  (u'P36010', {'embedding': array([ 2.04833154])}),
#  (u'P32867', {'embedding': array([ 1.43031548])}),
#  (u'P04076', {'embedding': array([ 2.50679786])}),
#  (u'P12689', {'embedding': array([ 1.64213992])}),
#  (u'P12688', {'embedding': array([ 1.64213992])}),
#  (u'Q01590', {'embedding': array([ 1.64213992])}),
#  (u'P36019', {'embedding': array([ 1.64213992])}),
#  (u'P06367', {'embedding': array([ 1.93280185])}),
#  (u'P43321', {'embedding': array([ 1.00602904])}),
#  (u'P22217', {'embedding': array([-6.46606286])}),
#  (u'P22216', {'embedding': array([ 1.66353196])}),
#  (u'P08431', {'embedding': array([ 1.64213992])}),
#  (u'P22214', {'embedding': array([ 1.37990856])}),
#  (u'P49166', {'embedding': array([ 1.37132127])}),
#  (u'P49167', {'embedding': array([-3.80889799])}),
#  (u'P10614', {'embedding': array([ 2.40153901])}),
#  (u'P50110', {'embedding': array([ 3.37380148])}),
#  (u'Q03407', {'embedding': array([ 2.52830821])}),
#  (u'P22219', {'embedding': array([ 2.52830821])}),
#  (u'P0CD91', {'embedding': array([ 1.60778683])}),
#  (u'P40344', {'embedding': array([ 1.71489468])}),
#  (u'P0CS91', {'embedding': array([ 0.19022152])}),
#  (u'P08539', {'embedding': array([-7.1216771])}),
#  (u'Q04500', {'embedding': array([ 2.08548736])}),
#  (u'P25373', {'embedding': array([-5.29233919])}),
#  (u'P40343', {'embedding': array([-6.93535072])}),
#  (u'P25336', {'embedding': array([ 1.89783654])}),
#  (u'P33202', {'embedding': array([ 2.62981133])}),
#  (u'P32600', {'embedding': array([ 2.32982633])}),
#  (u'P50874', {'embedding': array([ 1.29723697])}),
#  (u'P32602', {'embedding': array([ 2.46158537])}),
#  (u'P50873', {'embedding': array([-6.49615362])}),
#  (u'P38711', {'embedding': array([-4.65938154])}),
#  (u'P33298', {'embedding': array([-5.05906621])}),
#  (u'P40556', {'embedding': array([ 1.64213992])}),
#  (u'P38712', {'embedding': array([ 2.01021382])}),
#  (u'P52492', {'embedding': array([ 3.37380148])}),
#  (u'P52490', {'embedding': array([ 1.93195374])}),
#  (u'P38719', {'embedding': array([ 1.93595652])}),
#  (u'P32590', {'embedding': array([ 1.93595652])}),
#  (u'P22276', {'embedding': array([ 1.66353196])}),
#  (u'P19812', {'embedding': array([ 0.80299276])}),
#  (u'P16370', {'embedding': array([ 0.98876468])}),
#  (u'P24000', {'embedding': array([-1.08380904])}),
#  (u'P21524', {'embedding': array([ 1.93280185])}),
#  (u'P53839', {'embedding': array([ 1.85549014])}),
#  (u'Q06336', {'embedding': array([ 3.70446504])}),
#  (u'P15303', {'embedding': array([ 3.70446504])}),
#  (u'P37262', {'embedding': array([ 1.74146627])}),
#  (u'P38138', {'embedding': array([ 2.32982633])}),
#  (u'P48365', {'embedding': array([-5.03698081])}),
#  (u'Q06156', {'embedding': array([ 0.961235])}),
#  (u'Q05583', {'embedding': array([ 2.40163563])}),
#  (u'Q12339', {'embedding': array([ 0.5583013])}),
#  (u'P13382', {'embedding': array([ 1.12322213])}),
#  (u'P0C0W9', {'embedding': array([ 0.93400893])}),
#  (u'P48240', {'embedding': array([ 1.00602904])}),
#  (u'P38221', {'embedding': array([ 1.66353196])}),
#  (u'Q03497', {'embedding': array([ 0.91916673])}),
#  (u'P15790', {'embedding': array([ 2.75272397])}),
#  (u'P27895', {'embedding': array([ 1.97618528])}),
#  (u'P40469', {'embedding': array([ 0.50927824])}),
#  (u'Q99260', {'embedding': array([-5.41144798])}),
#  (u'P04046', {'embedding': array([ 0.01596191])}),
#  (u'P26343', {'embedding': array([ 1.96935042])}),
#  (u'P39929', {'embedding': array([-3.96022583])}),
#  (u'P38431', {'embedding': array([ 2.05958432])}),
#  (u'P48510', {'embedding': array([-5.20405486])}),
#  (u'P39538', {'embedding': array([ 1.93595652])}),
#  (u'P39926', {'embedding': array([-3.18949265])}),
#  (u'P38439', {'embedding': array([-4.66147706])}),
#  (u'P32324', {'embedding': array([ 3.47481559])}),
#  (u'P38063', {'embedding': array([ 1.26983424])}),
#  (u'Q06409', {'embedding': array([ 2.05958432])}),
#  (u'P12385', {'embedding': array([-7.68790834])}),
#  (u'P61829', {'embedding': array([ 1.01412718])}),
#  (u'P38061', {'embedding': array([-10.14273617])}),
#  (u'Q02753', {'embedding': array([-9.06329626])}),
#  (u'P38226', {'embedding': array([ 0.52513444])}),
#  (u'P25586', {'embedding': array([ 1.56072148])}),
#  (u'P14284', {'embedding': array([ 2.04797916])}),
#  (u'P40335', {'embedding': array([ 1.02391281])}),
#  (u'P57744', {'embedding': array([ 2.32982633])}),
#  (u'P10862', {'embedding': array([ 2.40180161])}),
#  (u'P57743', {'embedding': array([ 2.02540983])}),
#  (u'Q12200', {'embedding': array([ 1.37222127])}),
#  (u'Q08491', {'embedding': array([ 0.24167652])}),
#  (u'P16603', {'embedding': array([-5.04119965])}),
#  (u'P38873', {'embedding': array([ 1.96935042])}),
#  (u'P14832', {'embedding': array([ 4.20588452])}),
#  (u'Q12204', {'embedding': array([ 2.92459086])}),
#  (u'P26785', {'embedding': array([-7.33525073])}),
#  (u'P23394', {'embedding': array([ 1.70176811])}),
#  (u'P46946', {'embedding': array([ 1.48670072])}),
#  (u'Q03784', {'embedding': array([ 3.47485654])}),
#  (u'P17709', {'embedding': array([ 2.02060047])}),
#  (u'P46948', {'embedding': array([-4.15962042])}),
#  (u'P80967', {'embedding': array([ 0.74324089])}),
#  (u'Q12412', {'embedding': array([ 1.3415327])}),
#  (u'P39990', {'embedding': array([ 1.43228034])}),
#  (u'P0CX24', {'embedding': array([ 1.61253166])}),
#  (u'P0CX27', {'embedding': array([ 0.90108364])}),
#  (u'P0CX26', {'embedding': array([ 2.68408133])}),
#  (u'P39994', {'embedding': array([ 0.74938903])}),
#  (u'Q07381', {'embedding': array([ 1.43143948])}),
#  (u'P48589', {'embedding': array([-4.68844778])}),
#  (u'Q3E7A4', {'embedding': array([-4.66147706])}),
#  (u'Q00578', {'embedding': array([ 0.06085776])}),
#  (u'P23561', {'embedding': array([-4.68434146])}),
#  (u'P0CX29', {'embedding': array([ 2.50679786])}),
#  (u'P0CX28', {'embedding': array([-0.99890602])}),
#  (u'P53397', {'embedding': array([ 1.93595652])}),
#  (u'P33420', {'embedding': array([ 2.08761286])}),
#  (u'P39109', {'embedding': array([ 1.70161017])}),
#  (u'P36046', {'embedding': array([ 2.84752757])}),
#  (u'P39104', {'embedding': array([-4.66147706])}),
#  (u'Q05021', {'embedding': array([-5.83510572])}),
#  (u'Q02724', {'embedding': array([ 1.49222767])}),
#  (u'P31109', {'embedding': array([ 2.50679786])}),
#  (u'P25298', {'embedding': array([ 2.41902863])}),
#  (u'P25299', {'embedding': array([ 2.46158537])}),
#  (u'P25296', {'embedding': array([ 2.62981133])}),
#  (u'P38912', {'embedding': array([ 3.70446504])}),
#  (u'P25294', {'embedding': array([-6.64293694])}),
#  (u'Q02196', {'embedding': array([ 2.09055955])}),
#  (u'Q04272', {'embedding': array([ 2.01021382])}),
#  (u'P40160', {'embedding': array([ 1.28041747])}),
#  (u'P07245', {'embedding': array([-6.49615362])}),
#  (u'P07244', {'embedding': array([ 2.89830952])}),
#  (u'Q08032', {'embedding': array([ 1.68882803])}),
#  (u'P25454', {'embedding': array([ 1.97827051])}),
#  (u'Q00916', {'embedding': array([-10.13617406])}),
#  (u'P26784', {'embedding': array([-0.81894771])}),
#  (u'P39936', {'embedding': array([-5.52887393])}),
#  (u'Q02354', {'embedding': array([ 0.3955789])}),
#  (u'P04821', {'embedding': array([-0.21266522])}),
#  (u'P14741', {'embedding': array([ 2.05958432])}),
#  (u'P02406', {'embedding': array([ 2.08548736])}),
#  (u'P02407', {'embedding': array([-4.68434146])}),
#  (u'P02400', {'embedding': array([ 3.70590273])}),
#  (u'P14747', {'embedding': array([ 1.80502761])}),
#  (u'P38903', {'embedding': array([-8.22999173])}),
#  (u'P28000', {'embedding': array([ 2.09328702])}),
#  (u'P17898', {'embedding': array([ 2.92077027])}),
#  (u'P53960', {'embedding': array([ 2.62981133])}),
#  (u'O74700', {'embedding': array([-3.9513332])}),
#  (u'P17890', {'embedding': array([-1.72704361])}),
#  (u'P05745', {'embedding': array([-3.83819882])}),
#  (u'P53969', {'embedding': array([ 1.34665978])}),
#  (u'P27796', {'embedding': array([ 1.64213992])}),
#  (u'P33328', {'embedding': array([-4.56057437])}),
#  (u'P32496', {'embedding': array([ 2.08548736])}),
#  (u'P32497', {'embedding': array([-4.65639616])}),
#  (u'P32558', {'embedding': array([ 3.13786177])}),
#  (u'P13856', {'embedding': array([ 1.51875174])}),
#  (u'P40303', {'embedding': array([-5.03698081])}),
#  (u'P40302', {'embedding': array([ 1.12322213])}),
#  (u'P53064', {'embedding': array([ 2.70094659])}),
#  (u'P13393', {'embedding': array([ 1.66353196])}),
#  (u'P0CX25', {'embedding': array([-3.18949265])}),
#  (u'P38886', {'embedding': array([ 2.32982633])}),
#  (u'P36070', {'embedding': array([-7.1163735])}),
#  (u'P38968', {'embedding': array([ 1.12322213])}),
#  (u'P38615', {'embedding': array([ 1.93595652])}),
#  (u'P19073', {'embedding': array([ 2.02698757])}),
#  (u'P34730', {'embedding': array([ 1.96339378])}),
#  (u'P36126', {'embedding': array([ 2.02290591])}),
#  (u'P39993', {'embedding': array([ 1.04443679])}),
#  (u'P11747', {'embedding': array([ 2.01359877])}),
#  (u'P50086', {'embedding': array([ 1.93280185])}),
#  (u'P38989', {'embedding': array([-2.44626804])}),
#  (u'P17967', {'embedding': array([ 1.69232691])}),
#  (u'P43567', {'embedding': array([ 2.92459086])}),
#  (u'P00572', {'embedding': array([-9.02758303])}),
#  (u'P16862', {'embedding': array([-4.65639616])}),
#  (u'P16861', {'embedding': array([ 0.59089018])}),
#  (u'P34221', {'embedding': array([ 3.61211232])}),
#  (u'P32943', {'embedding': array([ 3.47485654])}),
#  (u'Q06624', {'embedding': array([-5.77613936])}),
#  (u'P54791', {'embedding': array([ 2.83014398])}),
#  (u'P30605', {'embedding': array([ 1.92799259])}),
#  (u'P32367', {'embedding': array([ 1.92913911])}),
#  (u'Q06506', {'embedding': array([ 2.04797916])}),
#  (u'P25635', {'embedding': array([ 2.50637058])}),
#  (u'Q99383', {'embedding': array([ 1.96935042])}),
#  (u'P32364', {'embedding': array([ 1.93595652])}),
#  (u'Q03020', {'embedding': array([ 2.85001965])}),
#  (u'P04710', {'embedding': array([-7.2651611])}),
#  (u'P39960', {'embedding': array([-7.44007889])}),
#  (u'P40541', {'embedding': array([-0.65963072])}),
#  (u'P06780', {'embedding': array([-0.18943088])}),
#  (u'P39967', {'embedding': array([-4.65639616])}),
#  (u'P39966', {'embedding': array([ 0.898753])}),
#  (u'P32771', {'embedding': array([ 2.08548736])}),
#  (u'P50947', {'embedding': array([-4.1385237])}),
#  (u'P14126', {'embedding': array([ 2.32982633])}),
#  (u'P06700', {'embedding': array([-4.66147706])}),
#  (u'P14120', {'embedding': array([ 2.62981133])}),
#  (u'P32774', {'embedding': array([ 0.54334517])}),
#  (u'P43588', {'embedding': array([-2.08365321])}),
#  (u'P32776', {'embedding': array([ 3.30617464])}),
#  (u'P0CG63', {'embedding': array([ 1.5194209])}),
#  (u'P02309', {'embedding': array([ 1.01412718])}),
#  (u'P41805', {'embedding': array([-1.17682754])}),
#  (u'P06785', {'embedding': array([ 1.42059501])}),
#  (u'Q04491', {'embedding': array([ 2.54693411])}),
#  (u'P25342', {'embedding': array([-4.15962042])}),
#  (u'Q07457', {'embedding': array([ 2.04797916])}),
#  (u'P38920', {'embedding': array([-4.66750428])}),
#  (u'P18851', {'embedding': array([-7.43114799])}),
#  (u'P38682', {'embedding': array([ 1.96909575])}),
#  (u'P32571', {'embedding': array([ 1.64213992])}),
#  (u'P32604', {'embedding': array([ 2.34251587])}),
#  (u'P00890', {'embedding': array([ 2.05484476])}),
#  (u'P38689', {'embedding': array([ 2.32982633])}),
#  (u'P38764', {'embedding': array([-6.66078249])}),
#  (u'P05375', {'embedding': array([ 1.69139614])}),
#  (u'P32899', {'embedding': array([ 2.08761286])}),
#  (u'Q05946', {'embedding': array([ 1.45809748])}),
#  (u'P38142', {'embedding': array([-4.92373418])}),
#  (u'Q3E846', {'embedding': array([ 1.52593617])}),
#  (u'Q3E840', {'embedding': array([ 1.64213992])}),
#  (u'P38147', {'embedding': array([ 3.47526494])}),
#  (u'P18414', {'embedding': array([ 3.15017652])}),
#  (u'Q12246', {'embedding': array([ 1.93280185])}),
#  (u'P30657', {'embedding': array([ 1.93113749])}),
#  (u'Q12520', {'embedding': array([-5.98631425])}),
#  (u'Q12451', {'embedding': array([ 1.97802274])}),
#  (u'P05750', {'embedding': array([ 2.41861672])}),
#  (u'Q12452', {'embedding': array([ 1.74222001])}),
#  (u'P05755', {'embedding': array([ 0.68552858])}),
#  (u'P32368', {'embedding': array([ 2.09710762])}),
#  (u'P05756', {'embedding': array([ 1.94141058])}),
#  (u'P05759', {'embedding': array([ 2.03555314])}),
#  (u'Q03330', {'embedding': array([ 2.52830821])}),
#  (u'P22140', {'embedding': array([ 1.00624385])}),
#  (u'Q03337', {'embedding': array([ 2.52830821])}),
#  (u'P30771', {'embedding': array([ 4.20588452])}),
#  (u'P22138', {'embedding': array([ 1.81494203])}),
#  (u'P22139', {'embedding': array([ 1.00602904])}),
#  (u'P06778', {'embedding': array([-4.65519125])}),
#  (u'P06777', {'embedding': array([-4.60508153])}),
#  (u'P06774', {'embedding': array([ 2.92459086])}),
#  (u'P30283', {'embedding': array([ 2.89830952])}),
#  (u'P32378', {'embedding': array([ 0.79538036])}),
#  (u'P32074', {'embedding': array([ 1.52593617])}),
#  (u'Q05636', {'embedding': array([ 2.84668749])}),
#  (u'P07991', {'embedding': array([-0.74210991])}),
#  (u'P87108', {'embedding': array([ 0.78559536])}),
#  (u'P32803', {'embedding': array([-5.39852536])}),
#  (u'Q02948', {'embedding': array([ 1.92913911])}),
#  (u'Q04338', {'embedding': array([ 1.92914092])}),
#  (u'P29055', {'embedding': array([ 1.94468212])}),
#  (u'P29056', {'embedding': array([-6.99801661])}),
#  (u'Q12099', {'embedding': array([ 2.09328702])}),
#  (u'P41896', {'embedding': array([ 1.66353196])}),
#  (u'P24868', {'embedding': array([-2.35513558])}),
#  (u'P24869', {'embedding': array([ 1.91580838])}),
#  (u'Q00618', {'embedding': array([ 1.64213992])}),
#  (u'P35817', {'embedding': array([ 0.89959754])}),
#  (u'P39540', {'embedding': array([-3.47840006])}),
#  (u'P18900', {'embedding': array([-2.60768947])}),
#  (u'P0CX40', {'embedding': array([ 2.05958432])}),
#  (u'Q04062', {'embedding': array([ 1.56425022])}),
#  (u'Q08548', {'embedding': array([ 1.93280185])}),
#  (u'P47011', {'embedding': array([-4.33284783])}),
#  (u'P47013', {'embedding': array([-5.48775787])}),
#  (u'Q05521', {'embedding': array([ 0.99624355])}),
#  (u'Q12149', {'embedding': array([ 1.64213992])}),
#  (u'P38829', {'embedding': array([ 1.7285788])}),
#  (u'P47017', {'embedding': array([ 1.35004289])}),
#  (u'Q12033', {'embedding': array([ 2.011566])}),
#  (u'P36095', {'embedding': array([ 2.32982633])}),
#  (u'P23542', {'embedding': array([ 2.0538498])}),
#  (u'P28519', {'embedding': array([ 0.78577283])}),
#  (u'P42826', {'embedding': array([-4.68434146])}),
#  (u'P10507', {'embedding': array([ 2.055723])}),
#  (u'P38820', {'embedding': array([ 1.66093926])}),
#  (u'P53622', {'embedding': array([-3.84085985])}),
#  (u'P26754', {'embedding': array([-4.71650286])}),
#  (u'Q02793', {'embedding': array([ 1.8086002])}),
#  (u'P28263', {'embedding': array([ 1.1205872])}),
#  (u'P32783', {'embedding': array([-0.75098649])}),
#  (u'P18961', {'embedding': array([ 0.74324089])}),
#  (u'P18963', {'embedding': array([ 2.32982633])}),
#  (u'P32839', {'embedding': array([-3.83819882])}),
#  (u'P32354', {'embedding': array([ 1.64213992])}),
#  (u'P53142', {'embedding': array([ 2.03750659])}),
#  (u'P53141', {'embedding': array([ 1.64213992])}),
#  (u'Q08273', {'embedding': array([-4.71211919])}),
#  (u'P39933', {'embedding': array([-5.03698081])}),
#  (u'P41056', {'embedding': array([ 2.68881535])}),
#  (u'P41057', {'embedding': array([ 0.87417815])}),
#  (u'P19262', {'embedding': array([ 1.96909575])}),
#  (u'P38921', {'embedding': array([ 1.94166018])}),
#  (u'Q12021', {'embedding': array([-3.68624409])}),
#  (u'P40487', {'embedding': array([ 2.32920291])}),
#  (u'P22543', {'embedding': array([ 3.15017652])}),
#  (u'P38929', {'embedding': array([-5.96953373])}),
#  (u'Q12028', {'embedding': array([ 2.05449802])}),
#  (u'P23748', {'embedding': array([ 2.32982633])}),
#  (u'P32641', {'embedding': array([ 1.74146627])}),
#  (u'Q04341', {'embedding': array([ 0.8222648])}),
#  (u'Q01939', {'embedding': array([ 2.05958432])}),
#  (u'Q08285', {'embedding': array([ 1.29278467])}),
#  (u'P29453', {'embedding': array([ 3.30617464])}),
#  (u'P25566', {'embedding': array([-3.17647752])}),
#  (u'P35728', {'embedding': array([-4.26207984])}),
#  (u'P00924', {'embedding': array([-4.56236254])}),
#  (u'P27999', {'embedding': array([-3.41499561])}),
#  (u'P20133', {'embedding': array([-3.83819882])}),
#  (u'P06197', {'embedding': array([-0.25823414])}),
#  (u'P36000', {'embedding': array([-3.71661569])}),
#  (u'P25847', {'embedding': array([ 1.66353196])}),
#  (u'P36009', {'embedding': array([ 2.05958432])}),
#  (u'P11075', {'embedding': array([ 1.64213992])}),
#  (u'Q05809', {'embedding': array([-7.12664601])}),
#  (u'P20967', {'embedding': array([ 0.11833862])}),
#  (u'P40581', {'embedding': array([ 0.02815936])}),
#  (u'P25451', {'embedding': array([ 0.16481534])}),
#  (u'P24719', {'embedding': array([ 1.44261372])}),
#  (u'P53859', {'embedding': array([-4.67498846])}),
#  (u'P53738', {'embedding': array([-9.50358511])}),
#  (u'P09032', {'embedding': array([ 1.93595652])}),
#  (u'Q01560', {'embedding': array([ 2.32982633])}),
#  (u'Q04162', {'embedding': array([ 1.95118081])}),
#  (u'P35497', {'embedding': array([-6.09451047])}),
#  (u'Q04693', {'embedding': array([ 2.62981133])}),
#  (u'P25301', {'embedding': array([ 1.95118081])}),
#  (u'Q03530', {'embedding': array([ 1.25572876])}),
#  (u'P21243', {'embedding': array([ 1.93595652])}),
#  (u'P15274', {'embedding': array([ 2.03750659])}),
#  (u'P49626', {'embedding': array([ 2.03555314])}),
#  (u'P38720', {'embedding': array([-4.22510144])}),
#  (u'P35181', {'embedding': array([-5.00512093])}),
#  (u'Q04195', {'embedding': array([ 2.46158537])}),
#  (u'P27692', {'embedding': array([ 1.6416469])}),
#  (u'Q04673', {'embedding': array([ 0.82424668])}),
#  (u'P40204', {'embedding': array([ 2.03750659])}),
#  (u'P00445', {'embedding': array([ 1.52359705])}),
#  (u'P47977', {'embedding': array([ 2.01021382])}),
#  (u'P47976', {'embedding': array([ 1.93595652])}),
#  (u'P06243', {'embedding': array([ 1.94311029])}),
#  (u'P42951', {'embedding': array([ 1.94175966])}),
#  (u'P07807', {'embedding': array([-2.90533409])}),
#  (u'P0C0V8', {'embedding': array([ 1.34916954])}),
#  (u'Q02260', {'embedding': array([-0.59384428])}),
#  (u'P22803', {'embedding': array([ 2.32982633])}),
#  (u'P32897', {'embedding': array([ 2.32982633])}),
#  (u'P37297', {'embedding': array([ 1.66353196])}),
#  (u'P53600', {'embedding': array([-5.20405486])}),
#  (u'P37292', {'embedding': array([ 1.64213992])}),
#  (u'P46678', {'embedding': array([ 1.66353196])}),
#  (u'P53327', {'embedding': array([-4.92373418])}),
#  (u'P06738', {'embedding': array([ 2.89709539])}),
#  (u'Q99216', {'embedding': array([ 0.57344193])}),
#  (u'Q07914', {'embedding': array([ 0.17115583])}),
#  (u'P27882', {'embedding': array([ 2.01779475])}),
#  (u'P22137', {'embedding': array([ 2.32982633])}),
#  (u'P15436', {'embedding': array([ 1.938476])}),
#  (u'P04051', {'embedding': array([ 1.97618528])}),
#  (u'P38339', {'embedding': array([ 1.10317575])}),
#  (u'Q01080', {'embedding': array([ 2.02814923])}),
#  (u'Q99181', {'embedding': array([ 2.62981133])}),
#  (u'P28834', {'embedding': array([ 1.93595652])}),
#  (u'P24583', {'embedding': array([ 1.64142157])}),
#  (u'P40580', {'embedding': array([ 1.93595652])}),
#  (u'P15202', {'embedding': array([-0.13864946])}),
#  (u'P34164', {'embedding': array([ 1.66353196])}),
#  (u'Q12250', {'embedding': array([-4.65639616])}),
#  (u'Q01852', {'embedding': array([ 1.45076717])}),
#  (u'Q01855', {'embedding': array([ 1.45076717])}),
#  (u'Q07540', {'embedding': array([ 2.92459086])}),
#  (u'Q12216', {'embedding': array([ 1.64213992])}),
#  (u'Q04217', {'embedding': array([ 1.70176811])}),
#  (u'Q12213', {'embedding': array([-0.65949414])}),
#  (u'P38748', {'embedding': array([-3.80889799])}),
#  (u'P38217', {'embedding': array([ 1.97076201])}),
#  (u'Q12196', {'embedding': array([ 0.961235])}),
#  (u'Q99190', {'embedding': array([ 1.01355536])}),
#  (u'P13045', {'embedding': array([ 2.32982633])}),
#  (u'B5VDL3', {'embedding': array([ 2.08548736])}),
#  (u'P38862', {'embedding': array([ 3.47436601])}),
#  (u'P07251', {'embedding': array([ 1.64213992])}),
#  (u'P47051', {'embedding': array([ 1.01501928])}),
#  (u'P51401', {'embedding': array([-5.39166028])}),
#  (u'Q12354', {'embedding': array([-3.71661569])}),
#  (u'P23500', {'embedding': array([-4.56236254])}),
#  (u'P23501', {'embedding': array([ 0.96416798])}),
#  (u'Q06287', {'embedding': array([ 0.89384366])}),
#  (u'P23503', {'embedding': array([ 1.35004289])}),
#  (u'Q12429', {'embedding': array([ 1.60633128])}),
#  (u'P27825', {'embedding': array([ 1.36470983])}),
#  (u'P39940', {'embedding': array([ 2.32982633])}),
#  (u'P52910', {'embedding': array([-4.28199031])}),
#  (u'Q03262', {'embedding': array([ 0.70063633])}),
#  (u'P25694', {'embedding': array([ 1.64213992])}),
#  (u'P11484', {'embedding': array([ 1.99647571])}),
#  (u'P21242', {'embedding': array([ 2.05958432])}),
#  (u'P34087', {'embedding': array([ 1.70176811])}),
#  (u'P47143', {'embedding': array([ 1.70176811])}),
#  (u'Q08650', {'embedding': array([ 1.64213992])}),
#  (u'P39984', {'embedding': array([ 2.32982633])}),
#  (u'P0C2H8', {'embedding': array([ 1.01412718])}),
#  (u'P24783', {'embedding': array([-4.99812982])}),
#  (u'P40015', {'embedding': array([ 2.50679786])}),
#  (u'Q04307', {'embedding': array([-7.90027048])}),
#  (u'P40016', {'embedding': array([ 1.01412718])}),
#  (u'P40018', {'embedding': array([-7.71438521])}),
#  (u'P11433', {'embedding': array([ 3.70494439])}),
#  (u'P53104', {'embedding': array([ 1.43031548])}),
#  (u'P18238', {'embedding': array([-4.57025656])}),
#  (u'P18239', {'embedding': array([ 0.961235])}),
#  (u'P23639', {'embedding': array([ 0.0040086])}),
#  (u'P29496', {'embedding': array([ 2.05958432])}),
#  (u'Q12267', {'embedding': array([-4.68084292])}),
#  (u'P38817', {'embedding': array([ 3.70494439])}),
#  (u'P07273', {'embedding': array([ 1.66353196])}),
#  (u'P15108', {'embedding': array([ 2.37080128])}),
#  (u'P23595', {'embedding': array([-6.43062255])}),
#  (u'P07277', {'embedding': array([-3.83927477])}),
#  (u'P07278', {'embedding': array([ 0.02815936])}),
#  (u'Q12018', {'embedding': array([ 1.70176811])}),
#  (u'P25443', {'embedding': array([ 2.04356913])}),
#  (u'P24279', {'embedding': array([ 1.55603908])}),
#  (u'Q04048', {'embedding': array([ 1.25572876])}),
#  (u'P14693', {'embedding': array([ 0.56836683])}),
#  (u'P23644', {'embedding': array([-4.62518])}),
#  (u'P33339', {'embedding': array([ 1.95497747])}),
#  (u'P39938', {'embedding': array([-4.62743949])}),
#  (u'P33314', {'embedding': array([-4.67498846])}),
#  (u'P36147', {'embedding': array([ 1.6416469])}),
#  (u'P53953', {'embedding': array([-4.68144248])}),
#  (u'P36143', {'embedding': array([ 1.70161017])}),
#  (u'P46957', {'embedding': array([-6.38183265])}),
#  (u'Q06697', {'embedding': array([ 2.05958432])}),
#  (u'Q05027', {'embedding': array([ 1.93595652])}),
#  (u'P47821', {'embedding': array([ 2.62981133])}),
#  (u'P40339', {'embedding': array([ 2.62981133])}),
#  (u'Q05022', {'embedding': array([ 1.65301873])}),
#  (u'P36149', {'embedding': array([ 0.24167652])}),
#  (u'P21182', {'embedding': array([-3.83393046])}),
#  (u'P32481', {'embedding': array([ 0.87261793])}),
#  (u'P26321', {'embedding': array([ 1.64213992])}),
#  (u'P32485', {'embedding': array([ 1.10883951])}),
#  (u'P32562', {'embedding': array([ 0.78559536])}),
#  (u'P32565', {'embedding': array([ 0.66982651])}),
#  (u'Q04410', {'embedding': array([-1.8589756])}),
#  (u'P32567', {'embedding': array([-1.8589756])}),
#  (u'P50942', {'embedding': array([ 1.93595652])}),
#  (u'P89105', {'embedding': array([ 1.64213992])}),
#  (u'P32454', {'embedding': array([ 1.64213992])}),
#  (u'P00817', {'embedding': array([ 3.18486344])}),
#  (u'Q12074', {'embedding': array([ 1.93595652])}),
#  (u'P50090', {'embedding': array([ 2.05958432])}),
#  (u'P00812', {'embedding': array([-3.07451251])}),
#  (u'P32807', {'embedding': array([-9.0014891])}),
#  (u'P09938', {'embedding': array([-3.07451251])}),
#  (u'Q12434', {'embedding': array([ 1.54091542])}),
#  (u'P80235', {'embedding': array([ 2.09517577])}),
#  (u'P39076', {'embedding': array([-3.07451251])}),
#  (u'P06104', {'embedding': array([ 2.05958432])}),
#  (u'P08678', {'embedding': array([ 0.99624355])}),
#  (u'P39079', {'embedding': array([ 3.30617464])}),
#  (u'P39078', {'embedding': array([ 0.70649549])}),
#  (u'P00560', {'embedding': array([ 1.64213992])}),
#  (u'P04840', {'embedding': array([ 1.64213992])}),
#  (u'P43574', {'embedding': array([-4.6100749])}),
#  (u'P25628', {'embedding': array([ 1.64213992])}),
#  (u'P43601', {'embedding': array([ 0.84478279])}),
#  (u'P53256', {'embedding': array([ 1.64213992])}),
#  (u'P50101', {'embedding': array([-4.71211919])}),
#  (u'P53254', {'embedding': array([ 2.63205838])}),
#  (u'P52489', {'embedding': array([-7.95482356])}),
#  (u'P34216', {'embedding': array([ 1.93595652])}),
#  (u'P38786', {'embedding': array([ 2.05449802])}),
#  (u'Q06510', {'embedding': array([ 1.81483358])}),
#  (u'Q06512', {'embedding': array([ 1.04412278])}),
#  (u'P53318', {'embedding': array([ 2.05686632])}),
#  (u'P53319', {'embedding': array([ 2.32920291])}),
#  (u'P39958', {'embedding': array([ 1.61562027])}),
#  (u'P06103', {'embedding': array([ 0.73982657])}),
#  (u'P43593', {'embedding': array([ 1.94166018])}),
#  (u'P53312', {'embedding': array([ 2.84668749])}),
#  (u'P39956', {'embedding': array([-1.75291885])}),
#  (u'P20485', {'embedding': array([ 2.62981133])}),
#  (u'P25359', {'embedding': array([ 1.69139614])}),
#  (u'P53315', {'embedding': array([ 1.16962754])}),
#  (u'P19158', {'embedding': array([-5.04918014])}),
#  (u'P23248', {'embedding': array([ 1.35004289])}),
#  (u'P38074', {'embedding': array([ 2.32920291])}),
#  (u'Q12341', {'embedding': array([ 1.00624385])}),
#  (u'P46995', {'embedding': array([ 1.64213992])}),
#  (u'P41921', {'embedding': array([ 2.50679786])}),
#  (u'P53086', {'embedding': array([-3.56723251])}),
#  (u'P43535', {'embedding': array([ 0.78559536])}),
#  (u'Q03103', {'embedding': array([-3.83927477])}),
#  (u'P38121', {'embedding': array([-5.91322406])}),
#  (u'P01123', {'embedding': array([ 1.92914092])}),
#  (u'P20053', {'embedding': array([ 1.64120931])}),
#  (u'P0CX33', {'embedding': array([-9.50604658])}),
#  (u'P07280', {'embedding': array([ 2.28443281])}),
#  (u'Q06632', {'embedding': array([-1.01665082])}),
#  (u'P41338', {'embedding': array([ 2.07993957])}),
#  (u'Q12317', {'embedding': array([ 1.38906544])}),
#  (u'P11914', {'embedding': array([-5.61111866])}),
#  (u'Q03630', {'embedding': array([ 2.0311453])}),
#  (u'P06839', {'embedding': array([ 0.74324089])}),
#  (u'P06838', {'embedding': array([ 1.38906544])}),
#  (u'P02293', {'embedding': array([-6.77256876])}),
#  (u'P05150', {'embedding': array([-3.89512567])}),
#  (u'P02294', {'embedding': array([ 0.36432441])}),
#  (u'P25719', {'embedding': array([ 3.13786177])}),
#  (u'P28742', {'embedding': array([-4.11452427])}),
#  (u'P30665', {'embedding': array([ 1.96774077])}),
#  (u'P15646', {'embedding': array([ 3.64879876])}),
#  (u'Q12063', {'embedding': array([ 1.94141058])}),
#  (u'P53220', {'embedding': array([ 1.00602904])}),
#  (u'P53221', {'embedding': array([ 2.05958432])}),
#  (u'Q02554', {'embedding': array([ 0.80299276])}),
#  (u'P29295', {'embedding': array([-3.83927477])}),
#  (u'Q12460', {'embedding': array([ 1.66353196])}),
#  (u'P47095', {'embedding': array([ 2.32982633])}),
#  (u'P53228', {'embedding': array([-7.40145903])}),
#  (u'Q05359', {'embedding': array([ 2.32982633])}),
#  (u'Q04636', {'embedding': array([ 1.94141058])}),
#  (u'P0CX55', {'embedding': array([ 2.08761286])}),
#  (u'P0CX56', {'embedding': array([ 1.96339378])}),
#  (u'P0CX50', {'embedding': array([ 2.04833154])}),
#  (u'P0CX51', {'embedding': array([ 2.32982633])}),
#  (u'Q04739', {'embedding': array([-0.87682676])}),
#  (u'P0CX53', {'embedding': array([ 3.15017652])}),
#  (u'P17076', {'embedding': array([ 2.50348123])}),
#  (u'Q08965', {'embedding': array([ 0.79489619])}),
#  (u'P52488', {'embedding': array([ 1.93595652])}),
#  (u'Q04638', {'embedding': array([ 1.64213992])}),
#  (u'P41909', {'embedding': array([ 0.78141984])}),
#  (u'Q99394', {'embedding': array([ 2.70094659])}),
#  (u'P15496', {'embedding': array([-4.70509632])}),
#  (u'P35207', {'embedding': array([ 2.06112495])}),
#  (u'P34760', {'embedding': array([ 1.93025597])}),
#  (u'P41903', {'embedding': array([ 2.10605525])}),
#  (u'Q12347', {'embedding': array([-5.41733024])}),
#  (u'Q06680', {'embedding': array([ 1.43881528])}),
#  (u'P06782', {'embedding': array([-10.15567392])}),
#  (u'P24871', {'embedding': array([ 0.35350198])}),
#  (u'P24870', {'embedding': array([ 1.96935042])}),
#  (u'P08524', {'embedding': array([ 0.86149096])}),
#  (u'Q04226', {'embedding': array([ 1.64295907])}),
#  (u'P38972', {'embedding': array([-5.87555871])}),
#  (u'P36015', {'embedding': array([ 0.24167652])}),
#  (u'P31383', {'embedding': array([-6.81460677])}),
#  (u'Q07938', {'embedding': array([-1.48359433])}),
#  (u'Q03254', {'embedding': array([ 1.94494484])}),
#  (u'P32379', {'embedding': array([-4.68434146])}),
#  (u'Q03920', {'embedding': array([-4.66750428])}),
#  (u'P35169', {'embedding': array([ 3.47485654])}),
#  (u'Q60949', {'embedding': array([ 3.30617464])}),
#  (u'P11792', {'embedding': array([-1.01665082])}),
#  (u'P38961', {'embedding': array([ 2.01021382])}),
#  (u'P19882', {'embedding': array([ 2.08548736])}),
#  (u'Q12220', {'embedding': array([ 2.04797916])}),
#  (u'Q02776', {'embedding': array([-3.09138726])}),
#  (u'P38858', {'embedding': array([-3.83819882])}),
#  (u'P38859', {'embedding': array([-1.97154022])}),
#  (u'P39730', {'embedding': array([ 2.4361818])}),
#  (u'Q12380', {'embedding': array([ 2.05958432])}),
#  (u'Q12672', {'embedding': array([ 1.35004289])}),
#  (u'P38856', {'embedding': array([-7.71438521])}),
#  (u'P38111', {'embedding': array([ 2.68408133])}),
#  (u'P40985', {'embedding': array([ 2.03750659])}),
#  (u'P42836', {'embedding': array([ 2.28443281])}),
#  (u'P38152', {'embedding': array([-5.05382563])}),
#  (u'P38251', {'embedding': array([-1.74358579])}),
#  (u'Q08685', {'embedding': array([ 1.93025597])}),
#  (u'P33755', {'embedding': array([ 1.64213992])}),
#  (u'P29469', {'embedding': array([ 1.66353196])}),
#  (u'P29468', {'embedding': array([ 1.64213992])}),
#  (u'Q12463', {'embedding': array([ 2.92647962])}),
#  (u'Q12051', {'embedding': array([-8.87099617])}),
#  (u'O60200', {'embedding': array([-0.87682676])}),
#  (u'P05319', {'embedding': array([ 1.04422564])}),
#  (u'P36108', {'embedding': array([ 2.92459086])}),
#  (u'Q03667', {'embedding': array([-4.65639616])}),
#  (u'Q08144', {'embedding': array([-0.48782235])}),
#  (u'P32529', {'embedding': array([-9.50604658])}),
#  (u'P00546', {'embedding': array([ 2.40163563])}),
#  (u'P33750', {'embedding': array([ 1.64213992])}),
#  (u'P36100', {'embedding': array([ 1.02329039])}),
#  (u'P32527', {'embedding': array([-4.92965092])}),
#  (u'P32833', {'embedding': array([ 0.80930002])}),
#  (u'P32830', {'embedding': array([ 0.17919553])}),
#  (u'P33448', {'embedding': array([-4.08527306])}),
#  (u'P38930', {'embedding': array([-5.41885966])}),
#  (u'P17505', {'embedding': array([-2.92476723])}),
#  (u'Q12030', {'embedding': array([-2.92476723])}),
#  (u'P35718', {'embedding': array([ 0.79489619])}),
#  (u'P12683', {'embedding': array([ 2.05958432])}),
#  (u'Q00776', {'embedding': array([ 1.64213992])}),
#  (u'P41695', {'embedding': array([ 3.15017652])}),
#  (u'P40066', {'embedding': array([ 1.35250765])}),
#  (u'P38555', {'embedding': array([-5.45849886])}),
#  (u'P51996', {'embedding': array([ 1.32266459])}),
#  (u'Q03957', {'embedding': array([-0.65949414])}),
#  (u'P49955', {'embedding': array([-4.92373418])}),
#  (u'P45818', {'embedding': array([-3.85710855])}),
#  (u'P38604', {'embedding': array([ 1.59074362])}),
#  (u'P12709', {'embedding': array([ 1.64213992])}),
#  (u'Q12136', {'embedding': array([-6.09451047])}),
#  (u'P50278', {'embedding': array([ 1.95030539])}),
#  (u'P24482', {'embedding': array([ 2.03750659])}),
#  (u'Q06224', {'embedding': array([ 1.10617826])}),
#  (u'P10964', {'embedding': array([ 1.64213992])}),
#  (u'Q12482', {'embedding': array([ 1.93280185])}),
#  (u'P10961', {'embedding': array([ 2.04833154])}),
#  (u'Q12481', {'embedding': array([-4.2695859])}),
#  (u'P37291', {'embedding': array([-4.67577114])}),
#  (u'P0CD92', {'embedding': array([-6.55412018])}),
#  (u'P21734', {'embedding': array([-5.64908012])}),
#  (u'P20459', {'embedding': array([ 1.93948963])}),
#  (u'Q12328', {'embedding': array([-5.67555883])}),
#  (u'P33317', {'embedding': array([ 1.66353196])}),
#  (u'P32626', {'embedding': array([ 1.68112431])}),
#  (u'P53867', {'embedding': array([ 2.04833154])}),
#  (u'P53685', {'embedding': array([ 1.26398693])}),
#  (u'Q05776', {'embedding': array([-7.33641962])}),
#  (u'P32628', {'embedding': array([-4.68844778])}),
#  (u'Q06417', {'embedding': array([-0.48782342])}),
#  (u'P05317', {'embedding': array([ 2.09517577])}),
#  (u'P53046', {'embedding': array([-4.02212282])}),
#  (u'P53044', {'embedding': array([ 1.93595652])}),
#  (u'P39525', {'embedding': array([-1.75291885])}),
#  (u'P40362', {'embedding': array([-4.86797588])}),
#  (u'Q04177', {'embedding': array([-7.95178675])}),
#  (u'P30606', {'embedding': array([-4.65938154])}),
#  (u'P32861', {'embedding': array([-5.77226622])}),
#  (u'P38630', {'embedding': array([ 2.16202868])}),
#  (u'Q03028', {'embedding': array([ 1.6785932])}),
#  (u'P11412', {'embedding': array([ 2.92459086])}),
#  (u'Q08826', {'embedding': array([ 0.24167652])}),
#  (u'P00359', {'embedding': array([ 1.44404039])}),
#  (u'P21374', {'embedding': array([ 1.83719808])}),
#  (u'Q12017', {'embedding': array([ 1.93595652])}),
#  (u'Q08446', {'embedding': array([ 2.0389474])}),
#  (u'Q06708', {'embedding': array([ 2.32920291])}),
#  (u'P33297', {'embedding': array([ 2.70094659])}),
#  (u'P37366', {'embedding': array([ 1.93025597])}),
#  (u'P33299', {'embedding': array([-5.06184167])}),
#  (u'P38736', {'embedding': array([-0.53306733])}),
#  (u'P43549', {'embedding': array([ 2.46031176])}),
#  (u'P32939', {'embedding': array([ 3.70494439])}),
#  (u'P34247', {'embedding': array([ 1.09745897])}),
#  (u'P42943', {'embedding': array([ 3.30617464])}),
#  (u'P42945', {'embedding': array([ 2.0538498])}),
#  (u'P42944', {'embedding': array([ 1.66353196])}),
#  (u'Q02516', {'embedding': array([ 2.92077027])}),
#  (u'P42949', {'embedding': array([ 1.64213992])}),
#  (u'P50623', {'embedding': array([ 0.91916673])}),
#  (u'Q06078', {'embedding': array([-4.63428967])}),
#  (u'P00175', {'embedding': array([ 2.01021382])}),
#  (u'P53598', {'embedding': array([ 0.6734705])}),
#  (u'P26793', {'embedding': array([ 1.51875174])}),
#  (u'Q08920', {'embedding': array([ 2.84830985])}),
#  (u'P40579', {'embedding': array([ 0.64183194])}),
#  (u'P20457', {'embedding': array([ 3.30371191])}),
#  (u'Q06489', {'embedding': array([ 2.89830952])}),
#  (u'P30620', {'embedding': array([ 2.34251587])}),
#  (u'P40484', {'embedding': array([-5.88479942])}),
#  (u'P40482', {'embedding': array([-3.96022583])}),
#  (u'Q00955', {'embedding': array([ 1.93280185])}),
#  (u'Q99207', {'embedding': array([ 1.93595652])}),
#  (u'P35194', {'embedding': array([-2.230697])}),
#  (u'P80210', {'embedding': array([ 1.93595652])}),
#  (u'P39518', {'embedding': array([-6.24891675])}),
#  (u'P25368', {'embedding': array([ 1.64213992])}),
#  (u'P40561', {'embedding': array([-2.230697])}),
#  (u'P39515', {'embedding': array([ 0.74938903])}),
#  (u'P49090', {'embedding': array([ 3.29128707])}),
#  (u'P38187', {'embedding': array([ 0.57344193])}),
#  (u'P38182', {'embedding': array([-4.66147706])}),
#  (u'P49095', {'embedding': array([-0.49155164])}),
#  (u'Q03071', {'embedding': array([-5.45849886])}),
#  (u'P32573', {'embedding': array([ 2.01021382])}),
#  (u'Q99297', {'embedding': array([-4.68166135])}),
#  (u'Q06005', {'embedding': array([ 0.91612478])}),
#  (u'P53290', {'embedding': array([-1.72704361])}),
#  (u'P27466', {'embedding': array([ 1.64213992])}),
#  (u'P53299', {'embedding': array([ 1.08057221])}),
#  (u'P52286', {'embedding': array([-4.08527306])}),
#  (u'Q12189', {'embedding': array([-4.68434146])}),
#  (u'P19454', {'embedding': array([ 1.66353196])}),
#  (u'Q04120', {'embedding': array([ 1.95378884])}),
#  (u'P35127', {'embedding': array([ 2.04797916])}),
#  (u'P08432', {'embedding': array([ 2.68100701])}),
#  (u'P38207', {'embedding': array([-4.0715906])}),
#  (u'P32469', {'embedding': array([-4.58829618])}),
#  (u'P38203', {'embedding': array([ 3.47391654])}),
#  (u'P09440', {'embedding': array([-5.75392915])}),
#  (u'Q3E7Y3', {'embedding': array([ 2.08761286])}),
#  (u'P53337', {'embedding': array([-0.28256408])}),
#  (u'P47047', {'embedding': array([-3.83819882])}),
#  (u'Q05498', {'embedding': array([ 0.961235])}),
#  (u'P47045', {'embedding': array([ 2.92459086])}),
#  (u'P12904', {'embedding': array([ 1.94141058])}),
#  (u'Q12344', {'embedding': array([-5.41733024])}),
#  (u'Q02207', {'embedding': array([-3.50006648])}),
#  (u'Q03677', {'embedding': array([ 1.00624385])}),
#  (u'Q02201', {'embedding': array([ 1.97670989])}),
#  (u'P06701', {'embedding': array([ 2.04833154])}),
#  (u'P05739', {'embedding': array([ 2.62981133])}),
#  (u'P38891', {'embedding': array([ 2.0057102])}),
#  (u'Q08645', {'embedding': array([ 1.93280185])}),
#  (u'P07702', {'embedding': array([-2.60768947])}),
#  (u'P07703', {'embedding': array([-0.24696478])}),
#  (u'P53507', {'embedding': array([ 0.71305447])}),
#  (u'P32775', {'embedding': array([ 1.9945765])}),
#  (u'Q6Q560', {'embedding': array([-3.83819882])}),
#  (u'P46969', {'embedding': array([-0.87638508])}),
#  (u'P27472', {'embedding': array([ 2.50978653])}),
#  (u'Q08649', {'embedding': array([-0.48410246])}),
#  (u'Q08723', {'embedding': array([-8.47815633])}),
#  (u'Q03280', {'embedding': array([ 1.66353196])}),
#  (u'P38110', {'embedding': array([ 1.35004289])}),
#  (u'Q00416', {'embedding': array([ 1.35004289])}),
#  (u'P29704', {'embedding': array([ 1.35004289])}),
#  (u'P39516', {'embedding': array([ 0.0040086])}),
#  (u'P06704', {'embedding': array([ 1.35004289])}),
#  (u'Q06679', {'embedding': array([-4.97600032])}),
#  (u'P19414', {'embedding': array([-2.90533409])}),
#  (u'P40029', {'embedding': array([-0.53306733])}),
#  (u'P09201', {'embedding': array([ 3.13786177])}),
#  (u'P42841', {'embedding': array([ 1.86617232])}),
#  (u'P25043', {'embedding': array([ 0.17919553])}),
#  (u'P31378', {'embedding': array([ 2.32982633])}),
#  (u'P33401', {'embedding': array([-5.17467985])}),
#  (u'P16892', {'embedding': array([ 2.52583884])}),
#  (u'P0CX52', {'embedding': array([ 2.76379005])}),
#  (u'P35196', {'embedding': array([ 1.93595652])}),
#  (u'P35197', {'embedding': array([-4.62279149])}),
#  (u'P20606', {'embedding': array([-4.92965092])}),
#  (u'P43621', {'embedding': array([ 1.50542259])}),
#  (u'P04456', {'embedding': array([ 1.66353196])}),
#  (u'P23254', {'embedding': array([ 2.05449802])}),
#  (u'P18544', {'embedding': array([ 2.0671517])}),
#  (u'P40089', {'embedding': array([ 2.50348123])}),
#  (u'P00950', {'embedding': array([-4.66147706])}),
#  (u'P34111', {'embedding': array([ 1.66353196])}),
#  (u'P23255', {'embedding': array([-6.09451047])}),
#  (u'P47037', {'embedding': array([ 2.50679786])}),
#  (u'P49435', {'embedding': array([ 1.3415327])}),
#  (u'P10566', {'embedding': array([ 2.03750659])}),
#  (u'P0CX23', {'embedding': array([ 2.02540983])}),
#  (u'Q06819', {'embedding': array([ 1.66353196])}),
#  (u'P40413', {'embedding': array([ 1.93595652])}),
#  (u'Q01574', {'embedding': array([ 2.01021382])}),
#  (u'Q02336', {'embedding': array([ 2.02698757])}),
#  (u'P40055', {'embedding': array([-10.71906269])}),
#  (u'P45976', {'embedding': array([-4.68434146])}),
#  (u'P14681', {'embedding': array([ 1.64213992])}),
#  (u'P32349', {'embedding': array([-5.39473129])}),
#  (u'P04037', {'embedding': array([ 2.08548736])}),
#  (u'P32464', {'embedding': array([-3.80214051])}),
#  (u'P25358', {'embedding': array([ 2.05958432])}),
#  (u'P40562', {'embedding': array([ 1.96971074])}),
#  (u'P39014', {'embedding': array([ 1.66353196])}),
#  (u'P40857', {'embedding': array([ 2.62981133])}),
#  (u'P40327', {'embedding': array([ 1.35832516])}),
#  (u'P32572', {'embedding': array([ 1.66353196])}),
#  (u'P32908', {'embedding': array([ 1.93595652])}),
#  (u'P09064', {'embedding': array([ 1.64213992])}),
#  (u'P0CX48', {'embedding': array([ 3.61211232])}),
#  (u'P22336', {'embedding': array([ 2.92459086])}),
#  (u'P15454', {'embedding': array([ 1.94296239])}),
#  (u'P53941', {'embedding': array([ 0.10878009])}),
#  (u'Q01477', {'embedding': array([ 2.04797916])}),
#  (u'P17695', {'embedding': array([-9.59182306])}),
#  (u'Q12287', {'embedding': array([-0.18962228])}),
#  (u'Q86TI0', {'embedding': array([ 0.24167652])}),
#  (u'P23724', {'embedding': array([ 0.24167652])}),
#  (u'P32474', {'embedding': array([ 2.32982633])}),
#  (u'P07260', {'embedding': array([-5.24891986])}),
#  (u'P47160', {'embedding': array([-2.60768947])}),
#  (u'P32473', {'embedding': array([ 1.80510456])}),
#  (u'P53973', {'embedding': array([ 3.13786177])}),
#  (u'P54115', {'embedding': array([ 4.17872962])}),
#  (u'Q00684', {'embedding': array([ 1.12027005])}),
#  (u'P51862', {'embedding': array([ 1.51875174])}),
#  (u'Q06217', {'embedding': array([-3.02904148])}),
#  (u'P0CH09', {'embedding': array([ 2.32982633])}),
#  (u'P0CH08', {'embedding': array([ 1.95586373])}),
#  (u'P38286', {'embedding': array([-4.22510144])}),
#  (u'P18759', {'embedding': array([ 1.66353196])}),
#  (u'P38990', {'embedding': array([ 0.89959754])}),
#  (u'P04397', {'embedding': array([ 1.92914092])}),
#  (u'Q12004', {'embedding': array([ 1.12062341])}),
#  (u'P40348', {'embedding': array([ 1.60757891])}),
#  (u'P12695', {'embedding': array([ 2.0057102])}),
#  (u'P11154', {'embedding': array([ 2.76379005])}),
#  (u'Q04924', {'embedding': array([ 2.7641475])}),
#  (u'P32875', {'embedding': array([ 1.10883951])}),
#  (u'P28272', {'embedding': array([-0.25823414])}),
#  (u'P39083', {'embedding': array([ 2.32982633])}),
#  (u'P12753', {'embedding': array([-2.60768947])}),
#  (u'P14680', {'embedding': array([ 2.62981133])}),
#  (u'P23180', {'embedding': array([-2.026244])}),
#  (u'P37898', {'embedding': array([ 0.20016066])}),
#  (u'P54838', {'embedding': array([-3.83819882])}),
#  (u'P54839', {'embedding': array([ 1.26787276])}),
#  (u'P50102', {'embedding': array([ 2.32982633])}),
#  (u'P54837', {'embedding': array([ 2.03518711])}),
#  (u'P38792', {'embedding': array([ 2.32982633])}),
#  (u'P39953', {'embedding': array([ 2.82503717])}),
#  (u'P53309', {'embedding': array([-5.03763225])}),
#  (u'P22209', {'embedding': array([ 3.15017652])}),
#  (u'P43570', {'embedding': array([ 1.05405059])}),
#  (u'P40352', {'embedding': array([ 1.93595652])}),
#  (u'P08018', {'embedding': array([ 1.10883951])}),
#  (u'P15442', {'embedding': array([ 1.93595652])}),
#  (u'P40217', {'embedding': array([ 1.93595652])}),
#  (u'P38715', {'embedding': array([ 2.32982633])}),
#  (u'P12887', {'embedding': array([ 2.03018937])}),
#  (u'P04786', {'embedding': array([ 1.85549014])}),
#  (u'P40212', {'embedding': array([ 1.72413477])}),
#  (u'P39944', {'embedding': array([ 0.79489619])}),
#  (u'P06773', {'embedding': array([-6.32354837])}),
#  (u'P38701', {'embedding': array([ 3.47481559])}),
#  (u'P04147', {'embedding': array([ 0.70649549])}),
#  (u'P53090', {'embedding': array([ 2.04833154])}),
#  (u'P41735', {'embedding': array([ 2.32982633])}),
#  (u'Q07530', {'embedding': array([ 2.32920291])}),
#  (u'P40525', {'embedding': array([ 2.52830821])}),
#  (u'P38065', {'embedding': array([-4.69269945])}),
#  (u'P53197', {'embedding': array([ 1.68112431])}),
#  (u'Q05911', {'embedding': array([-6.06658961])}),
#  (u'P53394', {'embedding': array([ 3.13837172])}),
#  (u'P38853', {'embedding': array([ 1.92799259])}),
#  (u'P43639', {'embedding': array([ 1.54967398])}),
#  (u'P34756', {'embedding': array([ 1.64213992])}),
#  (u'Q06147', {'embedding': array([ 1.92914092])}),
#  (u'P38128', {'embedding': array([ 1.80928054])}),
#  (u'P38129', {'embedding': array([ 2.63205838])}),
#  (u'P47083', {'embedding': array([-4.96643412])}),
#  (u'Q06143', {'embedding': array([ 2.02814923])}),
#  (u'P13259', {'embedding': array([ 0.9613382])}),
#  (u'Q12306', {'embedding': array([ 2.50423229])}),
#  (u'P54780', {'embedding': array([-3.83927477])}),
#  (u'Q06625', {'embedding': array([-5.03698081])}),
#  (u'P19146', {'embedding': array([-1.08737441])}),
#  (u'P54784', {'embedding': array([ 1.66353196])}),
#  (u'P33301', {'embedding': array([ 2.92647962])}),
#  (u'P00044', {'embedding': array([-4.97833482])}),
#  (u'P54787', {'embedding': array([ 2.54693411])}),
#  (u'P42837', {'embedding': array([ 0.84008472])}),
#  (u'P30656', {'embedding': array([ 1.71007834])}),
#  (u'P48445', {'embedding': array([-5.07798551])}),
#  (u'P47771', {'embedding': array([ 0.83129058])}),
#  (u'Q08214', {'embedding': array([ 1.64213992])}),
#  (u'P53549', {'embedding': array([-8.46412134])}),
#  (u'P15700', {'embedding': array([ 2.05958432])}),
#  (u'P25364', {'embedding': array([-2.92438891])}),
#  (u'P0CX43', {'embedding': array([ 2.50978653])}),
#  (u'P0CX42', {'embedding': array([ 2.32982633])}),
#  (u'P0CX41', {'embedding': array([-10.71906269])}),
#  ...]

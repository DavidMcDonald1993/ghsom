# %%
library(GO.db)
library(topGO)
library(GOSim)
library(org.Sc.sgd.db)
library(igraph)
# Out:
# Loading required package: AnnotationDbi
# Loading required package: stats4
# Loading required package: BiocGenerics
# Loading required package: parallel
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, cbind, colnames, do.call,
#     duplicated, eval, evalq, Filter, Find, get, grep, grepl, intersect,
#     is.unsorted, lapply, lengths, Map, mapply, match, mget, order,
#     paste, pmax, pmax.int, pmin, pmin.int, Position, rank, rbind,
#     Reduce, rownames, sapply, setdiff, sort, table, tapply, union,
#     unique, unsplit, which, which.max, which.min
#
# Loading required package: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
# Loading required package: IRanges
# Loading required package: S4Vectors
#
# Attaching package: ‘S4Vectors’
#
# The following objects are masked from ‘package:base’:
#
#     colMeans, colSums, expand.grid, rowMeans, rowSums
#
#
# Loading required package: graph
# Loading required package: SparseM
#
# Attaching package: ‘SparseM’
#
# The following object is masked from ‘package:base’:
#
#     backsolve
#
#
# groupGOTerms: 	GOBPTerm, GOMFTerm, GOCCTerm environments built.
#
# Attaching package: ‘topGO’
#
# The following object is masked from ‘package:IRanges’:
#
#     members
#
# Loading required package: annotate
# Loading required package: XML
#
# Attaching package: ‘XML’
#
# The following object is masked from ‘package:graph’:
#
#     addNode
#
#
#
#
# Attaching package: ‘igraph’
#
# The following objects are masked from ‘package:topGO’:
#
#     algorithm, graph
#
# The following objects are masked from ‘package:graph’:
#
#     degree, edges, intersection, union
#
# The following objects are masked from ‘package:IRanges’:
#
#     simplify, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     compare, union
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     normalize, union
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
# The following object is masked from ‘package:base’:
#
#     union

# %%
file <- "yeast_uetz"

ont <- "BP"
p <- 0.5
init <- 1

db <- org.Sc.sgd.db
mapping <- "org.Sc.sgd.db"
ID <- "ENSEMBL"

##load all community gene lists
setwd(sprintf("/home/david/Documents/ghsom/%s_hierarchy_communities_%s_%s", file, p, init))

setOntology(ont, loadIC=TRUE)
setEvidenceLevel(evidences="all",organism=org.Sc.sgdORGANISM, gomap=org.Sc.sgdGO)
# Out:
# initializing GOSim package ...
# -> retrieving GO information for all available genes for organism 'human' in GO database
# -> filtering GO terms according to evidence levels 'all'
# -> loading files with information content for corresponding GO category (human)
# finished.
# -> loading files with information content for corresponding GO category (human)
# -> retrieving GO information for all available genes for organism 'Saccharomyces cerevisiae' in GO database
# -> filtering GO terms according to evidence levels 'all'

# %%
generateMap <- function(filename){
    map <- as.matrix(read.csv(filename, sep=",", header = F))
    communities <- map[,1]
    map <- map[,2:ncol(map)]
    rownames(map) <- communities
    colnames(map) <- communities
    return (map)
}

# %%
#background gene list
backgroundFilename <- "all_genes.txt"
allGenes <- scan(backgroundFilename, character())

#shortest path files
shortestPathFiles  <- list.files(pattern="*shortest_path*")

#shortest paths list
shortestPaths <- sapply(shortestPathFiles, generateMap)
names(shortestPaths) <- sapply(names(shortestPaths), function(name) strsplit(name, "_")[[1]][[1]])

#communitiy assignemtns
assignments <- as.matrix(read.csv("assignment_matrix.txt", sep=",", header=F))
rownames(assignments) <- allGenes
colnames <- sapply(1:ncol(assignments), function(i) as.character(i-1))
colnames(assignments) <- colnames

# %%
getDepth <- function(com) {
    return(which(apply(assignments, 2, function(i) any(i == com))))
}

getGenes <- function(com){
    return(names(which(assignments[,getDepth(com)] == com)))
}

getSubCommunities <- function(com){
    return(try(as.character(unique(assignments[getGenes(com), getDepth(com) + 1]))))
}

getSuperCommunity <- function(com){
    return(try(as.character(unique(assignments[getGenes(com), getDepth(com) - 1]))))
}

getShortestPath <- function(com){
    return (try(shortestPaths[[com]]))
}

# %%
enrichmentResults <- sapply(2:max(assignments), function(i) 
    GOenrichment(getGenes(i), allGenes, cutoff=0.05, method="weight01"))
# Out:
# Building most specific GOs .....
# 	( 572 GO terms found. )
#
# Build GO DAG topology ..........
# 	( 1848 GO terms and 4082 relations. )
#
# Annotating nodes ...............
# 	( 252 genes annotated to the GO terms. )
#
# 			 -- Weight01 Algorithm --
#
# 		 the algorithm is scoring 561 nontrivial nodes
# 		 parameters:
# 			 test statistic: fisher
#
# 	 Level 14:	1 nodes to be scored	(0 eliminated genes)
#
# 	 Level 13:	10 nodes to be scored	(0 eliminated genes)
#
# 	 Level 12:	23 nodes to be scored	(6 eliminated genes)
#
# 	 Level 11:	33 nodes to be scored	(21 eliminated genes)
#
# 	 Level 10:	45 nodes to be scored	(49 eliminated genes)
#
# 	 Level 9:	53 nodes to be scored	(74 eliminated genes)
#
# 	 Level 8:	61 nodes to be scored	(89 eliminated genes)
#
# 	 Level 7:	64 nodes to be scored	(118 eliminated genes)
#
# 	 Level 6:	92 nodes to be scored	(159 eliminated genes)
#
# 	 Level 5:	86 nodes to be scored	(182 eliminated genes)
#
# 	 Level 4:	58 nodes to be scored	(205 eliminated genes)
#
# 	 Level 3:	26 nodes to be scored	(221 eliminated genes)
#
# 	 Level 2:	8 nodes to be scored	(229 eliminated genes)
#
# 	 Level 1:	1 nodes to be scored	(232 eliminated genes)
#
# Building most specific GOs .....
# 	( 572 GO terms found. )
#
# Build GO DAG topology ..........
# 	( 1848 GO terms and 4082 relations. )
#
# Annotating nodes ...............
# 	( 252 genes annotated to the GO terms. )
#
# 			 -- Weight01 Algorithm --
#
# 		 the algorithm is scoring 851 nontrivial nodes
# 		 parameters:
# 			 test statistic: fisher
#
# 	 Level 16:	2 nodes to be scored	(0 eliminated genes)
#
# 	 Level 15:	6 nodes to be scored	(0 eliminated genes)
#
# 	 Level 14:	18 nodes to be scored	(2 eliminated genes)
#
# 	 Level 13:	26 nodes to be scored	(11 eliminated genes)
#
# 	 Level 12:	31 nodes to be scored	(21 eliminated genes)
#
# 	 Level 11:	39 nodes to be scored	(42 eliminated genes)
#
# 	 Level 10:	56 nodes to be scored	(73 eliminated genes)
#
# 	 Level 9:	91 nodes to be scored	(90 eliminated genes)
#
# 	 Level 8:	106 nodes to be scored	(105 eliminated genes)
#
# 	 Level 7:	109 nodes to be scored	(123 eliminated genes)
#
# 	 Level 6:	129 nodes to be scored	(151 eliminated genes)
#
# 	 Level 5:	120 nodes to be scored	(186 eliminated genes)
#
# 	 Level 4:	74 nodes to be scored	(209 eliminated genes)
#
# 	 Level 3:	32 nodes to be scored	(224 eliminated genes)
#
# 	 Level 2:	11 nodes to be scored	(230 eliminated genes)
#
# 	 Level 1:	1 nodes to be scored	(232 eliminated genes)
#
# Building most specific GOs .....
# 	( 572 GO terms found. )
#
# Build GO DAG topology ..........
# 	( 1848 GO terms and 4082 relations. )
#
# Annotating nodes ...............
# 	( 252 genes annotated to the GO terms. )
#
# 			 -- Weight01 Algorithm --
#
# 		 the algorithm is scoring 557 nontrivial nodes
# 		 parameters:
# 			 test statistic: fisher
#
# 	 Level 13:	5 nodes to be scored	(0 eliminated genes)
#
# 	 Level 12:	14 nodes to be scored	(0 eliminated genes)
#
# 	 Level 11:	21 nodes to be scored	(8 eliminated genes)
#
# 	 Level 10:	35 nodes to be scored	(48 eliminated genes)
#
# 	 Level 9:	55 nodes to be scored	(69 eliminated genes)
#
# 	 Level 8:	58 nodes to be scored	(90 eliminated genes)
#
# 	 Level 7:	79 nodes to be scored	(122 eliminated genes)
#
# 	 Level 6:	82 nodes to be scored	(146 eliminated genes)
#
# 	 Level 5:	95 nodes to be scored	(189 eliminated genes)
#
# 	 Level 4:	67 nodes to be scored	(203 eliminated genes)
#
# 	 Level 3:	33 nodes to be scored	(218 eliminated genes)
#
# 	 Level 2:	12 nodes to be scored	(225 eliminated genes)
#
# 	 Level 1:	1 nodes to be scored	(232 eliminated genes)
#
# Building most specific GOs .....
# 	( 572 GO terms found. )
#
# Build GO DAG topology ..........
# 	( 1848 GO terms and 4082 relations. )
#
# Annotating nodes ...............
# 	( 252 genes annotated to the GO terms. )
#
# 			 -- Weight01 Algorithm --
#
# 		 the algorithm is scoring 586 nontrivial nodes
# 		 parameters:
# 			 test statistic: fisher
#
# 	 Level 15:	2 nodes to be scored	(0 eliminated genes)
#
# 	 Level 14:	8 nodes to be scored	(0 eliminated genes)
#
# 	 Level 13:	12 nodes to be scored	(3 eliminated genes)
#
# 	 Level 12:	15 nodes to be scored	(11 eliminated genes)
#
# 	 Level 11:	26 nodes to be scored	(28 eliminated genes)
#
# 	 Level 10:	31 nodes to be scored	(52 eliminated genes)
#
# 	 Level 9:	50 nodes to be scored	(65 eliminated genes)
#
# 	 Level 8:	61 nodes to be scored	(85 eliminated genes)
#
# 	 Level 7:	74 nodes to be scored	(114 eliminated genes)
#
# 	 Level 6:	97 nodes to be scored	(140 eliminated genes)
#
# 	 Level 5:	97 nodes to be scored	(170 eliminated genes)
#
# 	 Level 4:	68 nodes to be scored	(204 eliminated genes)
#
# 	 Level 3:	31 nodes to be scored	(218 eliminated genes)
#
# 	 Level 2:	13 nodes to be scored	(225 eliminated genes)
#
# 	 Level 1:	1 nodes to be scored	(232 eliminated genes)
#
# Building most specific GOs .....
# 	( 572 GO terms found. )
#
# Build GO DAG topology ..........
# 	( 1848 GO terms and 4082 relations. )
#
# Annotating nodes ...............
# 	( 252 genes annotated to the GO terms. )
#
# 			 -- Weight01 Algorithm --
#
# 		 the algorithm is scoring 806 nontrivial nodes
# 		 parameters:
# 			 test statistic: fisher
#
# 	 Level 16:	1 nodes to be scored	(0 eliminated genes)
#
# 	 Level 15:	4 nodes to be scored	(0 eliminated genes)
#
# 	 Level 14:	7 nodes to be scored	(1 eliminated genes)
#
# 	 Level 13:	12 nodes to be scored	(4 eliminated genes)
#
# 	 Level 12:	21 nodes to be scored	(7 eliminated genes)
#
# 	 Level 11:	36 nodes to be scored	(29 eliminated genes)
#
# 	 Level 10:	70 nodes to be scored	(46 eliminated genes)
#
# 	 Level 9:	88 nodes to be scored	(76 eliminated genes)
#
# 	 Level 8:	87 nodes to be scored	(101 eliminated genes)
#
# 	 Level 7:	104 nodes to be scored	(134 eliminated genes)
#
# 	 Level 6:	125 nodes to be scored	(172 eliminated genes)
#
# 	 Level 5:	123 nodes to be scored	(197 eliminated genes)
#
# 	 Level 4:	84 nodes to be scored	(216 eliminated genes)
#
# 	 Level 3:	31 nodes to be scored	(221 eliminated genes)
#
# 	 Level 2:	12 nodes to be scored	(229 eliminated genes)
#
# 	 Level 1:	1 nodes to be scored	(232 eliminated genes)
#
# Building most specific GOs .....
# 	( 572 GO terms found. )
#
# Build GO DAG topology ..........
# 	( 1848 GO terms and 4082 relations. )
#
# Annotating nodes ...............
# 	( 252 genes annotated to the GO terms. )
#
# 			 -- Weight01 Algorithm --
#
# 		 the algorithm is scoring 619 nontrivial nodes
# 		 parameters:
# 			 test statistic: fisher
#
# 	 Level 15:	3 nodes to be scored	(0 eliminated genes)
#
# 	 Level 14:	4 nodes to be scored	(0 eliminated genes)
#
# 	 Level 13:	11 nodes to be scored	(6 eliminated genes)
#
# 	 Level 12:	23 nodes to be scored	(8 eliminated genes)
#
# 	 Level 11:	31 nodes to be scored	(32 eliminated genes)
#
# 	 Level 10:	41 nodes to be scored	(60 eliminated genes)
#
# 	 Level 9:	64 nodes to be scored	(82 eliminated genes)
#
# 	 Level 8:	73 nodes to be scored	(109 eliminated genes)
#
# 	 Level 7:	75 nodes to be scored	(134 eliminated genes)
#
# 	 Level 6:	90 nodes to be scored	(161 eliminated genes)
#
# 	 Level 5:	93 nodes to be scored	(184 eliminated genes)
#
# 	 Level 4:	66 nodes to be scored	(196 eliminated genes)
#
# 	 Level 3:	32 nodes to be scored	(218 eliminated genes)
#
# 	 Level 2:	12 nodes to be scored	(228 eliminated genes)
#
# 	 Level 1:	1 nodes to be scored	(232 eliminated genes)
#
# Building most specific GOs .....
# 	( 572 GO terms found. )
#
# Build GO DAG topology ..........
# 	( 1848 GO terms and 4082 relations. )
#
# Annotating nodes ...............
# 	( 252 genes annotated to the GO terms. )
#
# 			 -- Weight01 Algorithm --
#
# 		 the algorithm is scoring 407 nontrivial nodes
# 		 parameters:
# 			 test statistic: fisher
#
# 	 Level 14:	2 nodes to be scored	(0 eliminated genes)
#
# 	 Level 13:	8 nodes to be scored	(0 eliminated genes)
#
# 	 Level 12:	16 nodes to be scored	(3 eliminated genes)
#
# 	 Level 11:	23 nodes to be scored	(9 eliminated genes)
#
# 	 Level 10:	32 nodes to be scored	(40 eliminated genes)
#
# 	 Level 9:	45 nodes to be scored	(75 eliminated genes)
#
# 	 Level 8:	37 nodes to be scored	(94 eliminated genes)
#
# 	 Level 7:	34 nodes to be scored	(103 eliminated genes)
#
# 	 Level 6:	57 nodes to be scored	(128 eliminated genes)
#
# 	 Level 5:	74 nodes to be scored	(170 eliminated genes)
#
# 	 Level 4:	48 nodes to be scored	(193 eliminated genes)
#
# 	 Level 3:	21 nodes to be scored	(215 eliminated genes)
#
# 	 Level 2:	9 nodes to be scored	(228 eliminated genes)
#
# 	 Level 1:	1 nodes to be scored	(231 eliminated genes)
#
# Building most specific GOs .....
# 	( 572 GO terms found. )
#
# Build GO DAG topology ..........
# 	( 1848 GO terms and 4082 relations. )
#
# Annotating nodes ...............
# 	( 252 genes annotated to the GO terms. )
#
# 			 -- Weight01 Algorithm --
#
# 		 the algorithm is scoring 256 nontrivial nodes
# 		 parameters:
# 			 test statistic: fisher
#
# 	 Level 12:	5 nodes to be scored	(0 eliminated genes)
#
# 	 Level 11:	7 nodes to be scored	(0 eliminated genes)
#
# 	 Level 10:	10 nodes to be scored	(24 eliminated genes)
#
# 	 Level 9:	17 nodes to be scored	(52 eliminated genes)
#
# 	 Level 8:	21 nodes to be scored	(59 eliminated genes)
#
# 	 Level 7:	31 nodes to be scored	(76 eliminated genes)
#
# 	 Level 6:	41 nodes to be scored	(100 eliminated genes)
#
# 	 Level 5:	48 nodes to be scored	(145 eliminated genes)
#
# 	 Level 4:	41 nodes to be scored	(182 eliminated genes)
#
# 	 Level 3:	24 nodes to be scored	(206 eliminated genes)
#
# 	 Level 2:	10 nodes to be scored	(218 eliminated genes)
#
# 	 Level 1:	1 nodes to be scored	(230 eliminated genes)
#
# Building most specific GOs .....
# 	( 572 GO terms found. )
#
# Build GO DAG topology ..........
# 	( 1848 GO terms and 4082 relations. )
#
# Annotating nodes ...............
# 	( 252 genes annotated to the GO terms. )
#
# 			 -- Weight01 Algorithm --
#
# 		 the algorithm is scoring 212 nontrivial nodes
# 		 parameters:
# 			 test statistic: fisher
#
# 	 Level 13:	1 nodes to be scored	(0 eliminated genes)
#
# 	 Level 12:	3 nodes to be scored	(0 eliminated genes)
#
# 	 Level 11:	6 nodes to be scored	(2 eliminated genes)
#
# 	 Level 10:	15 nodes to be scored	(5 eliminated genes)
#
# 	 Level 9:	19 nodes to be scored	(12 eliminated genes)
#
# 	 Level 8:	18 nodes to be scored	(24 eliminated genes)
#
# 	 Level 7:	20 nodes to be scored	(33 eliminated genes)
#
# 	 Level 6:	27 nodes to be scored	(72 eliminated genes)
#
# 	 Level 5:	41 nodes to be scored	(89 eliminated genes)
#
# 	 Level 4:	35 nodes to be scored	(144 eliminated genes)
#
# 	 Level 3:	19 nodes to be scored	(194 eliminated genes)
#
# 	 Level 2:	7 nodes to be scored	(220 eliminated genes)
#
# 	 Level 1:	1 nodes to be scored	(231 eliminated genes)
#
# Building most specific GOs .....
# 	( 572 GO terms found. )
#
# Build GO DAG topology ..........
# 	( 1848 GO terms and 4082 relations. )
#
# Annotating nodes ...............
# 	( 252 genes annotated to the GO terms. )
#
# 			 -- Weight01 Algorithm --
#
# 		 the algorithm is scoring 270 nontrivial nodes
# 		 parameters:
# 			 test statistic: fisher
#
# 	 Level 13:	2 nodes to be scored	(0 eliminated genes)
#
# 	 Level 12:	7 nodes to be scored	(0 eliminated genes)
#
# 	 Level 11:	9 nodes to be scored	(2 eliminated genes)
#
# 	 Level 10:	11 nodes to be scored	(38 eliminated genes)
#
# 	 Level 9:	18 nodes to be scored	(59 eliminated genes)
#
# 	 Level 8:	18 nodes to be scored	(73 eliminated genes)
#
# 	 Level 7:	27 nodes to be scored	(79 eliminated genes)
#
# 	 Level 6:	39 nodes to be scored	(102 eliminated genes)
#
# 	 Level 5:	57 nodes to be scored	(141 eliminated genes)
#
# 	 Level 4:	43 nodes to be scored	(182 eliminated genes)
#
# 	 Level 3:	27 nodes to be scored	(210 eliminated genes)
#
# 	 Level 2:	11 nodes to be scored	(221 eliminated genes)
#
# 	 Level 1:	1 nodes to be scored	(232 eliminated genes)
#
# Building most specific GOs .....
# 	( 572 GO terms found. )
#
# Build GO DAG topology ..........
# 	( 1848 GO terms and 4082 relations. )
#
# Annotating nodes ...............
# 	( 252 genes annotated to the GO terms. )
#
# 			 -- Weight01 Algorithm --
#
# 		 the algorithm is scoring 163 nontrivial nodes
# 		 parameters:
# 			 test statistic: fisher
#
# 	 Level 13:	1 nodes to be scored	(0 eliminated genes)
#
# 	 Level 12:	1 nodes to be scored	(0 eliminated genes)
#
# 	 Level 11:	3 nodes to be scored	(2 eliminated genes)
#
# 	 Level 10:	7 nodes to be scored	(2 eliminated genes)
#
# 	 Level 9:	11 nodes to be scored	(3 eliminated genes)
#
# 	 Level 8:	14 nodes to be scored	(11 eliminated genes)
#
# 	 Level 7:	21 nodes to be scored	(15 eliminated genes)
#
# 	 Level 6:	20 nodes to be scored	(25 eliminated genes)
#
# 	 Level 5:	31 nodes to be scored	(59 eliminated genes)
#
# 	 Level 4:	25 nodes to be scored	(129 eliminated genes)
#
# 	 Level 3:	19 nodes to be scored	(162 eliminated genes)
#
# 	 Level 2:	9 nodes to be scored	(202 eliminated genes)
#
# 	 Level 1:	1 nodes to be scored	(231 eliminated genes)
#
# Building most specific GOs .....
# 	( 572 GO terms found. )
#
# Build GO DAG topology ..........
# 	( 1848 GO terms and 4082 relations. )
#
# Annotating nodes ...............
# 	( 252 genes annotated to the GO terms. )
#
# 			 -- Weight01 Algorithm --
#
# 		 the algorithm is scoring 103 nontrivial nodes
# 		 parameters:
# 			 test statistic: fisher
#
# 	 Level 13:	1 nodes to be scored	(0 eliminated genes)
#
# 	 Level 12:	1 nodes to be scored	(0 eliminated genes)
#
# 	 Level 11:	1 nodes to be scored	(2 eliminated genes)
#
# 	 Level 10:	3 nodes to be scored	(2 eliminated genes)
#
# 	 Level 9:	6 nodes to be scored	(2 eliminated genes)
#
# 	 Level 8:	8 nodes to be scored	(5 eliminated genes)
#
# 	 Level 7:	14 nodes to be scored	(17 eliminated genes)
#
# 	 Level 6:	18 nodes to be scored	(24 eliminated genes)
#
# 	 Level 5:	21 nodes to be scored	(84 eliminated genes)
#
# 	 Level 4:	13 nodes to be scored	(130 eliminated genes)
#
# 	 Level 3:	11 nodes to be scored	(175 eliminated genes)
#
# 	 Level 2:	5 nodes to be scored	(207 eliminated genes)
#
# 	 Level 1:	1 nodes to be scored	(223 eliminated genes)
#
# Building most specific GOs .....
# 	( 572 GO terms found. )
#
# Build GO DAG topology ..........
# 	( 1848 GO terms and 4082 relations. )
#
# Annotating nodes ...............
# 	( 252 genes annotated to the GO terms. )
#
# 			 -- Weight01 Algorithm --
#
# 		 the algorithm is scoring 616 nontrivial nodes
# 		 parameters:
# 			 test statistic: fisher
#
# 	 Level 15:	1 nodes to be scored	(0 eliminated genes)
#
# 	 Level 14:	1 nodes to be scored	(0 eliminated genes)
#
# 	 Level 13:	9 nodes to be scored	(2 eliminated genes)
#
# 	 Level 12:	16 nodes to be scored	(3 eliminated genes)
#
# 	 Level 11:	30 nodes to be scored	(21 eliminated genes)
#
# 	 Level 10:	54 nodes to be scored	(43 eliminated genes)
#
# 	 Level 9:	64 nodes to be scored	(72 eliminated genes)
#
# 	 Level 8:	61 nodes to be scored	(91 eliminated genes)
#
# 	 Level 7:	77 nodes to be scored	(120 eliminated genes)
#
# 	 Level 6:	96 nodes to be scored	(152 eliminated genes)
#
# 	 Level 5:	97 nodes to be scored	(191 eliminated genes)
#
# 	 Level 4:	69 nodes to be scored	(209 eliminated genes)
#
# 	 Level 3:	28 nodes to be scored	(219 eliminated genes)
#
# 	 Level 2:	12 nodes to be scored	(226 eliminated genes)
#
# 	 Level 1:	1 nodes to be scored	(232 eliminated genes)
#
# Building most specific GOs .....
# 	( 572 GO terms found. )
#
# Build GO DAG topology ..........
# 	( 1848 GO terms and 4082 relations. )
#
# Annotating nodes ...............
# 	( 252 genes annotated to the GO terms. )
#
# 			 -- Weight01 Algorithm --
#
# 		 the algorithm is scoring 455 nontrivial nodes
# 		 parameters:
# 			 test statistic: fisher
#
# 	 Level 16:	1 nodes to be scored	(0 eliminated genes)
#
# 	 Level 15:	3 nodes to be scored	(0 eliminated genes)
#
# 	 Level 14:	6 nodes to be scored	(1 eliminated genes)
#
# 	 Level 13:	4 nodes to be scored	(2 eliminated genes)
#
# 	 Level 12:	8 nodes to be scored	(4 eliminated genes)
#
# 	 Level 11:	11 nodes to be scored	(22 eliminated genes)
#
# 	 Level 10:	21 nodes to be scored	(36 eliminated genes)
#
# 	 Level 9:	35 nodes to be scored	(54 eliminated genes)
#
# 	 Level 8:	45 nodes to be scored	(63 eliminated genes)
#
# 	 Level 7:	53 nodes to be scored	(84 eliminated genes)
#
# 	 Level 6:	76 nodes to be scored	(111 eliminated genes)
#
# 	 Level 5:	87 nodes to be scored	(159 eliminated genes)
#
# 	 Level 4:	64 nodes to be scored	(200 eliminated genes)
#
# 	 Level 3:	28 nodes to be scored	(215 eliminated genes)
#
# 	 Level 2:	12 nodes to be scored	(226 eliminated genes)
#
# 	 Level 1:	1 nodes to be scored	(232 eliminated genes)
#
# Building most specific GOs .....
# 	( 572 GO terms found. )
#
# Build GO DAG topology ..........
# 	( 1848 GO terms and 4082 relations. )
#
# Annotating nodes ...............
# 	( 252 genes annotated to the GO terms. )
#
# 			 -- Weight01 Algorithm --
#
# 		 the algorithm is scoring 172 nontrivial nodes
# 		 parameters:
# 			 test statistic: fisher
#
# 	 Level 13:	2 nodes to be scored	(0 eliminated genes)
#
# 	 Level 12:	4 nodes to be scored	(0 eliminated genes)
#
# 	 Level 11:	5 nodes to be scored	(2 eliminated genes)
#
# 	 Level 10:	5 nodes to be scored	(33 eliminated genes)
#
# 	 Level 9:	8 nodes to be scored	(47 eliminated genes)
#
# 	 Level 8:	9 nodes to be scored	(47 eliminated genes)
#
# 	 Level 7:	13 nodes to be scored	(49 eliminated genes)
#
# 	 Level 6:	26 nodes to be scored	(73 eliminated genes)
#
# 	 Level 5:	39 nodes to be scored	(111 eliminated genes)
#
# 	 Level 4:	29 nodes to be scored	(151 eliminated genes)
#
# 	 Level 3:	21 nodes to be scored	(190 eliminated genes)
#
# 	 Level 2:	10 nodes to be scored	(206 eliminated genes)
#
# 	 Level 1:	1 nodes to be scored	(225 eliminated genes)
#
# Building most specific GOs .....
# 	( 572 GO terms found. )
#
# Build GO DAG topology ..........
# 	( 1848 GO terms and 4082 relations. )
#
# Annotating nodes ...............
# 	( 252 genes annotated to the GO terms. )
#
# 			 -- Weight01 Algorithm --
#
# 		 the algorithm is scoring 99 nontrivial nodes
# 		 parameters:
# 			 test statistic: fisher
#
# 	 Level 12:	1 nodes to be scored	(0 eliminated genes)
#
# 	 Level 11:	1 nodes to be scored	(0 eliminated genes)
#
# 	 Level 10:	2 nodes to be scored	(1 eliminated genes)
#
# 	 Level 9:	4 nodes to be scored	(7 eliminated genes)
#
# 	 Level 8:	5 nodes to be scored	(15 eliminated genes)
#
# 	 Level 7:	10 nodes to be scored	(16 eliminated genes)
#
# 	 Level 6:	13 nodes to be scored	(43 eliminated genes)
#
# 	 Level 5:	19 nodes to be scored	(65 eliminated genes)
#
# 	 Level 4:	17 nodes to be scored	(117 eliminated genes)
#
# 	 Level 3:	18 nodes to be scored	(188 eliminated genes)
#
# 	 Level 2:	8 nodes to be scored	(213 eliminated genes)
#
# 	 Level 1:	1 nodes to be scored	(232 eliminated genes)
#
# Building most specific GOs .....
# 	( 572 GO terms found. )
#
# Build GO DAG topology ..........
# 	( 1848 GO terms and 4082 relations. )
#
# Annotating nodes ...............
# 	( 252 genes annotated to the GO terms. )
#
# 			 -- Weight01 Algorithm --
#
# 		 the algorithm is scoring 27 nontrivial nodes
# 		 parameters:
# 			 test statistic: fisher
#
# 	 Level 8:	1 nodes to be scored	(0 eliminated genes)
#
# 	 Level 7:	1 nodes to be scored	(0 eliminated genes)
#
# 	 Level 6:	5 nodes to be scored	(1 eliminated genes)
#
# 	 Level 5:	5 nodes to be scored	(11 eliminated genes)
#
# 	 Level 4:	5 nodes to be scored	(88 eliminated genes)
#
# 	 Level 3:	6 nodes to be scored	(146 eliminated genes)
#
# 	 Level 2:	3 nodes to be scored	(173 eliminated genes)
#
# 	 Level 1:	1 nodes to be scored	(197 eliminated genes)
#
# Building most specific GOs .....
# 	( 572 GO terms found. )
#
# Build GO DAG topology ..........
# 	( 1848 GO terms and 4082 relations. )
#
# Annotating nodes ...............
# 	( 252 genes annotated to the GO terms. )
#
# 			 -- Weight01 Algorithm --
#
# 		 the algorithm is scoring 80 nontrivial nodes
# 		 parameters:
# 			 test statistic: fisher
#
# 	 Level 12:	2 nodes to be scored	(0 eliminated genes)
#
# 	 Level 11:	3 nodes to be scored	(0 eliminated genes)
#
# 	 Level 10:	5 nodes to be scored	(4 eliminated genes)
#
# 	 Level 9:	7 nodes to be scored	(6 eliminated genes)
#
# 	 Level 8:	6 nodes to be scored	(22 eliminated genes)
#
# 	 Level 7:	9 nodes to be scored	(26 eliminated genes)
#
# 	 Level 6:	8 nodes to be scored	(28 eliminated genes)
#
# 	 Level 5:	14 nodes to be scored	(33 eliminated genes)
#
# 	 Level 4:	12 nodes to be scored	(43 eliminated genes)
#
# 	 Level 3:	8 nodes to be scored	(127 eliminated genes)
#
# 	 Level 2:	5 nodes to be scored	(182 eliminated genes)
#
# 	 Level 1:	1 nodes to be scored	(216 eliminated genes)
#
# Building most specific GOs .....
# 	( 572 GO terms found. )
#
# Build GO DAG topology ..........
# 	( 1848 GO terms and 4082 relations. )
#
# Annotating nodes ...............
# 	( 252 genes annotated to the GO terms. )
#
# 			 -- Weight01 Algorithm --
#
# 		 the algorithm is scoring 281 nontrivial nodes
# 		 parameters:
# 			 test statistic: fisher
#
# 	 Level 14:	2 nodes to be scored	(0 eliminated genes)
#
# 	 Level 13:	2 nodes to be scored	(0 eliminated genes)
#
# 	 Level 12:	5 nodes to be scored	(2 eliminated genes)
#
# 	 Level 11:	8 nodes to be scored	(21 eliminated genes)
#
# 	 Level 10:	13 nodes to be scored	(35 eliminated genes)
#
# 	 Level 9:	25 nodes to be scored	(51 eliminated genes)
#
# 	 Level 8:	29 nodes to be scored	(54 eliminated genes)
#
# 	 Level 7:	35 nodes to be scored	(72 eliminated genes)
#
# 	 Level 6:	46 nodes to be scored	(99 eliminated genes)
#
# 	 Level 5:	51 nodes to be scored	(134 eliminated genes)
#
# 	 Level 4:	34 nodes to be scored	(182 eliminated genes)
#
# 	 Level 3:	21 nodes to be scored	(206 eliminated genes)
#
# 	 Level 2:	9 nodes to be scored	(225 eliminated genes)
#
# 	 Level 1:	1 nodes to be scored	(231 eliminated genes)
#
# Building most specific GOs .....
# 	( 572 GO terms found. )
#
# Build GO DAG topology ..........
# 	( 1848 GO terms and 4082 relations. )
#
# Annotating nodes ...............
# 	( 252 genes annotated to the GO terms. )
#
# 			 -- Weight01 Algorithm --
#
# 		 the algorithm is scoring 200 nontrivial nodes
# 		 parameters:
# 			 test statistic: fisher
#
# 	 Level 11:	1 nodes to be scored	(0 eliminated genes)
#
# 	 Level 10:	5 nodes to be scored	(0 eliminated genes)
#
# 	 Level 9:	7 nodes to be scored	(1 eliminated genes)
#
# 	 Level 8:	9 nodes to be scored	(6 eliminated genes)
#
# 	 Level 7:	18 nodes to be scored	(16 eliminated genes)
#
# 	 Level 6:	36 nodes to be scored	(20 eliminated genes)
#
# 	 Level 5:	45 nodes to be scored	(90 eliminated genes)
#
# 	 Level 4:	43 nodes to be scored	(156 eliminated genes)
#
# 	 Level 3:	24 nodes to be scored	(201 eliminated genes)
#
# 	 Level 2:	11 nodes to be scored	(220 eliminated genes)
#
# 	 Level 1:	1 nodes to be scored	(231 eliminated genes)
#
# Building most specific GOs .....
# 	( 572 GO terms found. )
#
# Build GO DAG topology ..........
# 	( 1848 GO terms and 4082 relations. )
#
# Annotating nodes ...............
# 	( 252 genes annotated to the GO terms. )
#
# 			 -- Weight01 Algorithm --
#
# 		 the algorithm is scoring 183 nontrivial nodes
# 		 parameters:
# 			 test statistic: fisher
#
# 	 Level 16:	1 nodes to be scored	(0 eliminated genes)
#
# 	 Level 15:	3 nodes to be scored	(0 eliminated genes)
#
# 	 Level 14:	4 nodes to be scored	(1 eliminated genes)
#
# 	 Level 13:	3 nodes to be scored	(2 eliminated genes)
#
# 	 Level 12:	5 nodes to be scored	(2 eliminated genes)
#
# 	 Level 11:	5 nodes to be scored	(16 eliminated genes)
#
# 	 Level 10:	7 nodes to be scored	(29 eliminated genes)
#
# 	 Level 9:	8 nodes to be scored	(46 eliminated genes)
#
# 	 Level 8:	11 nodes to be scored	(49 eliminated genes)
#
# 	 Level 7:	15 nodes to be scored	(53 eliminated genes)
#
# 	 Level 6:	27 nodes to be scored	(69 eliminated genes)
#
# 	 Level 5:	38 nodes to be scored	(132 eliminated genes)
#
# 	 Level 4:	31 nodes to be scored	(161 eliminated genes)
#
# 	 Level 3:	17 nodes to be scored	(191 eliminated genes)
#
# 	 Level 2:	7 nodes to be scored	(205 eliminated genes)
#
# 	 Level 1:	1 nodes to be scored	(225 eliminated genes)
#
# Building most specific GOs .....
# 	( 572 GO terms found. )
#
# Build GO DAG topology ..........
# 	( 1848 GO terms and 4082 relations. )
#
# Annotating nodes ...............
# 	( 252 genes annotated to the GO terms. )
#
# 			 -- Weight01 Algorithm --
#
# 		 the algorithm is scoring 143 nontrivial nodes
# 		 parameters:
# 			 test statistic: fisher
#
# 	 Level 13:	1 nodes to be scored	(0 eliminated genes)
#
# 	 Level 12:	2 nodes to be scored	(0 eliminated genes)
#
# 	 Level 11:	4 nodes to be scored	(1 eliminated genes)
#
# 	 Level 10:	5 nodes to be scored	(27 eliminated genes)
#
# 	 Level 9:	8 nodes to be scored	(47 eliminated genes)
#
# 	 Level 8:	8 nodes to be scored	(47 eliminated genes)
#
# 	 Level 7:	11 nodes to be scored	(49 eliminated genes)
#
# 	 Level 6:	22 nodes to be scored	(72 eliminated genes)
#
# 	 Level 5:	30 nodes to be scored	(109 eliminated genes)
#
# 	 Level 4:	22 nodes to be scored	(148 eliminated genes)
#
# 	 Level 3:	19 nodes to be scored	(176 eliminated genes)
#
# 	 Level 2:	10 nodes to be scored	(190 eliminated genes)
#
# 	 Level 1:	1 nodes to be scored	(223 eliminated genes)
#
# Building most specific GOs .....
# 	( 572 GO terms found. )
#
# Build GO DAG topology ..........
# 	( 1848 GO terms and 4082 relations. )
#
# Annotating nodes ...............
# 	( 252 genes annotated to the GO terms. )
#
# 			 -- Weight01 Algorithm --
#
# 		 the algorithm is scoring 60 nontrivial nodes
# 		 parameters:
# 			 test statistic: fisher
#
# 	 Level 13:	1 nodes to be scored	(0 eliminated genes)
#
# 	 Level 12:	3 nodes to be scored	(0 eliminated genes)
#
# 	 Level 11:	3 nodes to be scored	(1 eliminated genes)
#
# 	 Level 10:	2 nodes to be scored	(30 eliminated genes)
#
# 	 Level 9:	2 nodes to be scored	(44 eliminated genes)
#
# 	 Level 8:	2 nodes to be scored	(44 eliminated genes)
#
# 	 Level 7:	2 nodes to be scored	(44 eliminated genes)
#
# 	 Level 6:	8 nodes to be scored	(46 eliminated genes)
#
# 	 Level 5:	15 nodes to be scored	(78 eliminated genes)
#
# 	 Level 4:	10 nodes to be scored	(102 eliminated genes)
#
# 	 Level 3:	7 nodes to be scored	(136 eliminated genes)
#
# 	 Level 2:	4 nodes to be scored	(177 eliminated genes)
#
# 	 Level 1:	1 nodes to be scored	(211 eliminated genes)
#
# Building most specific GOs .....
# 	( 572 GO terms found. )
#
# Build GO DAG topology ..........
# 	( 1848 GO terms and 4082 relations. )
#
# Annotating nodes ...............
# 	( 252 genes annotated to the GO terms. )
#
# 			 -- Weight01 Algorithm --
#
# 		 the algorithm is scoring 79 nontrivial nodes
# 		 parameters:
# 			 test statistic: fisher
#
# 	 Level 12:	1 nodes to be scored	(0 eliminated genes)
#
# 	 Level 11:	1 nodes to be scored	(0 eliminated genes)
#
# 	 Level 10:	3 nodes to be scored	(3 eliminated genes)
#
# 	 Level 9:	4 nodes to be scored	(3 eliminated genes)
#
# 	 Level 8:	6 nodes to be scored	(4 eliminated genes)
#
# 	 Level 7:	7 nodes to be scored	(6 eliminated genes)
#
# 	 Level 6:	11 nodes to be scored	(26 eliminated genes)
#
# 	 Level 5:	18 nodes to be scored	(51 eliminated genes)
#
# 	 Level 4:	13 nodes to be scored	(83 eliminated genes)
#
# 	 Level 3:	9 nodes to be scored	(171 eliminated genes)
#
# 	 Level 2:	5 nodes to be scored	(196 eliminated genes)
#
# 	 Level 1:	1 nodes to be scored	(219 eliminated genes)
#
# Building most specific GOs .....
# 	( 572 GO terms found. )
#
# Build GO DAG topology ..........
# 	( 1848 GO terms and 4082 relations. )
#
# Annotating nodes ...............
# 	( 252 genes annotated to the GO terms. )
#
# 			 -- Weight01 Algorithm --
#
# 		 the algorithm is scoring 154 nontrivial nodes
# 		 parameters:
# 			 test statistic: fisher
#
# 	 Level 11:	1 nodes to be scored	(0 eliminated genes)
#
# 	 Level 10:	5 nodes to be scored	(0 eliminated genes)
#
# 	 Level 9:	6 nodes to be scored	(1 eliminated genes)
#
# 	 Level 8:	6 nodes to be scored	(6 eliminated genes)
#
# 	 Level 7:	13 nodes to be scored	(12 eliminated genes)
#
# 	 Level 6:	26 nodes to be scored	(15 eliminated genes)
#
# 	 Level 5:	35 nodes to be scored	(79 eliminated genes)
#
# 	 Level 4:	31 nodes to be scored	(143 eliminated genes)
#
# 	 Level 3:	20 nodes to be scored	(196 eliminated genes)
#
# 	 Level 2:	10 nodes to be scored	(218 eliminated genes)
#
# 	 Level 1:	1 nodes to be scored	(228 eliminated genes)
#
# Building most specific GOs .....
# 	( 572 GO terms found. )
#
# Build GO DAG topology ..........
# 	( 1848 GO terms and 4082 relations. )
#
# Annotating nodes ...............
# 	( 252 genes annotated to the GO terms. )
#
# 			 -- Weight01 Algorithm --
#
# 		 the algorithm is scoring 80 nontrivial nodes
# 		 parameters:
# 			 test statistic: fisher
#
# 	 Level 9:	1 nodes to be scored	(0 eliminated genes)
#
# 	 Level 8:	3 nodes to be scored	(0 eliminated genes)
#
# 	 Level 7:	5 nodes to be scored	(4 eliminated genes)
#
# 	 Level 6:	10 nodes to be scored	(5 eliminated genes)
#
# 	 Level 5:	13 nodes to be scored	(14 eliminated genes)
#
# 	 Level 4:	22 nodes to be scored	(27 eliminated genes)
#
# 	 Level 3:	16 nodes to be scored	(98 eliminated genes)
#
# 	 Level 2:	9 nodes to be scored	(193 eliminated genes)
#
# 	 Level 1:	1 nodes to be scored	(229 eliminated genes)

# %%
rownames(enrichmentResults) <- c("terms","p-values","genes")
colnames(enrichmentResults) <- 2:max(assignments)

# %%
enrichmentResults["terms", "6"]
# Out:
# [[1]]
#            go_id                                                        Term
# 2441  GO:0001731              formation of translation preinitiation complex
# 14824 GO:0045454                                      cell redox homeostasis
# 35727 GO:0030950 establishment or maintenance of actin cytoskeleton polarity
# 36891 GO:0031505                          fungal-type cell wall organization
# 44024 GO:0034503              protein localization to nucleolar rDNA repeats
# 54648 GO:0045143                           homologous chromosome segregation
# 78651 GO:0070550                                           rDNA condensation
# 79446 GO:0070941                                           eisosome assembly
# 83423 GO:0090002    establishment of protein localization to plasma membrane
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Definition
# 2441                                                                                                                                                                                                                                                                                                                                                                                                                                                  The joining of the small ribosomal subunit, ternary complex, and mRNA.
# 14824                                                                                                                                                                                                                                                                                                                                                                                                                               Any process that maintains the redox environment of a cell or compartment within a cell.
# 35727                                                                                                                                                                                                                                                                                                                                                                                     Any cellular process that results in the specification, formation or maintenance of polarized actin-based cytoskeletal structures.
# 36891                                                                                                                                                                                                                                                                                                                                                      A process that is carried out at the cellular level which results in the assembly, arrangement of constituent parts, or disassembly of the fungal-type cell wall.
# 44024                                                                                                                                                                                                                                                                                                                                                                                                 Any process in which a protein is transported to, or maintained at, the rDNA repeats on a chromosome in the nucleolus.
# 54648 The cell cycle process in which replicated homologous chromosomes are organized and then physically separated and apportioned to two sets during the first division of the meiotic cell cycle. Each replicated chromosome, composed of two sister chromatids, aligns at the cell equator, paired with its homologous partner; this pairing off, referred to as synapsis, permits genetic recombination. One homolog (both sister chromatids) of each morphologic type goes into each of the resulting chromosome sets.
# 78651                                                                                                                                                                                                                                                                                                                                                       The process in which the chromatin structure of the rDNA repeats is compacted. In S. cerevisiae, condensation and resolution of the rDNA occurs during anaphase.
# 79446                                                                                                                                                             The aggregation, arrangement and bonding together of a set of components to form an eisosome, a cell part that is composed of the eisosome membrane or MCC domain, a furrow-like plasma membrane sub-domain and associated integral transmembrane proteins, and the proteins (eisosome filaments) that form a scaffolding lattice on the cytoplasmic face.
# 83423                                                                                                                                                                                                                                                                                                                                                                                                                                      The directed movement of a protein to a specific location in the plasma membrane.

# %%
enrichmentResults[["p-values", "14"]]
# Out:
# GO:0055114 GO:0030950 GO:0000050
# 0.02094775 0.04867463 0.04867463

# %%
enrichmentResults[["p-values", "15"]]
# Out:
#  GO:0034503  GO:0045143  GO:0070550  GO:0001731
# 0.004837792 0.026605756 0.004837792 0.004837792

# %%
mean(getTermSim(termlist = names(enrichmentResults[["p-values", "6"]]), method = "Resnik", verbose = F))
# Out:
# [1] Inf

# %%
mean(getTermSim(termlist = names(enrichmentResults[["p-values", "14"]]), method = "Resnik", verbose = F))
# Out:
# [1] 0.2698895

# %%
mean(getTermSim(termlist = names(enrichmentResults[["p-values", "15"]]), method = "Resnik", verbose = F))
# Out:
# [1] Inf

# %%
enrichmentResults["p-values",]
# Out:
# $`2`
#  GO:0006355  GO:0051123  GO:0044376  GO:1990022  GO:1903833  GO:0007064
# 0.017766354 0.000364910 0.001705559 0.014703092 0.014703092 0.013864542
#  GO:0016573
# 0.001705559
#
# $`3`
# GO:0009651 GO:0000122 GO:0016925 GO:0042766 GO:0042787 GO:0000722
# 0.04357174 0.01085902 0.04226295 0.04357174 0.04357174 0.03019994
#
# $`4`
#  GO:0032258  GO:0000422  GO:0015031  GO:0030242  GO:0007032  GO:0007034
# 0.001320829 0.013324099 0.005367128 0.002461814 0.024663252 0.019238023
#  GO:0007035  GO:0044805  GO:0006999  GO:0034727  GO:0006914  GO:0046777
# 0.024663252 0.003748814 0.002293801 0.003748814 0.018564748 0.024663252
#  GO:0006890  GO:0032147  GO:0007118  GO:0000301  GO:0006810  GO:0030474
# 0.024663252 0.003748814 0.024663252 0.024663252 0.007844947 0.024663252
#
# $`5`
#  GO:0006397  GO:2000221  GO:0045722  GO:0001302  GO:0000184  GO:0034063
# 0.027381477 0.015683299 0.015683299 0.015680617 0.028640287 0.015683299
#  GO:0007155  GO:0043254  GO:0031087  GO:0007126  GO:1900153  GO:0080009
# 0.015683299 0.041967019 0.006870418 0.016414997 0.015683299 0.015683299
#  GO:0006279  GO:0000290  GO:0033962  GO:0001403
# 0.015683299 0.015680617 0.015683299 0.001881996
#
# $`6`
#  GO:0030950  GO:0045143  GO:0031505  GO:0001731  GO:0070550  GO:0034503
# 0.008385506 0.040963855 0.027656086 0.041927528 0.041927528 0.041927528
#  GO:0045454  GO:0070941  GO:0090002
# 0.041927528 0.041927528 0.041927528
#
# $`7`
#   GO:0000132   GO:0051301   GO:0007094   GO:0007067   GO:0030437   GO:0051726
# 0.0013864542 0.0048218493 0.0006654765 0.0452011920 0.0357397078 0.0078369906
#   GO:0044774
# 0.0012580041
#
# $`8`
#  GO:0070481  GO:0070478  GO:0071051  GO:0071028  GO:0071042  GO:0071035
# 0.009614874 0.003320053 0.003320053 0.003320053 0.003320053 0.003320053
#  GO:0071038  GO:0070651  GO:0000467  GO:0034475  GO:0070987
# 0.003320053 0.003320053 0.003320053 0.003320053 0.009614874
#
# $`9`
#   GO:0006913   GO:0032465   GO:0007088   GO:0006606   GO:0031990   GO:0000755
# 3.354073e-02 3.174603e-02 2.868852e-02 1.344673e-02 3.174603e-02 3.174603e-02
#   GO:0015031   GO:0051028   GO:0030474   GO:0060188   GO:0006999   GO:0072417
# 7.500700e-03 2.751269e-04 8.853475e-04 3.174603e-02 1.090695e-06 3.174603e-02
#   GO:0090337
# 3.174603e-02
#
# $`10`
#   GO:0006810   GO:0032543   GO:0032880   GO:0007032   GO:0034727   GO:0000422
# 0.0322085143 0.0277777778 0.0019654714 0.0006640106 0.0019654714 0.0038784621
#   GO:0044805   GO:0032258   GO:0061709
# 0.0019654714 0.0130367925 0.0277777778
#
# $`11`
#  GO:0023014  GO:0006914  GO:0000920  GO:0001113  GO:0032258  GO:0070816
# 0.047619048 0.001582223 0.047619048 0.047619048 0.038290133 0.047619048
#  GO:0006289  GO:0031098  GO:0007039  GO:0006887  GO:0006888  GO:0032147
# 0.047619048 0.047619048 0.047619048 0.047619048 0.006093720 0.006093720
#  GO:0007118  GO:0030433  GO:0030242
# 0.002086891 0.047619048 0.019244261
#
# $`12`
# GO:0015991 GO:0006620 GO:0030242 GO:0016560 GO:0007030 GO:0007034 GO:0007035
# 0.03968254 0.03968254 0.01333723 0.03968254 0.03968254 0.01136309 0.00142288
# GO:0045048 GO:0006890 GO:0070072 GO:0007266 GO:0006797 GO:0048213
# 0.03968254 0.00142288 0.03968254 0.03968254 0.03968254 0.03968254
#
# $`13`
# GO:0015693 GO:0032511 GO:0006446 GO:0006895 GO:0036010 GO:0098655 GO:0019509
# 0.01190476 0.01190476 0.04705141 0.01190476 0.01190476 0.03543009 0.02371467
#
# $`14`
# GO:0055114 GO:0030950 GO:0000050
# 0.02094775 0.04867463 0.04867463
#
# $`15`
#  GO:0034503  GO:0045143  GO:0070550  GO:0001731
# 0.004837792 0.026605756 0.004837792 0.004837792
#
# $`16`
#   GO:0006289   GO:0006360   GO:0042981   GO:0031098   GO:0007118   GO:0032147
# 0.0238095238 0.0471447543 0.0471447543 0.0238095238 0.0004742933 0.0014077025
#   GO:0023014   GO:0070816   GO:0000920   GO:0001113
# 0.0238095238 0.0238095238 0.0238095238 0.0238095238
#
# $`17`
#  GO:0006914  GO:0030433  GO:0046777  GO:0016485  GO:0016050  GO:0006887
# 0.009614874 0.011904762 0.023714665 0.023714665 0.047051413 0.011904762
#  GO:0006888
# 0.035430089
#
# $`18`
#  GO:0007039
# 0.003968254
#
# $`19`
# GO:0000301 GO:0016973 GO:0006409 GO:0030242 GO:0000055 GO:0006888
# 0.01584140 0.03155631 0.01584140 0.03936634 0.02371467 0.02371467
#
# $`20`
#  GO:0070550  GO:0007089  GO:0031860  GO:0070814  GO:0000183  GO:0003333
# 0.001138304 0.035714286 0.035714286 0.035714286 0.035714286 0.035714286
#  GO:1990145  GO:0034503  GO:0090282  GO:0019343  GO:0019346  GO:0031292
# 0.035714286 0.001138304 0.035714286 0.035714286 0.035714286 0.035714286
#  GO:0000737  GO:0045143  GO:0015827  GO:0006535
# 0.035714286 0.006577148 0.035714286 0.035714286
#
# $`21`
# GO:0045454 GO:0001731 GO:0003400 GO:0090002 GO:0000754 GO:0007120 GO:0007121
# 0.03936634 0.03936634 0.01984127 0.03936634 0.01984127 0.01984127 0.01984127
# GO:0070941
# 0.03936634
#
# $`22`
# GO:0016241 GO:0006972 GO:0046685 GO:0034605 GO:0007231 GO:0033262 GO:0009967
# 0.04705141 0.03155631 0.01587302 0.04705141 0.03155631 0.03155631 0.03155631
# GO:0061393 GO:0034316
# 0.01587302 0.01587302
#
# $`23`
#   GO:0007118   GO:0000902   GO:0070816   GO:0032147   GO:0000920   GO:0042981
# 9.485866e-05 4.705141e-02 1.190476e-02 3.543009e-02 1.190476e-02 2.371467e-02
#   GO:0023014   GO:0006289   GO:0006360   GO:0031098
# 1.190476e-02 1.190476e-02 2.371467e-02 1.190476e-02
#
# $`24`
#  GO:0001113  GO:0006367
# 0.007936508 0.039840637
#
# $`25`
# GO:0000045 GO:0044805 GO:0034727 GO:0000422 GO:0032147 GO:0030242
# 0.01984127 0.01190476 0.01190476 0.01587302 0.01190476 0.01984127
#
# $`26`
# GO:0000754 GO:0003400 GO:0006446 GO:0001731 GO:0007120 GO:0007121
# 0.01190476 0.01190476 0.04705141 0.02371467 0.01190476 0.01190476
#
# $`27`
# GO:0051017 GO:0016197 GO:0034599 GO:0001558 GO:0045454 GO:0070941 GO:0016226
# 0.03155631 0.02371467 0.02371467 0.03936634 0.01584140 0.01584140 0.02371467
# GO:0090002 GO:0038203 GO:0006970 GO:0030950
# 0.01584140 0.02371467 0.03936634 0.02371467

# %%
communitySimilarity <- function(community) {
    termSims <- getTermSim(termlist = names(community), method = "Resnik", verbose = F)
    if (length(geneSims) > 1) {
        return(mean(termSims[upper.tri(termSims)]))
    } else {
        return (NaN)
    }
}

# %%
enrichmentResults[["p-values", "5"]]
# Out:
#  GO:0006397  GO:2000221  GO:0045722  GO:0001302  GO:0000184  GO:0034063
# 0.027381477 0.015683299 0.015683299 0.015680617 0.028640287 0.015683299
#  GO:0007155  GO:0043254  GO:0031087  GO:0007126  GO:1900153  GO:0080009
# 0.015683299 0.041967019 0.006870418 0.016414997 0.015683299 0.015683299
#  GO:0006279  GO:0000290  GO:0033962  GO:0001403
# 0.015683299 0.015680617 0.015683299 0.001881996

# %%
communitySimilarity(enrichmentResults[["p-values", "5"]])
# Out:
# Error in communitySimilarity(enrichmentResults[["p-values", "5"]]): object 'geneSims' not found
# Traceback:
#
# 1. communitySimilarity(enrichmentResults[["p-values", "5"]])

# %%
layerSimilarity <- function(layer) {
    p-valueList <- enrichmentResults["p-values", unique(assignments[,layer][assignments[,layer] != -1])]
    communitiesSimilarity <- sapply(p-valueList, communitySimilarity)
    communitiesSimilarity <- communitiesSimilarity[!is.na(communitiesSimilarity)]
    return(mean(communitiesSimilarity))
}

# %%
layerMeanSimilarities <- sapply(colnames, layerSimilarity)
